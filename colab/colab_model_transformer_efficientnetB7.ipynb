# %%
! wget http://images.cocodataset.org/zips/train2014.zip
! wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip
! sudo apt-get install unzip
! unzip train2014.zip -d coco
! unzip annotations_trainval2014.zip -d coco
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: coco/train2014/COCO_train2014_000000200024.jpg
#  extracting: coco/train2014/COCO_train2014_000000435713.jpg
#  extracting: coco/train2014/COCO_train2014_000000249993.jpg
#  extracting: coco/train2014/COCO_train2014_000000424160.jpg
#  extracting: coco/train2014/COCO_train2014_000000142761.jpg
#  extracting: coco/train2014/COCO_train2014_000000532668.jpg
#  extracting: coco/train2014/COCO_train2014_000000564904.jpg
#  extracting: coco/train2014/COCO_train2014_000000346384.jpg
#  extracting: coco/train2014/COCO_train2014_000000560934.jpg
#  extracting: coco/train2014/COCO_train2014_000000122356.jpg
#  extracting: coco/train2014/COCO_train2014_000000193042.jpg
#  extracting: coco/train2014/COCO_train2014_000000072702.jpg
#  extracting: coco/train2014/COCO_train2014_000000064795.jpg
#  extracting: coco/train2014/COCO_train2014_000000118089.jpg
#  extracting: coco/train2014/COCO_train2014_000000082228.jpg
#  extracting: coco/train2014/COCO_train2014_000000002148.jpg
#  extracting: coco/train2014/COCO_train2014_000000102210.jpg
#  extracting: coco/train2014/COCO_train2014_000000281355.jpg
#  extracting: coco/train2014/COCO_train2014_000000312076.jpg
#  extracting: coco/train2014/COCO_train2014_000000040008.jpg
#  extracting: coco/train2014/COCO_train2014_000000483458.jpg
#  extracting: coco/train2014/COCO_train2014_000000205131.jpg
#  extracting: coco/train2014/COCO_train2014_000000223534.jpg
#  extracting: coco/train2014/COCO_train2014_000000309137.jpg
#  extracting: coco/train2014/COCO_train2014_000000353559.jpg
#  extracting: coco/train2014/COCO_train2014_000000088136.jpg
#  extracting: coco/train2014/COCO_train2014_000000550649.jpg
#  extracting: coco/train2014/COCO_train2014_000000541343.jpg
#  extracting: coco/train2014/COCO_train2014_000000522992.jpg
#  extracting: coco/train2014/COCO_train2014_000000079107.jpg
#  extracting: coco/train2014/COCO_train2014_000000475185.jpg
#  extracting: coco/train2014/COCO_train2014_000000561339.jpg
#  extracting: coco/train2014/COCO_train2014_000000273503.jpg
#  extracting: coco/train2014/COCO_train2014_000000566439.jpg
#  extracting: coco/train2014/COCO_train2014_000000364457.jpg
#  extracting: coco/train2014/COCO_train2014_000000006355.jpg
#  extracting: coco/train2014/COCO_train2014_000000254078.jpg
#  extracting: coco/train2014/COCO_train2014_000000204867.jpg
#  extracting: coco/train2014/COCO_train2014_000000266496.jpg
#  extracting: coco/train2014/COCO_train2014_000000065712.jpg
#  extracting: coco/train2014/COCO_train2014_000000092731.jpg
#  extracting: coco/train2014/COCO_train2014_000000173474.jpg
#  extracting: coco/train2014/COCO_train2014_000000136043.jpg
#  extracting: coco/train2014/COCO_train2014_000000232919.jpg
#  extracting: coco/train2014/COCO_train2014_000000223526.jpg
#  extracting: coco/train2014/COCO_train2014_000000091973.jpg
#  extracting: coco/train2014/COCO_train2014_000000224407.jpg
#  extracting: coco/train2014/COCO_train2014_000000129753.jpg
#  extracting: coco/train2014/COCO_train2014_000000300454.jpg
#  extracting: coco/train2014/COCO_train2014_000000560388.jpg
#  extracting: coco/train2014/COCO_train2014_000000292146.jpg
#  extracting: coco/train2014/COCO_train2014_000000362839.jpg
#  extracting: coco/train2014/COCO_train2014_000000505418.jpg
#  extracting: coco/train2014/COCO_train2014_000000565858.jpg
#  extracting: coco/train2014/COCO_train2014_000000313971.jpg
#  extracting: coco/train2014/COCO_train2014_000000484899.jpg
#  extracting: coco/train2014/COCO_train2014_000000464372.jpg
#  extracting: coco/train2014/COCO_train2014_000000259316.jpg
#  extracting: coco/train2014/COCO_train2014_000000265449.jpg
#  extracting: coco/train2014/COCO_train2014_000000334645.jpg
#  extracting: coco/train2014/COCO_train2014_000000474405.jpg
#  extracting: coco/train2014/COCO_train2014_000000084391.jpg
#  extracting: coco/train2014/COCO_train2014_000000014764.jpg
#  extracting: coco/train2014/COCO_train2014_000000566236.jpg
#  extracting: coco/train2014/COCO_train2014_000000552461.jpg
#  extracting: coco/train2014/COCO_train2014_000000237009.jpg
#  extracting: coco/train2014/COCO_train2014_000000131579.jpg
#  extracting: coco/train2014/COCO_train2014_000000415497.jpg
#  extracting: coco/train2014/COCO_train2014_000000167995.jpg
#  extracting: coco/train2014/COCO_train2014_000000431492.jpg
#  extracting: coco/train2014/COCO_train2014_000000346978.jpg
#  extracting: coco/train2014/COCO_train2014_000000097260.jpg
#  extracting: coco/train2014/COCO_train2014_000000395007.jpg
#  extracting: coco/train2014/COCO_train2014_000000537772.jpg
#  extracting: coco/train2014/COCO_train2014_000000411212.jpg
#  extracting: coco/train2014/COCO_train2014_000000258714.jpg
#  extracting: coco/train2014/COCO_train2014_000000081944.jpg
#  extracting: coco/train2014/COCO_train2014_000000353906.jpg
#  extracting: coco/train2014/COCO_train2014_000000279762.jpg
#  extracting: coco/train2014/COCO_train2014_000000459201.jpg
#  extracting: coco/train2014/COCO_train2014_000000057868.jpg
#  extracting: coco/train2014/COCO_train2014_000000358545.jpg
#  extracting: coco/train2014/COCO_train2014_000000326712.jpg
#  extracting: coco/train2014/COCO_train2014_000000478306.jpg
#  extracting: coco/train2014/COCO_train2014_000000430391.jpg
#  extracting: coco/train2014/COCO_train2014_000000013703.jpg
#  extracting: coco/train2014/COCO_train2014_000000137681.jpg
#  extracting: coco/train2014/COCO_train2014_000000267192.jpg
#  extracting: coco/train2014/COCO_train2014_000000454406.jpg
#  extracting: coco/train2014/COCO_train2014_000000461333.jpg
#  extracting: coco/train2014/COCO_train2014_000000575149.jpg
#  extracting: coco/train2014/COCO_train2014_000000181828.jpg
#  extracting: coco/train2014/COCO_train2014_000000202372.jpg
#  extracting: coco/train2014/COCO_train2014_000000121535.jpg
#  extracting: coco/train2014/COCO_train2014_000000368738.jpg
#  extracting: coco/train2014/COCO_train2014_000000425200.jpg
#  extracting: coco/train2014/COCO_train2014_000000350784.jpg
#  extracting: coco/train2014/COCO_train2014_000000287213.jpg
#  extracting: coco/train2014/COCO_train2014_000000093363.jpg
#  extracting: coco/train2014/COCO_train2014_000000539789.jpg
#  extracting: coco/train2014/COCO_train2014_000000390742.jpg
#  extracting: coco/train2014/COCO_train2014_000000531033.jpg
#  extracting: coco/train2014/COCO_train2014_000000548964.jpg
#  extracting: coco/train2014/COCO_train2014_000000308221.jpg
#  extracting: coco/train2014/COCO_train2014_000000476430.jpg
#  extracting: coco/train2014/COCO_train2014_000000237034.jpg
#  extracting: coco/train2014/COCO_train2014_000000496730.jpg
#  extracting: coco/train2014/COCO_train2014_000000513520.jpg
#  extracting: coco/train2014/COCO_train2014_000000273710.jpg
#  extracting: coco/train2014/COCO_train2014_000000573456.jpg
#  extracting: coco/train2014/COCO_train2014_000000495931.jpg
#  extracting: coco/train2014/COCO_train2014_000000097296.jpg
#  extracting: coco/train2014/COCO_train2014_000000314750.jpg
#  extracting: coco/train2014/COCO_train2014_000000146208.jpg
#  extracting: coco/train2014/COCO_train2014_000000524253.jpg
#  extracting: coco/train2014/COCO_train2014_000000544053.jpg
#  extracting: coco/train2014/COCO_train2014_000000069205.jpg
#  extracting: coco/train2014/COCO_train2014_000000116326.jpg
#  extracting: coco/train2014/COCO_train2014_000000479867.jpg
#  extracting: coco/train2014/COCO_train2014_000000561426.jpg
#  extracting: coco/train2014/COCO_train2014_000000112459.jpg
#  extracting: coco/train2014/COCO_train2014_000000114035.jpg
#  extracting: coco/train2014/COCO_train2014_000000101357.jpg
#  extracting: coco/train2014/COCO_train2014_000000074842.jpg
#  extracting: coco/train2014/COCO_train2014_000000529542.jpg
#  extracting: coco/train2014/COCO_train2014_000000222074.jpg
#  extracting: coco/train2014/COCO_train2014_000000266271.jpg
#  extracting: coco/train2014/COCO_train2014_000000328654.jpg
#  extracting: coco/train2014/COCO_train2014_000000301918.jpg
#  extracting: coco/train2014/COCO_train2014_000000403899.jpg
#  extracting: coco/train2014/COCO_train2014_000000257517.jpg
#  extracting: coco/train2014/COCO_train2014_000000177060.jpg
#  extracting: coco/train2014/COCO_train2014_000000449179.jpg
#  extracting: coco/train2014/COCO_train2014_000000157801.jpg
#  extracting: coco/train2014/COCO_train2014_000000289561.jpg
#  extracting: coco/train2014/COCO_train2014_000000539189.jpg
#  extracting: coco/train2014/COCO_train2014_000000116783.jpg
#  extracting: coco/train2014/COCO_train2014_000000114925.jpg
#  extracting: coco/train2014/COCO_train2014_000000056705.jpg
#  extracting: coco/train2014/COCO_train2014_000000075466.jpg
#  extracting: coco/train2014/COCO_train2014_000000364879.jpg
#  extracting: coco/train2014/COCO_train2014_000000101749.jpg
#  extracting: coco/train2014/COCO_train2014_000000025421.jpg
#  extracting: coco/train2014/COCO_train2014_000000283624.jpg
#  extracting: coco/train2014/COCO_train2014_000000049095.jpg
#  extracting: coco/train2014/COCO_train2014_000000207471.jpg
#  extracting: coco/train2014/COCO_train2014_000000440532.jpg
#  extracting: coco/train2014/COCO_train2014_000000056857.jpg
#  extracting: coco/train2014/COCO_train2014_000000395500.jpg
#  extracting: coco/train2014/COCO_train2014_000000208898.jpg
#  extracting: coco/train2014/COCO_train2014_000000338760.jpg
#  extracting: coco/train2014/COCO_train2014_000000580971.jpg
#  extracting: coco/train2014/COCO_train2014_000000517972.jpg
#  extracting: coco/train2014/COCO_train2014_000000028518.jpg
#  extracting: coco/train2014/COCO_train2014_000000256576.jpg
#  extracting: coco/train2014/COCO_train2014_000000528900.jpg
#  extracting: coco/train2014/COCO_train2014_000000002886.jpg
#  extracting: coco/train2014/COCO_train2014_000000114686.jpg
#  extracting: coco/train2014/COCO_train2014_000000258073.jpg
#  extracting: coco/train2014/COCO_train2014_000000445392.jpg
#  extracting: coco/train2014/COCO_train2014_000000221540.jpg
#  extracting: coco/train2014/COCO_train2014_000000493791.jpg
#  extracting: coco/train2014/COCO_train2014_000000038718.jpg
#  extracting: coco/train2014/COCO_train2014_000000110094.jpg
#  extracting: coco/train2014/COCO_train2014_000000440738.jpg
#  extracting: coco/train2014/COCO_train2014_000000290969.jpg
#  extracting: coco/train2014/COCO_train2014_000000105063.jpg
#  extracting: coco/train2014/COCO_train2014_000000172148.jpg
#  extracting: coco/train2014/COCO_train2014_000000101050.jpg
#  extracting: coco/train2014/COCO_train2014_000000184493.jpg
#  extracting: coco/train2014/COCO_train2014_000000501381.jpg
#  extracting: coco/train2014/COCO_train2014_000000536103.jpg
#  extracting: coco/train2014/COCO_train2014_000000009999.jpg
#  extracting: coco/train2014/COCO_train2014_000000462129.jpg
#  extracting: coco/train2014/COCO_train2014_000000374598.jpg
#  extracting: coco/train2014/COCO_train2014_000000472861.jpg
#  extracting: coco/train2014/COCO_train2014_000000052562.jpg
#  extracting: coco/train2014/COCO_train2014_000000182118.jpg
#  extracting: coco/train2014/COCO_train2014_000000009226.jpg
#  extracting: coco/train2014/COCO_train2014_000000369931.jpg
#  extracting: coco/train2014/COCO_train2014_000000127330.jpg
#  extracting: coco/train2014/COCO_train2014_000000566591.jpg
#  extracting: coco/train2014/COCO_train2014_000000233688.jpg
#  extracting: coco/train2014/COCO_train2014_000000029915.jpg
#  extracting: coco/train2014/COCO_train2014_000000004159.jpg
#  extracting: coco/train2014/COCO_train2014_000000030023.jpg
#  extracting: coco/train2014/COCO_train2014_000000343204.jpg
#  extracting: coco/train2014/COCO_train2014_000000241785.jpg
#  extracting: coco/train2014/COCO_train2014_000000218274.jpg
#  extracting: coco/train2014/COCO_train2014_000000145264.jpg
#  extracting: coco/train2014/COCO_train2014_000000008829.jpg
#  extracting: coco/train2014/COCO_train2014_000000337775.jpg
#  extracting: coco/train2014/COCO_train2014_000000380455.jpg
#  extracting: coco/train2014/COCO_train2014_000000114068.jpg
#  extracting: coco/train2014/COCO_train2014_000000360725.jpg
#  extracting: coco/train2014/COCO_train2014_000000264322.jpg
#  extracting: coco/train2014/COCO_train2014_000000030357.jpg
#  extracting: coco/train2014/COCO_train2014_000000365030.jpg
#  extracting: coco/train2014/COCO_train2014_000000489085.jpg
#  extracting: coco/train2014/COCO_train2014_000000400828.jpg
#  extracting: coco/train2014/COCO_train2014_000000484300.jpg
#  extracting: coco/train2014/COCO_train2014_000000234642.jpg
#  extracting: coco/train2014/COCO_train2014_000000553777.jpg
#  extracting: coco/train2014/COCO_train2014_000000535514.jpg
#  extracting: coco/train2014/COCO_train2014_000000255877.jpg
#  extracting: coco/train2014/COCO_train2014_000000419618.jpg
#  extracting: coco/train2014/COCO_train2014_000000412142.jpg
#  extracting: coco/train2014/COCO_train2014_000000515464.jpg
#  extracting: coco/train2014/COCO_train2014_000000372634.jpg
#  extracting: coco/train2014/COCO_train2014_000000179480.jpg
#  extracting: coco/train2014/COCO_train2014_000000169517.jpg
#  extracting: coco/train2014/COCO_train2014_000000213554.jpg
#  extracting: coco/train2014/COCO_train2014_000000237561.jpg
#  extracting: coco/train2014/COCO_train2014_000000496918.jpg
#  extracting: coco/train2014/COCO_train2014_000000474356.jpg
#  extracting: coco/train2014/COCO_train2014_000000082936.jpg
#  extracting: coco/train2014/COCO_train2014_000000129689.jpg
#  extracting: coco/train2014/COCO_train2014_000000571805.jpg
#  extracting: coco/train2014/COCO_train2014_000000037757.jpg
#  extracting: coco/train2014/COCO_train2014_000000161083.jpg
#  extracting: coco/train2014/COCO_train2014_000000003276.jpg
#  extracting: coco/train2014/COCO_train2014_000000255306.jpg
#  extracting: coco/train2014/COCO_train2014_000000578041.jpg
#  extracting: coco/train2014/COCO_train2014_000000468518.jpg
#  extracting: coco/train2014/COCO_train2014_000000311238.jpg
#  extracting: coco/train2014/COCO_train2014_000000277491.jpg
#  extracting: coco/train2014/COCO_train2014_000000268855.jpg
#  extracting: coco/train2014/COCO_train2014_000000554182.jpg
#  extracting: coco/train2014/COCO_train2014_000000061045.jpg
#  extracting: coco/train2014/COCO_train2014_000000186317.jpg
#  extracting: coco/train2014/COCO_train2014_000000208678.jpg
#  extracting: coco/train2014/COCO_train2014_000000116204.jpg
#  extracting: coco/train2014/COCO_train2014_000000483424.jpg
#  extracting: coco/train2014/COCO_train2014_000000494941.jpg
#  extracting: coco/train2014/COCO_train2014_000000145174.jpg
#  extracting: coco/train2014/COCO_train2014_000000521907.jpg
#  extracting: coco/train2014/COCO_train2014_000000191690.jpg
#  extracting: coco/train2014/COCO_train2014_000000006424.jpg
#  extracting: coco/train2014/COCO_train2014_000000103018.jpg
#  extracting: coco/train2014/COCO_train2014_000000280642.jpg
#  extracting: coco/train2014/COCO_train2014_000000002229.jpg
#  extracting: coco/train2014/COCO_train2014_000000079530.jpg
#  extracting: coco/train2014/COCO_train2014_000000504259.jpg
#  extracting: coco/train2014/COCO_train2014_000000261871.jpg
#  extracting: coco/train2014/COCO_train2014_000000497327.jpg
#  extracting: coco/train2014/COCO_train2014_000000231401.jpg
#  extracting: coco/train2014/COCO_train2014_000000148824.jpg
#  extracting: coco/train2014/COCO_train2014_000000287503.jpg
#  extracting: coco/train2014/COCO_train2014_000000423412.jpg
#  extracting: coco/train2014/COCO_train2014_000000052270.jpg
#  extracting: coco/train2014/COCO_train2014_000000067082.jpg
#  extracting: coco/train2014/COCO_train2014_000000237423.jpg
#  extracting: coco/train2014/COCO_train2014_000000375674.jpg
#  extracting: coco/train2014/COCO_train2014_000000147865.jpg
#  extracting: coco/train2014/COCO_train2014_000000344618.jpg
#  extracting: coco/train2014/COCO_train2014_000000353274.jpg
#  extracting: coco/train2014/COCO_train2014_000000411851.jpg
#  extracting: coco/train2014/COCO_train2014_000000262136.jpg
#  extracting: coco/train2014/COCO_train2014_000000498138.jpg
#  extracting: coco/train2014/COCO_train2014_000000408040.jpg
#  extracting: coco/train2014/COCO_train2014_000000573166.jpg
#  extracting: coco/train2014/COCO_train2014_000000118775.jpg
#  extracting: coco/train2014/COCO_train2014_000000035351.jpg
#  extracting: coco/train2014/COCO_train2014_000000143420.jpg
#  extracting: coco/train2014/COCO_train2014_000000416516.jpg
#  extracting: coco/train2014/COCO_train2014_000000138536.jpg
#  extracting: coco/train2014/COCO_train2014_000000280068.jpg
#  extracting: coco/train2014/COCO_train2014_000000112805.jpg
#  extracting: coco/train2014/COCO_train2014_000000572250.jpg
#  extracting: coco/train2014/COCO_train2014_000000169474.jpg
#  extracting: coco/train2014/COCO_train2014_000000563488.jpg
#  extracting: coco/train2014/COCO_train2014_000000495902.jpg
#  extracting: coco/train2014/COCO_train2014_000000004546.jpg
#  extracting: coco/train2014/COCO_train2014_000000419767.jpg
#  extracting: coco/train2014/COCO_train2014_000000427154.jpg
#  extracting: coco/train2014/COCO_train2014_000000569592.jpg
#  extracting: coco/train2014/COCO_train2014_000000539313.jpg
#  extracting: coco/train2014/COCO_train2014_000000338120.jpg
#  extracting: coco/train2014/COCO_train2014_000000470781.jpg
#  extracting: coco/train2014/COCO_train2014_000000335184.jpg
#  extracting: coco/train2014/COCO_train2014_000000551757.jpg
#  extracting: coco/train2014/COCO_train2014_000000377585.jpg
#  extracting: coco/train2014/COCO_train2014_000000230428.jpg
#  extracting: coco/train2014/COCO_train2014_000000117284.jpg
#  extracting: coco/train2014/COCO_train2014_000000112989.jpg
#  extracting: coco/train2014/COCO_train2014_000000342592.jpg
#  extracting: coco/train2014/COCO_train2014_000000578793.jpg
#  extracting: coco/train2014/COCO_train2014_000000419785.jpg
#  extracting: coco/train2014/COCO_train2014_000000196294.jpg
#  extracting: coco/train2014/COCO_train2014_000000507542.jpg
#  extracting: coco/train2014/COCO_train2014_000000281505.jpg
#  extracting: coco/train2014/COCO_train2014_000000542186.jpg
#  extracting: coco/train2014/COCO_train2014_000000178572.jpg
#  extracting: coco/train2014/COCO_train2014_000000543289.jpg
#  extracting: coco/train2014/COCO_train2014_000000397190.jpg
#  extracting: coco/train2014/COCO_train2014_000000015525.jpg
#  extracting: coco/train2014/COCO_train2014_000000056040.jpg
#  extracting: coco/train2014/COCO_train2014_000000265744.jpg
#  extracting: coco/train2014/COCO_train2014_000000557251.jpg
#  extracting: coco/train2014/COCO_train2014_000000500987.jpg
#  extracting: coco/train2014/COCO_train2014_000000313579.jpg
#  extracting: coco/train2014/COCO_train2014_000000111606.jpg
#  extracting: coco/train2014/COCO_train2014_000000003866.jpg
#  extracting: coco/train2014/COCO_train2014_000000029391.jpg
#  extracting: coco/train2014/COCO_train2014_000000021678.jpg
#  extracting: coco/train2014/COCO_train2014_000000282067.jpg
#  extracting: coco/train2014/COCO_train2014_000000158680.jpg
#  extracting: coco/train2014/COCO_train2014_000000420403.jpg
#  extracting: coco/train2014/COCO_train2014_000000250196.jpg
#  extracting: coco/train2014/COCO_train2014_000000436932.jpg
#  extracting: coco/train2014/COCO_train2014_000000114175.jpg
#  extracting: coco/train2014/COCO_train2014_000000425912.jpg
#  extracting: coco/train2014/COCO_train2014_000000266533.jpg
#  extracting: coco/train2014/COCO_train2014_000000122763.jpg
#  extracting: coco/train2014/COCO_train2014_000000105686.jpg
#  extracting: coco/train2014/COCO_train2014_000000505098.jpg
#  extracting: coco/train2014/COCO_train2014_000000526514.jpg
#  extracting: coco/train2014/COCO_train2014_000000558287.jpg
#  extracting: coco/train2014/COCO_train2014_000000238217.jpg
#  extracting: coco/train2014/COCO_train2014_000000276871.jpg
#  extracting: coco/train2014/COCO_train2014_000000510617.jpg
#  extracting: coco/train2014/COCO_train2014_000000281763.jpg
#  extracting: coco/train2014/COCO_train2014_000000036281.jpg
#  extracting: coco/train2014/COCO_train2014_000000465018.jpg
#  extracting: coco/train2014/COCO_train2014_000000473102.jpg
#  extracting: coco/train2014/COCO_train2014_000000575310.jpg
#  extracting: coco/train2014/COCO_train2014_000000360313.jpg
#  extracting: coco/train2014/COCO_train2014_000000404579.jpg
#  extracting: coco/train2014/COCO_train2014_000000506270.jpg
#  extracting: coco/train2014/COCO_train2014_000000102469.jpg
#  extracting: coco/train2014/COCO_train2014_000000307940.jpg
#  extracting: coco/train2014/COCO_train2014_000000051871.jpg
#  extracting: coco/train2014/COCO_train2014_000000198671.jpg
#  extracting: coco/train2014/COCO_train2014_000000018201.jpg
#  extracting: coco/train2014/COCO_train2014_000000278528.jpg
#  extracting: coco/train2014/COCO_train2014_000000517830.jpg
#  extracting: coco/train2014/COCO_train2014_000000048685.jpg
#  extracting: coco/train2014/COCO_train2014_000000083754.jpg
#  extracting: coco/train2014/COCO_train2014_000000118742.jpg
#  extracting: coco/train2014/COCO_train2014_000000435920.jpg
#  extracting: coco/train2014/COCO_train2014_000000026720.jpg
#  extracting: coco/train2014/COCO_train2014_000000332039.jpg
#  extracting: coco/train2014/COCO_train2014_000000388894.jpg
#  extracting: coco/train2014/COCO_train2014_000000371114.jpg
#  extracting: coco/train2014/COCO_train2014_000000213933.jpg
#  extracting: coco/train2014/COCO_train2014_000000565429.jpg
#  extracting: coco/train2014/COCO_train2014_000000124834.jpg
#  extracting: coco/train2014/COCO_train2014_000000519168.jpg
#  extracting: coco/train2014/COCO_train2014_000000177182.jpg
#  extracting: coco/train2014/COCO_train2014_000000398200.jpg
#  extracting: coco/train2014/COCO_train2014_000000386250.jpg
#  extracting: coco/train2014/COCO_train2014_000000579679.jpg
#  extracting: coco/train2014/COCO_train2014_000000326948.jpg
#  extracting: coco/train2014/COCO_train2014_000000236725.jpg
#  extracting: coco/train2014/COCO_train2014_000000118769.jpg
#  extracting: coco/train2014/COCO_train2014_000000109008.jpg
#  extracting: coco/train2014/COCO_train2014_000000080471.jpg
#  extracting: coco/train2014/COCO_train2014_000000120518.jpg
#  extracting: coco/train2014/COCO_train2014_000000480001.jpg
#  extracting: coco/train2014/COCO_train2014_000000176617.jpg
#  extracting: coco/train2014/COCO_train2014_000000229415.jpg
#  extracting: coco/train2014/COCO_train2014_000000131902.jpg
#  extracting: coco/train2014/COCO_train2014_000000098859.jpg
#  extracting: coco/train2014/COCO_train2014_000000472729.jpg
#  extracting: coco/train2014/COCO_train2014_000000100638.jpg
#  extracting: coco/train2014/COCO_train2014_000000375248.jpg
#  extracting: coco/train2014/COCO_train2014_000000015268.jpg
#  extracting: coco/train2014/COCO_train2014_000000469941.jpg
#  extracting: coco/train2014/COCO_train2014_000000002563.jpg
#  extracting: coco/train2014/COCO_train2014_000000099907.jpg
#  extracting: coco/train2014/COCO_train2014_000000292444.jpg
#  extracting: coco/train2014/COCO_train2014_000000532147.jpg
#  extracting: coco/train2014/COCO_train2014_000000320566.jpg
#  extracting: coco/train2014/COCO_train2014_000000242291.jpg
#  extracting: coco/train2014/COCO_train2014_000000390347.jpg
#  extracting: coco/train2014/COCO_train2014_000000001108.jpg
#  extracting: coco/train2014/COCO_train2014_000000426839.jpg
#  extracting: coco/train2014/COCO_train2014_000000335633.jpg
#  extracting: coco/train2014/COCO_train2014_000000544264.jpg
#  extracting: coco/train2014/COCO_train2014_000000154928.jpg
#  extracting: coco/train2014/COCO_train2014_000000163764.jpg
#  extracting: coco/train2014/COCO_train2014_000000551793.jpg
#  extracting: coco/train2014/COCO_train2014_000000014385.jpg
#  extracting: coco/train2014/COCO_train2014_000000184800.jpg
#  extracting: coco/train2014/COCO_train2014_000000062617.jpg
#  extracting: coco/train2014/COCO_train2014_000000282359.jpg
#  extracting: coco/train2014/COCO_train2014_000000579968.jpg
#  extracting: coco/train2014/COCO_train2014_000000117512.jpg
#  extracting: coco/train2014/COCO_train2014_000000152273.jpg
#  extracting: coco/train2014/COCO_train2014_000000204626.jpg
#  extracting: coco/train2014/COCO_train2014_000000361145.jpg
#  extracting: coco/train2014/COCO_train2014_000000183412.jpg
#  extracting: coco/train2014/COCO_train2014_000000067222.jpg
#  extracting: coco/train2014/COCO_train2014_000000354235.jpg
#  extracting: coco/train2014/COCO_train2014_000000004173.jpg
#  extracting: coco/train2014/COCO_train2014_000000487903.jpg
#  extracting: coco/train2014/COCO_train2014_000000551063.jpg
#  extracting: coco/train2014/COCO_train2014_000000044286.jpg
#  extracting: coco/train2014/COCO_train2014_000000160403.jpg
#  extracting: coco/train2014/COCO_train2014_000000079572.jpg
#  extracting: coco/train2014/COCO_train2014_000000303436.jpg
#  extracting: coco/train2014/COCO_train2014_000000099245.jpg
#  extracting: coco/train2014/COCO_train2014_000000311578.jpg
#  extracting: coco/train2014/COCO_train2014_000000078750.jpg
#  extracting: coco/train2014/COCO_train2014_000000502395.jpg
#  extracting: coco/train2014/COCO_train2014_000000268622.jpg
#  extracting: coco/train2014/COCO_train2014_000000548726.jpg
#  extracting: coco/train2014/COCO_train2014_000000182933.jpg
#  extracting: coco/train2014/COCO_train2014_000000483045.jpg
#  extracting: coco/train2014/COCO_train2014_000000252381.jpg
#  extracting: coco/train2014/COCO_train2014_000000480841.jpg
#  extracting: coco/train2014/COCO_train2014_000000479651.jpg
#  extracting: coco/train2014/COCO_train2014_000000283715.jpg
#  extracting: coco/train2014/COCO_train2014_000000341707.jpg
#  extracting: coco/train2014/COCO_train2014_000000566495.jpg
#  extracting: coco/train2014/COCO_train2014_000000308059.jpg
#  extracting: coco/train2014/COCO_train2014_000000449852.jpg
#  extracting: coco/train2014/COCO_train2014_000000290420.jpg
#  extracting: coco/train2014/COCO_train2014_000000473134.jpg
#  extracting: coco/train2014/COCO_train2014_000000523304.jpg
#  extracting: coco/train2014/COCO_train2014_000000039460.jpg
#  extracting: coco/train2014/COCO_train2014_000000488297.jpg
#  extracting: coco/train2014/COCO_train2014_000000020245.jpg
#  extracting: coco/train2014/COCO_train2014_000000487399.jpg
#  extracting: coco/train2014/COCO_train2014_000000526204.jpg
#  extracting: coco/train2014/COCO_train2014_000000075415.jpg
#  extracting: coco/train2014/COCO_train2014_000000513221.jpg
#  extracting: coco/train2014/COCO_train2014_000000201035.jpg
#  extracting: coco/train2014/COCO_train2014_000000380171.jpg
#  extracting: coco/train2014/COCO_train2014_000000322530.jpg
#  extracting: coco/train2014/COCO_train2014_000000438368.jpg
#  extracting: coco/train2014/COCO_train2014_000000334158.jpg
#  extracting: coco/train2014/COCO_train2014_000000194200.jpg
#  extracting: coco/train2014/COCO_train2014_000000515020.jpg
#  extracting: coco/train2014/COCO_train2014_000000009119.jpg
#  extracting: coco/train2014/COCO_train2014_000000131419.jpg
#  extracting: coco/train2014/COCO_train2014_000000196377.jpg
#  extracting: coco/train2014/COCO_train2014_000000208122.jpg
#  extracting: coco/train2014/COCO_train2014_000000172987.jpg
#  extracting: coco/train2014/COCO_train2014_000000017858.jpg
#  extracting: coco/train2014/COCO_train2014_000000187178.jpg
#  extracting: coco/train2014/COCO_train2014_000000268151.jpg
#  extracting: coco/train2014/COCO_train2014_000000138760.jpg
#  extracting: coco/train2014/COCO_train2014_000000480950.jpg
#  extracting: coco/train2014/COCO_train2014_000000415588.jpg
#  extracting: coco/train2014/COCO_train2014_000000177860.jpg
#  extracting: coco/train2014/COCO_train2014_000000280788.jpg
#  extracting: coco/train2014/COCO_train2014_000000327000.jpg
#  extracting: coco/train2014/COCO_train2014_000000394713.jpg
#  extracting: coco/train2014/COCO_train2014_000000388976.jpg
#  extracting: coco/train2014/COCO_train2014_000000473294.jpg
#  extracting: coco/train2014/COCO_train2014_000000412141.jpg
#  extracting: coco/train2014/COCO_train2014_000000404910.jpg
#  extracting: coco/train2014/COCO_train2014_000000206465.jpg
#  extracting: coco/train2014/COCO_train2014_000000539072.jpg
#  extracting: coco/train2014/COCO_train2014_000000571627.jpg
#  extracting: coco/train2014/COCO_train2014_000000245823.jpg
#  extracting: coco/train2014/COCO_train2014_000000139526.jpg
#  extracting: coco/train2014/COCO_train2014_000000205270.jpg
#  extracting: coco/train2014/COCO_train2014_000000150652.jpg
#  extracting: coco/train2014/COCO_train2014_000000028072.jpg
#  extracting: coco/train2014/COCO_train2014_000000425709.jpg
#  extracting: coco/train2014/COCO_train2014_000000206676.jpg
#  extracting: coco/train2014/COCO_train2014_000000076101.jpg
#  extracting: coco/train2014/COCO_train2014_000000563070.jpg
#  extracting: coco/train2014/COCO_train2014_000000445620.jpg
#  extracting: coco/train2014/COCO_train2014_000000510366.jpg
#  extracting: coco/train2014/COCO_train2014_000000578037.jpg
#  extracting: coco/train2014/COCO_train2014_000000161473.jpg
#  extracting: coco/train2014/COCO_train2014_000000356086.jpg
#  extracting: coco/train2014/COCO_train2014_000000277341.jpg
#  extracting: coco/train2014/COCO_train2014_000000486547.jpg
#  extracting: coco/train2014/COCO_train2014_000000064141.jpg
#  extracting: coco/train2014/COCO_train2014_000000574901.jpg
#  extracting: coco/train2014/COCO_train2014_000000547742.jpg
#  extracting: coco/train2014/COCO_train2014_000000580405.jpg
#  extracting: coco/train2014/COCO_train2014_000000285800.jpg
#  extracting: coco/train2014/COCO_train2014_000000099628.jpg
#  extracting: coco/train2014/COCO_train2014_000000332556.jpg
#  extracting: coco/train2014/COCO_train2014_000000569449.jpg
#  extracting: coco/train2014/COCO_train2014_000000270109.jpg
#  extracting: coco/train2014/COCO_train2014_000000184751.jpg
#  extracting: coco/train2014/COCO_train2014_000000468896.jpg
#  extracting: coco/train2014/COCO_train2014_000000162283.jpg
#  extracting: coco/train2014/COCO_train2014_000000502407.jpg
#  extracting: coco/train2014/COCO_train2014_000000485187.jpg
#  extracting: coco/train2014/COCO_train2014_000000467491.jpg
#  extracting: coco/train2014/COCO_train2014_000000074213.jpg
#  extracting: coco/train2014/COCO_train2014_000000352427.jpg
#  extracting: coco/train2014/COCO_train2014_000000414828.jpg
#  extracting: coco/train2014/COCO_train2014_000000443522.jpg
#  extracting: coco/train2014/COCO_train2014_000000046818.jpg
#  extracting: coco/train2014/COCO_train2014_000000055410.jpg
#  extracting: coco/train2014/COCO_train2014_000000466202.jpg
#  extracting: coco/train2014/COCO_train2014_000000158044.jpg
#  extracting: coco/train2014/COCO_train2014_000000447103.jpg
#  extracting: coco/train2014/COCO_train2014_000000185004.jpg
#  extracting: coco/train2014/COCO_train2014_000000573479.jpg
#  extracting: coco/train2014/COCO_train2014_000000348487.jpg
#  extracting: coco/train2014/COCO_train2014_000000113293.jpg
#  extracting: coco/train2014/COCO_train2014_000000314064.jpg
#  extracting: coco/train2014/COCO_train2014_000000285355.jpg
#  extracting: coco/train2014/COCO_train2014_000000382559.jpg
#  extracting: coco/train2014/COCO_train2014_000000017602.jpg
#  extracting: coco/train2014/COCO_train2014_000000250801.jpg
#  extracting: coco/train2014/COCO_train2014_000000320333.jpg
#  extracting: coco/train2014/COCO_train2014_000000216763.jpg
#  extracting: coco/train2014/COCO_train2014_000000484273.jpg
#  extracting: coco/train2014/COCO_train2014_000000507840.jpg
#  extracting: coco/train2014/COCO_train2014_000000391388.jpg
#  extracting: coco/train2014/COCO_train2014_000000119755.jpg
#  extracting: coco/train2014/COCO_train2014_000000044781.jpg
#  extracting: coco/train2014/COCO_train2014_000000125626.jpg
#  extracting: coco/train2014/COCO_train2014_000000092747.jpg
#  extracting: coco/train2014/COCO_train2014_000000379871.jpg
#  extracting: coco/train2014/COCO_train2014_000000460005.jpg
#  extracting: coco/train2014/COCO_train2014_000000390914.jpg
#  extracting: coco/train2014/COCO_train2014_000000473587.jpg
#  extracting: coco/train2014/COCO_train2014_000000038326.jpg
#  extracting: coco/train2014/COCO_train2014_000000479504.jpg
#  extracting: coco/train2014/COCO_train2014_000000461326.jpg
#  extracting: coco/train2014/COCO_train2014_000000132991.jpg
#  extracting: coco/train2014/COCO_train2014_000000573533.jpg
#  extracting: coco/train2014/COCO_train2014_000000175608.jpg
#  extracting: coco/train2014/COCO_train2014_000000311232.jpg
#  extracting: coco/train2014/COCO_train2014_000000365950.jpg
#  extracting: coco/train2014/COCO_train2014_000000220898.jpg
#  extracting: coco/train2014/COCO_train2014_000000391361.jpg
#  extracting: coco/train2014/COCO_train2014_000000063299.jpg
#  extracting: coco/train2014/COCO_train2014_000000372868.jpg
#  extracting: coco/train2014/COCO_train2014_000000424718.jpg
#  extracting: coco/train2014/COCO_train2014_000000204728.jpg
#  extracting: coco/train2014/COCO_train2014_000000350885.jpg
#  extracting: coco/train2014/COCO_train2014_000000164502.jpg
#  extracting: coco/train2014/COCO_train2014_000000275771.jpg
#  extracting: coco/train2014/COCO_train2014_000000322445.jpg
#  extracting: coco/train2014/COCO_train2014_000000429158.jpg
#  extracting: coco/train2014/COCO_train2014_000000130563.jpg
#  extracting: coco/train2014/COCO_train2014_000000163030.jpg
#  extracting: coco/train2014/COCO_train2014_000000235012.jpg
#  extracting: coco/train2014/COCO_train2014_000000189645.jpg
#  extracting: coco/train2014/COCO_train2014_000000272171.jpg
#  extracting: coco/train2014/COCO_train2014_000000310707.jpg
#  extracting: coco/train2014/COCO_train2014_000000576157.jpg
#  extracting: coco/train2014/COCO_train2014_000000181759.jpg
#  extracting: coco/train2014/COCO_train2014_000000063797.jpg
#  extracting: coco/train2014/COCO_train2014_000000260882.jpg
#  extracting: coco/train2014/COCO_train2014_000000142510.jpg
#  extracting: coco/train2014/COCO_train2014_000000062478.jpg
#  extracting: coco/train2014/COCO_train2014_000000361437.jpg
#  extracting: coco/train2014/COCO_train2014_000000372022.jpg
#  extracting: coco/train2014/COCO_train2014_000000013802.jpg
#  extracting: coco/train2014/COCO_train2014_000000146584.jpg
#  extracting: coco/train2014/COCO_train2014_000000568597.jpg
#  extracting: coco/train2014/COCO_train2014_000000347351.jpg
#  extracting: coco/train2014/COCO_train2014_000000354794.jpg
#  extracting: coco/train2014/COCO_train2014_000000130222.jpg
#  extracting: coco/train2014/COCO_train2014_000000541580.jpg
#  extracting: coco/train2014/COCO_train2014_000000145155.jpg
#  extracting: coco/train2014/COCO_train2014_000000005554.jpg
#  extracting: coco/train2014/COCO_train2014_000000571719.jpg
#  extracting: coco/train2014/COCO_train2014_000000204603.jpg
#  extracting: coco/train2014/COCO_train2014_000000445214.jpg
#  extracting: coco/train2014/COCO_train2014_000000547503.jpg
#  extracting: coco/train2014/COCO_train2014_000000187162.jpg
#  extracting: coco/train2014/COCO_train2014_000000027980.jpg
#  extracting: coco/train2014/COCO_train2014_000000216802.jpg
#  extracting: coco/train2014/COCO_train2014_000000060419.jpg
#  extracting: coco/train2014/COCO_train2014_000000117062.jpg
#  extracting: coco/train2014/COCO_train2014_000000453945.jpg
#  extracting: coco/train2014/COCO_train2014_000000408151.jpg
#  extracting: coco/train2014/COCO_train2014_000000367121.jpg
#  extracting: coco/train2014/COCO_train2014_000000137181.jpg
#  extracting: coco/train2014/COCO_train2014_000000464967.jpg
#  extracting: coco/train2014/COCO_train2014_000000426079.jpg
#  extracting: coco/train2014/COCO_train2014_000000507910.jpg
#  extracting: coco/train2014/COCO_train2014_000000263762.jpg
#  extracting: coco/train2014/COCO_train2014_000000246609.jpg
#  extracting: coco/train2014/COCO_train2014_000000329629.jpg
#  extracting: coco/train2014/COCO_train2014_000000208006.jpg
#  extracting: coco/train2014/COCO_train2014_000000176737.jpg
#  extracting: coco/train2014/COCO_train2014_000000105472.jpg
#  extracting: coco/train2014/COCO_train2014_000000156784.jpg
#  extracting: coco/train2014/COCO_train2014_000000098439.jpg
#  extracting: coco/train2014/COCO_train2014_000000255419.jpg
#  extracting: coco/train2014/COCO_train2014_000000003668.jpg
#  extracting: coco/train2014/COCO_train2014_000000500212.jpg
#  extracting: coco/train2014/COCO_train2014_000000486711.jpg
#  extracting: coco/train2014/COCO_train2014_000000062942.jpg
#  extracting: coco/train2014/COCO_train2014_000000005811.jpg
#  extracting: coco/train2014/COCO_train2014_000000277203.jpg
#  extracting: coco/train2014/COCO_train2014_000000281327.jpg
#  extracting: coco/train2014/COCO_train2014_000000443987.jpg
#  extracting: coco/train2014/COCO_train2014_000000529788.jpg
#  extracting: coco/train2014/COCO_train2014_000000433825.jpg
#  extracting: coco/train2014/COCO_train2014_000000313979.jpg
#  extracting: coco/train2014/COCO_train2014_000000090498.jpg
#  extracting: coco/train2014/COCO_train2014_000000224217.jpg
#  extracting: coco/train2014/COCO_train2014_000000333976.jpg
#  extracting: coco/train2014/COCO_train2014_000000554351.jpg
#  extracting: coco/train2014/COCO_train2014_000000513703.jpg
#  extracting: coco/train2014/COCO_train2014_000000119953.jpg
#  extracting: coco/train2014/COCO_train2014_000000509367.jpg
#  extracting: coco/train2014/COCO_train2014_000000112562.jpg
#  extracting: coco/train2014/COCO_train2014_000000049079.jpg
#  extracting: coco/train2014/COCO_train2014_000000156608.jpg
#  extracting: coco/train2014/COCO_train2014_000000044040.jpg
#  extracting: coco/train2014/COCO_train2014_000000486372.jpg
#  extracting: coco/train2014/COCO_train2014_000000540735.jpg
#  extracting: coco/train2014/COCO_train2014_000000221120.jpg
#  extracting: coco/train2014/COCO_train2014_000000013967.jpg
#  extracting: coco/train2014/COCO_train2014_000000507459.jpg
#  extracting: coco/train2014/COCO_train2014_000000030276.jpg
#  extracting: coco/train2014/COCO_train2014_000000430537.jpg
#  extracting: coco/train2014/COCO_train2014_000000337707.jpg
#  extracting: coco/train2014/COCO_train2014_000000558190.jpg
#  extracting: coco/train2014/COCO_train2014_000000223734.jpg
#  extracting: coco/train2014/COCO_train2014_000000402847.jpg
#  extracting: coco/train2014/COCO_train2014_000000126524.jpg
#  extracting: coco/train2014/COCO_train2014_000000148479.jpg
#  extracting: coco/train2014/COCO_train2014_000000181699.jpg
#  extracting: coco/train2014/COCO_train2014_000000534627.jpg
#  extracting: coco/train2014/COCO_train2014_000000267555.jpg
#  extracting: coco/train2014/COCO_train2014_000000058511.jpg
#  extracting: coco/train2014/COCO_train2014_000000137203.jpg
#  extracting: coco/train2014/COCO_train2014_000000454538.jpg
#  extracting: coco/train2014/COCO_train2014_000000056485.jpg
#  extracting: coco/train2014/COCO_train2014_000000174229.jpg
#  extracting: coco/train2014/COCO_train2014_000000399200.jpg
#  extracting: coco/train2014/COCO_train2014_000000224390.jpg
#  extracting: coco/train2014/COCO_train2014_000000369793.jpg
#  extracting: coco/train2014/COCO_train2014_000000565932.jpg
#  extracting: coco/train2014/COCO_train2014_000000105332.jpg
#  extracting: coco/train2014/COCO_train2014_000000147054.jpg
#  extracting: coco/train2014/COCO_train2014_000000388149.jpg
#  extracting: coco/train2014/COCO_train2014_000000523834.jpg
#  extracting: coco/train2014/COCO_train2014_000000203336.jpg
#  extracting: coco/train2014/COCO_train2014_000000252518.jpg
#  extracting: coco/train2014/COCO_train2014_000000289689.jpg
#  extracting: coco/train2014/COCO_train2014_000000118534.jpg
#  extracting: coco/train2014/COCO_train2014_000000097210.jpg
#  extracting: coco/train2014/COCO_train2014_000000380928.jpg
#  extracting: coco/train2014/COCO_train2014_000000527207.jpg
#  extracting: coco/train2014/COCO_train2014_000000445500.jpg
#  extracting: coco/train2014/COCO_train2014_000000014966.jpg
#  extracting: coco/train2014/COCO_train2014_000000364476.jpg
#  extracting: coco/train2014/COCO_train2014_000000314481.jpg
#  extracting: coco/train2014/COCO_train2014_000000503227.jpg
#  extracting: coco/train2014/COCO_train2014_000000183882.jpg
#  extracting: coco/train2014/COCO_train2014_000000167712.jpg
#  extracting: coco/train2014/COCO_train2014_000000150932.jpg
#  extracting: coco/train2014/COCO_train2014_000000421557.jpg
#  extracting: coco/train2014/COCO_train2014_000000459451.jpg
#  extracting: coco/train2014/COCO_train2014_000000085483.jpg
#  extracting: coco/train2014/COCO_train2014_000000328812.jpg
#  extracting: coco/train2014/COCO_train2014_000000538821.jpg
#  extracting: coco/train2014/COCO_train2014_000000182758.jpg
#  extracting: coco/train2014/COCO_train2014_000000168422.jpg
#  extracting: coco/train2014/COCO_train2014_000000572801.jpg
#  extracting: coco/train2014/COCO_train2014_000000457344.jpg
#  extracting: coco/train2014/COCO_train2014_000000225127.jpg
#  extracting: coco/train2014/COCO_train2014_000000234713.jpg
#  extracting: coco/train2014/COCO_train2014_000000344456.jpg
#  extracting: coco/train2014/COCO_train2014_000000358921.jpg
#  extracting: coco/train2014/COCO_train2014_000000449316.jpg
#  extracting: coco/train2014/COCO_train2014_000000451832.jpg
#  extracting: coco/train2014/COCO_train2014_000000206083.jpg
#  extracting: coco/train2014/COCO_train2014_000000034340.jpg
#  extracting: coco/train2014/COCO_train2014_000000134320.jpg
#  extracting: coco/train2014/COCO_train2014_000000431168.jpg
#  extracting: coco/train2014/COCO_train2014_000000483639.jpg
#  extracting: coco/train2014/COCO_train2014_000000300514.jpg
#  extracting: coco/train2014/COCO_train2014_000000293529.jpg
#  extracting: coco/train2014/COCO_train2014_000000470172.jpg
#  extracting: coco/train2014/COCO_train2014_000000171449.jpg
#  extracting: coco/train2014/COCO_train2014_000000027267.jpg
#  extracting: coco/train2014/COCO_train2014_000000100253.jpg
#  extracting: coco/train2014/COCO_train2014_000000275046.jpg
#  extracting: coco/train2014/COCO_train2014_000000439871.jpg
#  extracting: coco/train2014/COCO_train2014_000000451133.jpg
#  extracting: coco/train2014/COCO_train2014_000000089770.jpg
#  extracting: coco/train2014/COCO_train2014_000000228855.jpg
#  extracting: coco/train2014/COCO_train2014_000000089208.jpg
#  extracting: coco/train2014/COCO_train2014_000000537371.jpg
#  extracting: coco/train2014/COCO_train2014_000000358088.jpg
#  extracting: coco/train2014/COCO_train2014_000000067057.jpg
#  extracting: coco/train2014/COCO_train2014_000000447773.jpg
#  extracting: coco/train2014/COCO_train2014_000000035382.jpg
#  extracting: coco/train2014/COCO_train2014_000000333424.jpg
#  extracting: coco/train2014/COCO_train2014_000000009935.jpg
#  extracting: coco/train2014/COCO_train2014_000000573482.jpg
#  extracting: coco/train2014/COCO_train2014_000000192221.jpg
#  extracting: coco/train2014/COCO_train2014_000000256386.jpg
#  extracting: coco/train2014/COCO_train2014_000000197057.jpg
#  extracting: coco/train2014/COCO_train2014_000000289739.jpg
#  extracting: coco/train2014/COCO_train2014_000000252535.jpg
#  extracting: coco/train2014/COCO_train2014_000000210431.jpg
#  extracting: coco/train2014/COCO_train2014_000000179338.jpg
#  extracting: coco/train2014/COCO_train2014_000000227723.jpg
#  extracting: coco/train2014/COCO_train2014_000000062390.jpg
#  extracting: coco/train2014/COCO_train2014_000000475457.jpg
#  extracting: coco/train2014/COCO_train2014_000000149634.jpg
#  extracting: coco/train2014/COCO_train2014_000000315719.jpg
#  extracting: coco/train2014/COCO_train2014_000000053604.jpg
#  extracting: coco/train2014/COCO_train2014_000000519431.jpg
#  extracting: coco/train2014/COCO_train2014_000000320353.jpg
#  extracting: coco/train2014/COCO_train2014_000000026784.jpg
#  extracting: coco/train2014/COCO_train2014_000000037169.jpg
#  extracting: coco/train2014/COCO_train2014_000000265052.jpg
#  extracting: coco/train2014/COCO_train2014_000000485902.jpg
#  extracting: coco/train2014/COCO_train2014_000000061326.jpg
#  extracting: coco/train2014/COCO_train2014_000000177947.jpg
#  extracting: coco/train2014/COCO_train2014_000000399585.jpg
#  extracting: coco/train2014/COCO_train2014_000000216954.jpg
#  extracting: coco/train2014/COCO_train2014_000000113334.jpg
#  extracting: coco/train2014/COCO_train2014_000000376912.jpg
#  extracting: coco/train2014/COCO_train2014_000000063890.jpg
#  extracting: coco/train2014/COCO_train2014_000000496776.jpg
#  extracting: coco/train2014/COCO_train2014_000000027901.jpg
#  extracting: coco/train2014/COCO_train2014_000000063163.jpg
#  extracting: coco/train2014/COCO_train2014_000000383902.jpg
#  extracting: coco/train2014/COCO_train2014_000000414891.jpg
#  extracting: coco/train2014/COCO_train2014_000000274605.jpg
#  extracting: coco/train2014/COCO_train2014_000000233111.jpg
#  extracting: coco/train2014/COCO_train2014_000000478142.jpg
#  extracting: coco/train2014/COCO_train2014_000000292351.jpg
#  extracting: coco/train2014/COCO_train2014_000000148924.jpg
#  extracting: coco/train2014/COCO_train2014_000000537617.jpg
#  extracting: coco/train2014/COCO_train2014_000000406171.jpg
#  extracting: coco/train2014/COCO_train2014_000000366688.jpg
#  extracting: coco/train2014/COCO_train2014_000000168741.jpg
#  extracting: coco/train2014/COCO_train2014_000000430531.jpg
#  extracting: coco/train2014/COCO_train2014_000000333378.jpg
#  extracting: coco/train2014/COCO_train2014_000000352176.jpg
#  extracting: coco/train2014/COCO_train2014_000000530701.jpg
#  extracting: coco/train2014/COCO_train2014_000000113418.jpg
#  extracting: coco/train2014/COCO_train2014_000000418113.jpg
#  extracting: coco/train2014/COCO_train2014_000000358678.jpg
#  extracting: coco/train2014/COCO_train2014_000000027395.jpg
#  extracting: coco/train2014/COCO_train2014_000000088339.jpg
#  extracting: coco/train2014/COCO_train2014_000000121613.jpg
#  extracting: coco/train2014/COCO_train2014_000000433941.jpg
#  extracting: coco/train2014/COCO_train2014_000000355968.jpg
#  extracting: coco/train2014/COCO_train2014_000000109862.jpg
#  extracting: coco/train2014/COCO_train2014_000000339491.jpg
#  extracting: coco/train2014/COCO_train2014_000000129007.jpg
#  extracting: coco/train2014/COCO_train2014_000000196899.jpg
#  extracting: coco/train2014/COCO_train2014_000000038277.jpg
#  extracting: coco/train2014/COCO_train2014_000000268111.jpg
#  extracting: coco/train2014/COCO_train2014_000000158233.jpg
#  extracting: coco/train2014/COCO_train2014_000000155794.jpg
#  extracting: coco/train2014/COCO_train2014_000000072382.jpg
#  extracting: coco/train2014/COCO_train2014_000000289690.jpg
#  extracting: coco/train2014/COCO_train2014_000000280770.jpg
#  extracting: coco/train2014/COCO_train2014_000000371808.jpg
#  extracting: coco/train2014/COCO_train2014_000000524946.jpg
#  extracting: coco/train2014/COCO_train2014_000000230014.jpg
#  extracting: coco/train2014/COCO_train2014_000000409194.jpg
#  extracting: coco/train2014/COCO_train2014_000000528654.jpg
#  extracting: coco/train2014/COCO_train2014_000000390956.jpg
#  extracting: coco/train2014/COCO_train2014_000000281021.jpg
#  extracting: coco/train2014/COCO_train2014_000000148263.jpg
#  extracting: coco/train2014/COCO_train2014_000000086329.jpg
#  extracting: coco/train2014/COCO_train2014_000000262935.jpg
#  extracting: coco/train2014/COCO_train2014_000000388962.jpg
#  extracting: coco/train2014/COCO_train2014_000000162861.jpg
#  extracting: coco/train2014/COCO_train2014_000000571168.jpg
#  extracting: coco/train2014/COCO_train2014_000000456262.jpg
#  extracting: coco/train2014/COCO_train2014_000000367063.jpg
#  extracting: coco/train2014/COCO_train2014_000000140204.jpg
#  extracting: coco/train2014/COCO_train2014_000000259029.jpg
#  extracting: coco/train2014/COCO_train2014_000000549209.jpg
#  extracting: coco/train2014/COCO_train2014_000000459618.jpg
# ...
#  extracting: coco/train2014/COCO_train2014_000000367523.jpg
#  extracting: coco/train2014/COCO_train2014_000000236389.jpg
#  extracting: coco/train2014/COCO_train2014_000000405897.jpg
#  extracting: coco/train2014/COCO_train2014_000000112358.jpg
#  extracting: coco/train2014/COCO_train2014_000000349750.jpg
#  extracting: coco/train2014/COCO_train2014_000000541957.jpg
#  extracting: coco/train2014/COCO_train2014_000000266696.jpg
#  extracting: coco/train2014/COCO_train2014_000000491084.jpg
#  extracting: coco/train2014/COCO_train2014_000000466714.jpg
#  extracting: coco/train2014/COCO_train2014_000000447016.jpg
#  extracting: coco/train2014/COCO_train2014_000000442473.jpg
#  extracting: coco/train2014/COCO_train2014_000000184908.jpg
#  extracting: coco/train2014/COCO_train2014_000000516570.jpg
#  extracting: coco/train2014/COCO_train2014_000000203054.jpg
#  extracting: coco/train2014/COCO_train2014_000000382643.jpg
#  extracting: coco/train2014/COCO_train2014_000000154614.jpg
#  extracting: coco/train2014/COCO_train2014_000000465507.jpg
#  extracting: coco/train2014/COCO_train2014_000000236425.jpg
#  extracting: coco/train2014/COCO_train2014_000000373099.jpg
#  extracting: coco/train2014/COCO_train2014_000000270873.jpg
#  extracting: coco/train2014/COCO_train2014_000000394115.jpg
#  extracting: coco/train2014/COCO_train2014_000000522362.jpg
#  extracting: coco/train2014/COCO_train2014_000000125116.jpg
#  extracting: coco/train2014/COCO_train2014_000000362654.jpg
#  extracting: coco/train2014/COCO_train2014_000000161051.jpg
#  extracting: coco/train2014/COCO_train2014_000000348180.jpg
#  extracting: coco/train2014/COCO_train2014_000000377011.jpg
#  extracting: coco/train2014/COCO_train2014_000000328113.jpg
#  extracting: coco/train2014/COCO_train2014_000000514556.jpg
#  extracting: coco/train2014/COCO_train2014_000000181344.jpg
#  extracting: coco/train2014/COCO_train2014_000000005459.jpg
#  extracting: coco/train2014/COCO_train2014_000000238187.jpg
#  extracting: coco/train2014/COCO_train2014_000000449103.jpg
#  extracting: coco/train2014/COCO_train2014_000000019146.jpg
#  extracting: coco/train2014/COCO_train2014_000000580345.jpg
#  extracting: coco/train2014/COCO_train2014_000000420308.jpg
#  extracting: coco/train2014/COCO_train2014_000000285639.jpg
#  extracting: coco/train2014/COCO_train2014_000000290952.jpg
#  extracting: coco/train2014/COCO_train2014_000000325935.jpg
#  extracting: coco/train2014/COCO_train2014_000000037076.jpg
#  extracting: coco/train2014/COCO_train2014_000000359147.jpg
#  extracting: coco/train2014/COCO_train2014_000000460030.jpg
#  extracting: coco/train2014/COCO_train2014_000000191754.jpg
#  extracting: coco/train2014/COCO_train2014_000000514060.jpg
#  extracting: coco/train2014/COCO_train2014_000000473955.jpg
#  extracting: coco/train2014/COCO_train2014_000000190554.jpg
#  extracting: coco/train2014/COCO_train2014_000000261702.jpg
#  extracting: coco/train2014/COCO_train2014_000000576850.jpg
#  extracting: coco/train2014/COCO_train2014_000000327702.jpg
#  extracting: coco/train2014/COCO_train2014_000000187037.jpg
#  extracting: coco/train2014/COCO_train2014_000000136651.jpg
#  extracting: coco/train2014/COCO_train2014_000000062053.jpg
#  extracting: coco/train2014/COCO_train2014_000000183329.jpg
#  extracting: coco/train2014/COCO_train2014_000000017171.jpg
#  extracting: coco/train2014/COCO_train2014_000000535160.jpg
#  extracting: coco/train2014/COCO_train2014_000000564475.jpg
#  extracting: coco/train2014/COCO_train2014_000000265361.jpg
#  extracting: coco/train2014/COCO_train2014_000000272297.jpg
#  extracting: coco/train2014/COCO_train2014_000000305450.jpg
#  extracting: coco/train2014/COCO_train2014_000000118851.jpg
#  extracting: coco/train2014/COCO_train2014_000000483241.jpg
#  extracting: coco/train2014/COCO_train2014_000000420425.jpg
#  extracting: coco/train2014/COCO_train2014_000000219445.jpg
#  extracting: coco/train2014/COCO_train2014_000000234424.jpg
#  extracting: coco/train2014/COCO_train2014_000000021095.jpg
#  extracting: coco/train2014/COCO_train2014_000000384844.jpg
#  extracting: coco/train2014/COCO_train2014_000000122923.jpg
#  extracting: coco/train2014/COCO_train2014_000000166522.jpg
#  extracting: coco/train2014/COCO_train2014_000000013482.jpg
#  extracting: coco/train2014/COCO_train2014_000000249688.jpg
#  extracting: coco/train2014/COCO_train2014_000000010015.jpg
#  extracting: coco/train2014/COCO_train2014_000000107011.jpg
#  extracting: coco/train2014/COCO_train2014_000000166657.jpg
#  extracting: coco/train2014/COCO_train2014_000000367809.jpg
#  extracting: coco/train2014/COCO_train2014_000000024380.jpg
#  extracting: coco/train2014/COCO_train2014_000000012421.jpg
#  extracting: coco/train2014/COCO_train2014_000000240685.jpg
#  extracting: coco/train2014/COCO_train2014_000000324349.jpg
#  extracting: coco/train2014/COCO_train2014_000000444566.jpg
#  extracting: coco/train2014/COCO_train2014_000000255486.jpg
#  extracting: coco/train2014/COCO_train2014_000000381667.jpg
#  extracting: coco/train2014/COCO_train2014_000000538116.jpg
#  extracting: coco/train2014/COCO_train2014_000000328381.jpg
#  extracting: coco/train2014/COCO_train2014_000000014844.jpg
#  extracting: coco/train2014/COCO_train2014_000000578663.jpg
#  extracting: coco/train2014/COCO_train2014_000000107691.jpg
#  extracting: coco/train2014/COCO_train2014_000000426143.jpg
#  extracting: coco/train2014/COCO_train2014_000000444945.jpg
#  extracting: coco/train2014/COCO_train2014_000000337883.jpg
#  extracting: coco/train2014/COCO_train2014_000000024289.jpg
#  extracting: coco/train2014/COCO_train2014_000000092553.jpg
#  extracting: coco/train2014/COCO_train2014_000000041311.jpg
#  extracting: coco/train2014/COCO_train2014_000000166998.jpg
#  extracting: coco/train2014/COCO_train2014_000000044702.jpg
#  extracting: coco/train2014/COCO_train2014_000000355236.jpg
#  extracting: coco/train2014/COCO_train2014_000000015843.jpg
#  extracting: coco/train2014/COCO_train2014_000000397205.jpg
#  extracting: coco/train2014/COCO_train2014_000000038375.jpg
#  extracting: coco/train2014/COCO_train2014_000000128215.jpg
#  extracting: coco/train2014/COCO_train2014_000000250424.jpg
#  extracting: coco/train2014/COCO_train2014_000000328242.jpg
#  extracting: coco/train2014/COCO_train2014_000000313481.jpg
#  extracting: coco/train2014/COCO_train2014_000000337448.jpg
#  extracting: coco/train2014/COCO_train2014_000000398936.jpg
#  extracting: coco/train2014/COCO_train2014_000000320911.jpg
#  extracting: coco/train2014/COCO_train2014_000000464237.jpg
#  extracting: coco/train2014/COCO_train2014_000000172040.jpg
#  extracting: coco/train2014/COCO_train2014_000000313556.jpg
#  extracting: coco/train2014/COCO_train2014_000000130598.jpg
#  extracting: coco/train2014/COCO_train2014_000000346562.jpg
#  extracting: coco/train2014/COCO_train2014_000000455601.jpg
#  extracting: coco/train2014/COCO_train2014_000000379136.jpg
#  extracting: coco/train2014/COCO_train2014_000000567836.jpg
#  extracting: coco/train2014/COCO_train2014_000000234536.jpg
#  extracting: coco/train2014/COCO_train2014_000000278549.jpg
#  extracting: coco/train2014/COCO_train2014_000000426988.jpg
#  extracting: coco/train2014/COCO_train2014_000000055534.jpg
#  extracting: coco/train2014/COCO_train2014_000000372213.jpg
#  extracting: coco/train2014/COCO_train2014_000000402120.jpg
#  extracting: coco/train2014/COCO_train2014_000000518355.jpg
#  extracting: coco/train2014/COCO_train2014_000000037868.jpg
#  extracting: coco/train2014/COCO_train2014_000000012696.jpg
#  extracting: coco/train2014/COCO_train2014_000000083875.jpg
#  extracting: coco/train2014/COCO_train2014_000000174623.jpg
#  extracting: coco/train2014/COCO_train2014_000000039531.jpg
#  extracting: coco/train2014/COCO_train2014_000000523468.jpg
#  extracting: coco/train2014/COCO_train2014_000000062715.jpg
#  extracting: coco/train2014/COCO_train2014_000000548662.jpg
#  extracting: coco/train2014/COCO_train2014_000000549626.jpg
#  extracting: coco/train2014/COCO_train2014_000000416119.jpg
#  extracting: coco/train2014/COCO_train2014_000000384643.jpg
#  extracting: coco/train2014/COCO_train2014_000000392167.jpg
#  extracting: coco/train2014/COCO_train2014_000000055493.jpg
#  extracting: coco/train2014/COCO_train2014_000000560754.jpg
#  extracting: coco/train2014/COCO_train2014_000000491277.jpg
#  extracting: coco/train2014/COCO_train2014_000000389088.jpg
#  extracting: coco/train2014/COCO_train2014_000000407926.jpg
#  extracting: coco/train2014/COCO_train2014_000000380115.jpg
#  extracting: coco/train2014/COCO_train2014_000000329892.jpg
#  extracting: coco/train2014/COCO_train2014_000000206530.jpg
#  extracting: coco/train2014/COCO_train2014_000000518075.jpg
#  extracting: coco/train2014/COCO_train2014_000000041475.jpg
#  extracting: coco/train2014/COCO_train2014_000000138370.jpg
#  extracting: coco/train2014/COCO_train2014_000000087871.jpg
#  extracting: coco/train2014/COCO_train2014_000000171126.jpg
#  extracting: coco/train2014/COCO_train2014_000000499920.jpg
#  extracting: coco/train2014/COCO_train2014_000000385075.jpg
#  extracting: coco/train2014/COCO_train2014_000000100535.jpg
#  extracting: coco/train2014/COCO_train2014_000000212359.jpg
#  extracting: coco/train2014/COCO_train2014_000000113598.jpg
#  extracting: coco/train2014/COCO_train2014_000000004377.jpg
#  extracting: coco/train2014/COCO_train2014_000000546695.jpg
#  extracting: coco/train2014/COCO_train2014_000000498409.jpg
#  extracting: coco/train2014/COCO_train2014_000000402174.jpg
#  extracting: coco/train2014/COCO_train2014_000000400443.jpg
#  extracting: coco/train2014/COCO_train2014_000000139945.jpg
#  extracting: coco/train2014/COCO_train2014_000000190530.jpg
#  extracting: coco/train2014/COCO_train2014_000000324339.jpg
#  extracting: coco/train2014/COCO_train2014_000000168453.jpg
#  extracting: coco/train2014/COCO_train2014_000000271870.jpg
#  extracting: coco/train2014/COCO_train2014_000000556001.jpg
#  extracting: coco/train2014/COCO_train2014_000000311476.jpg
#  extracting: coco/train2014/COCO_train2014_000000139109.jpg
#  extracting: coco/train2014/COCO_train2014_000000184518.jpg
#  extracting: coco/train2014/COCO_train2014_000000399687.jpg
#  extracting: coco/train2014/COCO_train2014_000000330426.jpg
#  extracting: coco/train2014/COCO_train2014_000000379558.jpg
#  extracting: coco/train2014/COCO_train2014_000000532583.jpg
#  extracting: coco/train2014/COCO_train2014_000000026635.jpg
#  extracting: coco/train2014/COCO_train2014_000000380715.jpg
#  extracting: coco/train2014/COCO_train2014_000000373148.jpg
#  extracting: coco/train2014/COCO_train2014_000000274170.jpg
#  extracting: coco/train2014/COCO_train2014_000000187025.jpg
#  extracting: coco/train2014/COCO_train2014_000000049363.jpg
#  extracting: coco/train2014/COCO_train2014_000000344669.jpg
#  extracting: coco/train2014/COCO_train2014_000000476874.jpg
#  extracting: coco/train2014/COCO_train2014_000000230129.jpg
#  extracting: coco/train2014/COCO_train2014_000000305170.jpg
#  extracting: coco/train2014/COCO_train2014_000000419798.jpg
#  extracting: coco/train2014/COCO_train2014_000000452005.jpg
#  extracting: coco/train2014/COCO_train2014_000000089838.jpg
#  extracting: coco/train2014/COCO_train2014_000000055607.jpg
#  extracting: coco/train2014/COCO_train2014_000000447130.jpg
#  extracting: coco/train2014/COCO_train2014_000000100777.jpg
#  extracting: coco/train2014/COCO_train2014_000000287105.jpg
#  extracting: coco/train2014/COCO_train2014_000000125063.jpg
#  extracting: coco/train2014/COCO_train2014_000000270379.jpg
#  extracting: coco/train2014/COCO_train2014_000000116006.jpg
#  extracting: coco/train2014/COCO_train2014_000000552472.jpg
#  extracting: coco/train2014/COCO_train2014_000000540864.jpg
#  extracting: coco/train2014/COCO_train2014_000000556855.jpg
#  extracting: coco/train2014/COCO_train2014_000000398540.jpg
#  extracting: coco/train2014/COCO_train2014_000000287324.jpg
#  extracting: coco/train2014/COCO_train2014_000000493187.jpg
#  extracting: coco/train2014/COCO_train2014_000000226555.jpg
#  extracting: coco/train2014/COCO_train2014_000000197584.jpg
#  extracting: coco/train2014/COCO_train2014_000000411505.jpg
#  extracting: coco/train2014/COCO_train2014_000000086927.jpg
#  extracting: coco/train2014/COCO_train2014_000000351852.jpg
#  extracting: coco/train2014/COCO_train2014_000000248979.jpg
#  extracting: coco/train2014/COCO_train2014_000000414047.jpg
#  extracting: coco/train2014/COCO_train2014_000000379448.jpg
#  extracting: coco/train2014/COCO_train2014_000000104248.jpg
#  extracting: coco/train2014/COCO_train2014_000000216413.jpg
#  extracting: coco/train2014/COCO_train2014_000000493618.jpg
#  extracting: coco/train2014/COCO_train2014_000000241325.jpg
#  extracting: coco/train2014/COCO_train2014_000000138782.jpg
#  extracting: coco/train2014/COCO_train2014_000000499985.jpg
#  extracting: coco/train2014/COCO_train2014_000000356064.jpg
#  extracting: coco/train2014/COCO_train2014_000000443650.jpg
#  extracting: coco/train2014/COCO_train2014_000000021968.jpg
#  extracting: coco/train2014/COCO_train2014_000000304587.jpg
#  extracting: coco/train2014/COCO_train2014_000000132778.jpg
#  extracting: coco/train2014/COCO_train2014_000000136346.jpg
#  extracting: coco/train2014/COCO_train2014_000000345585.jpg
#  extracting: coco/train2014/COCO_train2014_000000485465.jpg
#  extracting: coco/train2014/COCO_train2014_000000041461.jpg
#  extracting: coco/train2014/COCO_train2014_000000166592.jpg
#  extracting: coco/train2014/COCO_train2014_000000419406.jpg
#  extracting: coco/train2014/COCO_train2014_000000125305.jpg
#  extracting: coco/train2014/COCO_train2014_000000322892.jpg
#  extracting: coco/train2014/COCO_train2014_000000578154.jpg
#  extracting: coco/train2014/COCO_train2014_000000189520.jpg
#  extracting: coco/train2014/COCO_train2014_000000524773.jpg
#  extracting: coco/train2014/COCO_train2014_000000104559.jpg
#  extracting: coco/train2014/COCO_train2014_000000110423.jpg
#  extracting: coco/train2014/COCO_train2014_000000383446.jpg
#  extracting: coco/train2014/COCO_train2014_000000161436.jpg
#  extracting: coco/train2014/COCO_train2014_000000090006.jpg
#  extracting: coco/train2014/COCO_train2014_000000061072.jpg
#  extracting: coco/train2014/COCO_train2014_000000381256.jpg
#  extracting: coco/train2014/COCO_train2014_000000008458.jpg
#  extracting: coco/train2014/COCO_train2014_000000375027.jpg
#  extracting: coco/train2014/COCO_train2014_000000073339.jpg
#  extracting: coco/train2014/COCO_train2014_000000564020.jpg
#  extracting: coco/train2014/COCO_train2014_000000175057.jpg
#  extracting: coco/train2014/COCO_train2014_000000328246.jpg
#  extracting: coco/train2014/COCO_train2014_000000298657.jpg
#  extracting: coco/train2014/COCO_train2014_000000219869.jpg
#  extracting: coco/train2014/COCO_train2014_000000025162.jpg
#  extracting: coco/train2014/COCO_train2014_000000341052.jpg
#  extracting: coco/train2014/COCO_train2014_000000093789.jpg
#  extracting: coco/train2014/COCO_train2014_000000254701.jpg
#  extracting: coco/train2014/COCO_train2014_000000177349.jpg
#  extracting: coco/train2014/COCO_train2014_000000283267.jpg
#  extracting: coco/train2014/COCO_train2014_000000334463.jpg
#  extracting: coco/train2014/COCO_train2014_000000500946.jpg
#  extracting: coco/train2014/COCO_train2014_000000000531.jpg
#  extracting: coco/train2014/COCO_train2014_000000291366.jpg
#  extracting: coco/train2014/COCO_train2014_000000533055.jpg
#  extracting: coco/train2014/COCO_train2014_000000467840.jpg
# Archive:  annotations_trainval2014.zip
#   inflating: coco/annotations/instances_train2014.json
#   inflating: coco/annotations/instances_val2014.json
#   inflating: coco/annotations/person_keypoints_train2014.json
#   inflating: coco/annotations/person_keypoints_val2014.json
#   inflating: coco/annotations/captions_train2014.json
#   inflating: coco/annotations/captions_val2014.json

# %% [markdown]
# # Image Captioning
#
# **Author:** [A_K_Nain](https://twitter.com/A_K_Nain)<br>
# **Date created:** 2021/05/29<br>
# **Last modified:** 2021/10/31<br>
# **Description:** Implement an image captioning model using a CNN and a Transformer.

# %%
import pandas as pd
import os
import json


class DatasetLoader:

    def __init__(self, folder_name: str = "coco"):
        self.data = self.load_data(folder_name)

    def load_data(self, folder_name: str = "coco"):
        print("Loading data..")
        # Set the data folder
        data_folder = os.path.join(folder_name)

        # Create the directory if it doesn't exist
        if not os.path.exists(data_folder):
            os.makedirs(data_folder)

        # Path to the captions JSON file
        filename = os.path.join(data_folder, "annotations", "captions_train2014.json")

        # Read and parse the JSON file
        with open(filename, "r") as json_file:
            data = json.load(json_file)

        print("Data loaded succesfully!")

        return data

    def get_data_dict(self):
        return self.data

    def get_df_annotations(self):
        return pd.DataFrame(self.data["annotations"])

    def get_df_images(self):
        return pd.DataFrame(self.data["images"])

# %% [markdown]
# ## Setup

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers
from keras.applications import efficientnet
from keras.layers import TextVectorization

keras.utils.set_random_seed(111)

# %% [markdown]
# ## Download the dataset
#
# We will be using the Flickr8K dataset for this tutorial. This dataset comprises over
# 8,000 images, that are each paired with five different captions.

# %%
# Desired image dimensions
IMAGE_SIZE = (299, 299)

# Vocabulary size
VOCAB_SIZE = 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 25

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 256
EPOCHS = 15
AUTOTUNE = tf.data.AUTOTUNE

# %%
EPOCHS = 15

# %% [markdown]
# ## Preparing the dataset

# %%
import json
import os
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.xception import preprocess_input
# from fdl_project.classes.dataset_loader import DatasetLoader

# Load the dataset
dataset = DatasetLoader().load_data(folder_name=os.path.join(os.getcwd(), "coco"))
# Out:
# Loading data..
# Data loaded succesfully!
# Loading data..
# Data loaded succesfully!

# %%
def load_captions_data(dataset):
    text_annotations = []

    # Create a mapping from image_id to file_name
    image_id_to_file_name = {image["id"]: image["file_name"] for image in dataset["images"]}

    # Create a mapping from image_id to captions
    image_id_to_captions = {}
    for annotation in dataset["annotations"]:
        image_id = annotation["image_id"]
        caption = "<start> " + annotation["caption"] + " <end>"

        if image_id not in image_id_to_captions:
            image_id_to_captions[image_id] = []

        image_id_to_captions[image_id].append(caption)
        text_annotations.append(caption)

    # Create a combined dictionary with image file names and their corresponding captions
    file_name_to_captions = {
        image_id_to_file_name[image_id]: captions
        for image_id, captions in image_id_to_captions.items()
    }

    return file_name_to_captions, text_annotations


def train_val_split(caption_data, train_size=0.8, shuffle=True):
    """Split the captioning dataset into train and validation sets.

    Args:
        caption_data (dict): Dictionary containing the mapped caption data
        train_size (float): Fraction of all the full dataset to use as training data
        shuffle (bool): Whether to shuffle the dataset before splitting

    Returns:
        Traning and validation datasets as two separated dicts
    """

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    # 4. Return the splits
    return training_data, validation_data

# Load the dataset
captions_mapping, text_data = load_captions_data(dataset)

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  66226
# Number of validation samples:  16557

# %%
captions_mapping
# Out:
# {'COCO_train2014_000000318556.jpg': ['<start> A very clean and well decorated empty bathroom <end>',
#   '<start> A blue and white bathroom with butterfly themed wall tiles. <end>',
#   '<start> A bathroom with a border of butterflies and blue paint on the walls above it. <end>',
#   '<start> An angled view of a beautifully decorated bathroom. <end>',
#   '<start> A clock that blends in with the wall hangs in a bathroom.  <end>'],
#  'COCO_train2014_000000116100.jpg': ['<start> A panoramic view of a kitchen and all of its appliances. <end>',
#   '<start> A panoramic photo of a kitchen and dining room <end>',
#   '<start> A wide angle view of the kitchen work area <end>',
#   '<start> multiple photos of a brown and white kitchen.  <end>',
#   '<start> A kitchen that has a checkered patterned floor and white cabinets. <end>'],
#  'COCO_train2014_000000379340.jpg': ['<start> A graffiti-ed stop sign across the street from a red car  <end>',
#   '<start> A vandalized stop sign and a red beetle on the road <end>',
#   '<start> A red stop sign with a Bush bumper sticker under the word stop. <end>',
#   '<start> A stop sign that has been vandalized is pictured in front of a parked car. <end>',
#   '<start> A street sign modified to read stop bush. <end>'],
#  'COCO_train2014_000000134754.jpg': ['<start> The two people are walking down the beach. <end>',
#   '<start> Two people carrying surf boards on a beach. <end>',
#   '<start> Two teenagers at a white sanded beach with surfboards. <end>',
#   '<start> A couple at the beach walking with their surf boards. <end>',
#   '<start> A guy and a girl are walking on the beach holding surfboards. <end>'],
#  'COCO_train2014_000000538480.jpg': ['<start> A sink and a toilet inside a small bathroom. <end>',
#   '<start> White pedestal sink and toilet located in a poorly lit bathroom. <end>',
#   '<start> Clean indoor bathroom with tiled floor and good lighting. <end>',
#   '<start> a bathroom with toilet and sink and blue wall <end>',
#   '<start> a blue bathroom with a sink and toilet <end>'],
#  'COCO_train2014_000000476220.jpg': ['<start> An empty kitchen with white and black appliances. <end>',
#   '<start> A refrigerator and stove are in a small kitchen area.  <end>',
#   '<start> Small kitchen in a personal home with dual sinks. <end>',
#   '<start> A small kitchen with sink, stove and refrigerator. <end>',
#   '<start> A small kitchen with several appliances and cookware. <end>'],
#  'COCO_train2014_000000299675.jpg': ['<start> A white square kitchen with tile floor that needs repairs  <end>',
#   '<start> A white kitchen in a home with the light on. <end>',
#   '<start> A kitchen with a tile floor has cabinets with no doors, a dishwasher, a sink, and a refrigerator. <end>',
#   '<start> A white kitchen without doors on the cabinets. <end>',
#   '<start> A white kitchen filled with pots, pans and dishes. <end>'],
#  'COCO_train2014_000000032275.jpg': ['<start> The vanity contains two sinks with a towel for each. <end>',
#   '<start> A clean restroom with towels and washcloths laid out. <end>',
#   '<start> The bathroom counter is stocked with towels and supplies. <end>',
#   '<start> There is a clean bathroom counter and sink. <end>',
#   '<start> A hotel bathroom with stone counter and mirror <end>'],
#  'COCO_train2014_000000302443.jpg': ['<start> Several metal balls sit in the sand near a group of people. <end>',
#   '<start> People standing around many silver round balls on the ground. <end>',
#   '<start> Silver balls are lined up in the sand as people mill about in the background. <end>',
#   '<start> Silver balls on sand with people walking around.  <end>',
#   '<start> silver balls laying on the ground around a smaller red ball.  <end>'],
#  'COCO_train2014_000000025470.jpg': ['<start> A kitchen with brown cabinets, tile backsplash, and grey counters. <end>',
#   '<start> A kitchen contains black countertops, brown cabinets, and a red and white tile blacksplash. <end>',
#   '<start> A clean, organized, kitchen cabinet and countertop area. <end>',
#   '<start> A kitchen has red bricks lining the counter. <end>',
#   '<start> A kitchen with wood cabinets and granite counter tops. <end>'],
#  'COCO_train2014_000000513461.jpg': ['<start> A surfer, a woman, and a child walk on the beach. <end>',
#   '<start> A person holding a surf board on a beach.  <end>',
#   '<start> A family standing next to the ocean on a sandy beach with a surf board. <end>',
#   '<start> A man getting ready to surf as lookers walk by <end>',
#   '<start> A family carrying a surfboard to the ocean. <end>'],
#  'COCO_train2014_000000018691.jpg': ['<start> A few people sit on a dim transportation system.  <end>',
#   '<start> six people on a bus at night time <end>',
#   '<start> random people sitting in a public tranport bus. <end>',
#   '<start> There are only a few people in the bus. <end>',
#   '<start> A group of people are riding the bus. <end>'],
#  'COCO_train2014_000000285579.jpg': ['<start> A person, protected from the rain by their umbrella, walks down the road. <end>',
#   '<start> A person walking outside in the rain with a green umbrella.  <end>',
#   '<start> A student walks in the rain with a green umbrella. <end>',
#   '<start> An individual covers himself under an umbrella on a rainy day. <end>',
#   '<start> A man walking in the rain crossing a street while holding an umbrella. <end>'],
#  'COCO_train2014_000000266366.jpg': ['<start> The bathroom with a toilet has an interesting sink. <end>',
#   '<start> A demonstration of a well maintained hotel bathroom <end>',
#   '<start> A clean, mediocre motel bathroom with a nice sink. <end>',
#   '<start> A modern hotel bathroom with accessories set out. <end>',
#   '<start> A bathroom with a toilet, sink, mirror and shower stall. <end>'],
#  'COCO_train2014_000000226658.jpg': ['<start> Two women preparing food in a kitchen, one at the sink and one at the table <end>',
#   '<start> A set table with silverware, glasses and a bottle of wine. <end>',
#   '<start> A woman having a slice of bread with jelly. <end>',
#   '<start> A woman sitting at a table with win and bread. <end>',
#   '<start> A women who is tearing off a piece of bread. <end>'],
#  'COCO_train2014_000000124567.jpg': ['<start> A cat stuck in a car with a slightly opened window. <end>',
#   '<start> A cat peeking out a car window that is rolled down <end>',
#   '<start> A cat standing on a car seat looking out the car window. <end>',
#   '<start> A person is taking a photo of a cat in a car. <end>',
#   '<start> A cat sitting on top of the passenger seat of a car. <end>'],
#  'COCO_train2014_000000293605.jpg': ['<start> Two bicycles and a woman walking in front of a shop <end>',
#   '<start> A woman walks by a couple of shop windows. <end>',
#   '<start> Woman walking down the street past a wig shop. <end>',
#   '<start> A storefront with two bicycles and a woman walking past. <end>',
#   '<start> A woman passing a store front wearing a long blue coat <end>'],
#  'COCO_train2014_000000321194.jpg': ['<start> Green tiled backsplash highlighted by low overhead lighting. <end>',
#   '<start> A kitchen counter is illuminated by a hood light <end>',
#   '<start> A kitchen sink next to an empty counter with a tiled wall. <end>',
#   '<start> A back splash is added to the wall in the kitchen. <end>',
#   '<start> A picture of a sink top with dim lighting. <end>'],
#  'COCO_train2014_000000479495.jpg': ['<start> A bicycle is parked by a bench at night. <end>',
#   '<start> A bike on the platform of a public transportation stop at night. <end>',
#   '<start> A bicycle leans on a bench at a subway stop. <end>',
#   '<start> A bicycle parked next to a bench in a train station. <end>',
#   '<start> A bike and a bench on the side of a street. <end>'],
#  'COCO_train2014_000000539984.jpg': ['<start> A brown horse is grazing grass near a red house. <end>',
#   '<start> A skinny horse is grazing in a field. <end>',
#   '<start> A large hours is eating grass in a field.  <end>',
#   '<start> A brown horse is grazing in the grass. <end>',
#   '<start> A brown horse grazes in an open field next to trees. <end>'],
#  'COCO_train2014_000000028231.jpg': ['<start> A black car is near someone riding a bike. <end>',
#   '<start> A person on a bicycle is riding in front of a car.   <end>',
#   '<start> A blurry bike rider zooms past a new Mercedes.  <end>',
#   '<start> A blurry bicycle riders goes by a black car. <end>',
#   '<start> A man rides a bike past a black car in a parking lot. <end>'],
#  'COCO_train2014_000000350235.jpg': ['<start> This is a pick-up game of shirts and skins basketball <end>',
#   '<start> A group of people playing a game of basketball. <end>',
#   '<start> a group of men standing around while one seems angry at the others.  <end>',
#   '<start> Several athletes appear to be having a disagreement. <end>',
#   '<start> A man attempts to separate men during a fight at a street basketball game. <end>'],
#  'COCO_train2014_000000314265.jpg': ['<start> A toilet, sink, bathtub with shower, mirror and cabinet\n <end>',
#   '<start> A small bathroom painted white with an empty shower. <end>',
#   '<start> White bathroom with glass shelves and wood sink. <end>',
#   '<start> A bathroom with an over the toilet cabinet.  <end>',
#   '<start> In the bathroom there is a shower, sink, and toilet. <end>'],
#  'COCO_train2014_000000389006.jpg': ['<start> A kitchen with a countertop that includes an Apple phone. <end>',
#   '<start> A phone and a computer on a kitchen counter. <end>',
#   '<start> A phone lies on the counter in a modern kitchen. <end>',
#   '<start> A nicely decorated kitchen with metallic refrigerator and blue counter. <end>',
#   '<start> A clean kitchen with a phone and laptop on the counter. <end>'],
#  'COCO_train2014_000000031813.jpg': ['<start> A surfer riding his bike to the beach. <end>',
#   '<start> a surfer rides his bike down the street <end>',
#   '<start> A man riding a bicycle on a road carrying a surf board. <end>',
#   '<start> A man on a bike carrying a surfboard under his arm. <end>',
#   '<start> A man rides a bike down the street while holding a surfboard.  <end>'],
#  'COCO_train2014_000000465049.jpg': ['<start> A closeup of a red fire hydrant including the chains. <end>',
#   '<start> A fire hydrant with chains is painted red. <end>',
#   '<start> A red fire hydrant wrapped in a red chain on a sidewalk. <end>',
#   '<start> The chain of a red fire hydrant is the focus. <end>',
#   '<start> A fire hydrant and the chain attached to it. <end>'],
#  'COCO_train2014_000000360334.jpg': ['<start> A man standing in the kitchen with his arms crossed <end>',
#   '<start> young man with folded arms standing in the kitchen  <end>',
#   '<start> A man standing in a white kitchen with his arms folded. <end>',
#   '<start> A man folds his arms in a kitchen. <end>',
#   '<start> Man standing in a kitchen with his arms crossed. <end>'],
#  'COCO_train2014_000000524679.jpg': ['<start> A purple bus and a man dressed as a nun on a tall bicycle. <end>',
#   '<start> Sister on her bike trying to race the bus. <end>',
#   '<start> A person riding a very high bike on the road. <end>',
#   '<start> A nun riding a very tallk bike next to a purple bus. <end>',
#   '<start> A woman in a nun costume is riding a bike next to a bus. <end>'],
#  'COCO_train2014_000000279672.jpg': ['<start> An herb that is in front of a toaster oven. <end>',
#   '<start> A vegetable in front of a toaster oven. <end>',
#   '<start> An evergreen sprig is sitting on top of an appliance. <end>',
#   '<start> A microwave is next to sage or some kind of spice. <end>',
#   '<start> This is a toaster with a green stem from a tree in front of it. <end>'],
#  'COCO_train2014_000000385716.jpg': ['<start> Lady carrying a purse walking along side a man. <end>',
#   '<start> A city sidewalk is lined with lamp posts <end>',
#   '<start> A man and a woman stand on the sidewalk lined with street lights. <end>',
#   '<start> A city sidewalk with storefronts on the right. <end>',
#   '<start> Two people leaving a building to walk down the street. <end>'],
#  'COCO_train2014_000000044816.jpg': ['<start> Clean bathroom that is brightly colored and has a window <end>',
#   '<start> A toilet sits next to a sink in a bathroom. <end>',
#   '<start> A pristine bathroom sits waiting to be used <end>',
#   '<start> An empty bathroom painted yellow with an open window. <end>',
#   '<start> This is a photo of a small hotel bathroom <end>'],
#  'COCO_train2014_000000360306.jpg': ['<start> A man working at a kitchen counter in a room illuminated by sunlight. <end>',
#   '<start> A man in shorts standing at the kitchen sink. <end>',
#   '<start> A man is washing dishes in the kitchen sink. <end>',
#   '<start> A man standing in a kitchen with a baby and dog. <end>',
#   '<start> A man in a kitchen with his family in a house. <end>'],
#  'COCO_train2014_000000122802.jpg': ['<start> A man standing in a kitchen with granite countertops. <end>',
#   '<start> An old man in the middle of his kitchen. <end>',
#   '<start> A man stands in the middle of his granite counter-topped kitchen. <end>',
#   '<start> A man leaning forward on a counter top. <end>',
#   '<start> A man stands behind a granite kitchen countertop with industrial lighting overhead. <end>'],
#  'COCO_train2014_000000515040.jpg': ['<start> Seagulls flying overhead while trucks sit in a parking lot. <end>',
#   '<start> A seagull perches on top of a van. <end>',
#   '<start> A white van parked out side of a large white building. <end>',
#   '<start> A white van sits outside of a white building. <end>',
#   '<start> A white van parked with a seagull standing on top of it. <end>',
#   '<start> Single seagull sits on a white van with others flying in background <end>'],
#  'COCO_train2014_000000161657.jpg': ['<start> A modern bathroom contains many glass and tile pieces <end>',
#   '<start> A bathroom with a white toilet and a white bath <end>',
#   '<start> The overhead view of a tiled bathroom  with a tub, shower, toilet, bidet, and sink. <end>',
#   '<start> A bathroom dimly lit with a bathtub and a shower <end>',
#   '<start> A bathroom with bathtub, shower, bidet, toilet, and sink. <end>'],
#  'COCO_train2014_000000072704.jpg': ['<start> A black cat making an angry face while sitting on the bathroom floor  <end>',
#   '<start> a black cat sits next to laundry on the floor <end>',
#   '<start> a black cat sitting next to dirty clothes on the bathroom floor <end>',
#   '<start> A black cat sits on a bathroom floor next to some laundry. <end>',
#   '<start> A cat sitting on a bath rug next to a pile of clothes. <end>'],
#  'COCO_train2014_000000028149.jpg': ['<start> A bathroom with a TV near the mirror <end>',
#   '<start> A television reflected off a mirror near a counter top. <end>',
#   '<start> A flat screen TV sits next to a box of tissues and a remote control. <end>',
#   '<start> A TV is behind glass in a bathroom. <end>',
#   '<start> A hotel bathroom that has technology in the mirror. <end>'],
#  'COCO_train2014_000000257263.jpg': ['<start> A public restroom toilet has been photographed in sepia <end>',
#   '<start> A restroom with the toilet in the corner. <end>',
#   '<start> A toilet is equipped with support bars for the disabled. <end>',
#   '<start> A bathroom toilet is surrounded with silver handrails. <end>',
#   '<start> Toilet paper on the floor below a public toilet. <end>'],
#  'COCO_train2014_000000520049.jpg': ['<start> Photo of a man riding an old styled bicycle near what appears to be the Golden Gate Bridge. <end>',
#   '<start> A man rides a bicycle across the river.  <end>',
#   '<start> Man riding on a very old version of a personal bicycle.  <end>',
#   '<start> A man on an old-fashioned bicycle, biking across a bridge. <end>',
#   '<start> A man in a yellow coat rides an old-fashioned bicycle <end>'],
#  'COCO_train2014_000000503598.jpg': ['<start> There is some pet food in the floor in an empty kitchen <end>',
#   '<start> A kitchen sink, counter, pots, and a dog dish. <end>',
#   '<start> There is a small kitchen with wooden cabinets and pet bowls on the floor. <end>',
#   '<start> A kitchen with a pets food dishes on the floor. <end>',
#   '<start> A very clean kitchen with some animal food on the ground. <end>'],
#  'COCO_train2014_000000230843.jpg': ['<start> A young boy surfing  in low waves. <end>',
#   '<start> A young boy is standing on a surfboard and riding a wave. <end>',
#   '<start> A surfer rides his surf board on some very small waves. <end>',
#   '<start> A young boy is standing on a surfboard in the water. <end>',
#   '<start> A young boy is standing on a surfboard in the ocean.  <end>'],
#  'COCO_train2014_000000231029.jpg': ['<start> The top of a kitchen cabinet covered with brass pots and pans. <end>',
#   '<start> A kitchen with some old fashioned kitchen ware. <end>',
#   '<start> A kitchen with copper pots on pot racks and on the stove <end>',
#   '<start> A restaurant kitchen with bowls and pans ready for the night. <end>',
#   '<start> A kitchen with several brass pots and pans on stove tops. <end>'],
#  'COCO_train2014_000000174028.jpg': ['<start> A woman is shaving her face while sitting on a wooden bench. <end>',
#   '<start> two girls sitting on a bench eating lunch <end>',
#   '<start> A girl demonstrating the act of shaving sitting on a bench. <end>',
#   '<start> A girl trusts another girl to shave her while sitting back to back. <end>',
#   '<start> two females sitting on a bench one is being the arms for the other. <end>'],
#  'COCO_train2014_000000480489.jpg': ['<start> The sky is full of colorful kites along a mountain. <end>',
#   '<start> A large kite in the shape of the bottom half of a woman. <end>',
#   '<start> The parachutes fly through the sky next to each other. <end>',
#   '<start> assorted decorations laying around on a plastic tarp <end>',
#   '<start> A plethora of kites flying in the sky next to some mountains. <end>'],
#  'COCO_train2014_000000056972.jpg': ['<start> A bathroom in white has a cupboard above the sink. <end>',
#   '<start> A bathroom sink and cabinet featuring everything white <end>',
#   '<start> A bathroom with a sink, cabinet, mirror and picture. <end>',
#   '<start> A white pedestal sink below a white cabinet in a white bathroom.  <end>',
#   '<start> A modern bathroom sink and wall deco is shown.   <end>'],
#  'COCO_train2014_000000187042.jpg': ['<start> A bike and a raft sit atop a boat on the water. <end>',
#   '<start> A boat in the water with a raft and a bike loaded at one end of it <end>',
#   '<start> A boat has a raft and a bicycle on it. <end>',
#   '<start> The front of a boat with a raft and bicycle on it. <end>',
#   '<start> A small boat with a raft and bike strapped to it in a body of water. <end>'],
#  'COCO_train2014_000000101891.jpg': ['<start> Bicycles, cars and a trash can in a garage. <end>',
#   '<start> Clutter blocks antique cars from leaving the garage <end>',
#   '<start> A garage filled with old cards and old bicycles. <end>',
#   '<start> Some antique cars sit in a garage with some bicycles <end>',
#   '<start> A garage with bicycles, cars and a garbage can. <end>'],
#  'COCO_train2014_000000090359.jpg': ['<start> A man jumping his bicycle onto a bench. <end>',
#   '<start> A man balancing a bike on a bench. <end>',
#   '<start> a man does a trick on a bike on a bench <end>',
#   '<start> A young man rides his bicycle on top of a cement bench. <end>',
#   '<start> A man on a bicycle performing tricks on a bench. <end>'],
#  'COCO_train2014_000000213532.jpg': ['<start> Black and white image of two children paying attention.  <end>',
#   '<start> A boy holding his arm around the shoulders of the girl sitting next to him.  <end>',
#   '<start> A boy places his arm around a friend. <end>',
#   '<start> One kid has his arm wrapped around the other kid <end>',
#   '<start> Two children sitting down, one with his arm over the other. <end>'],
#  'COCO_train2014_000000024091.jpg': ['<start> A compact car with bicycles mounted on the roof.  <end>',
#   '<start> A car with a bunch of bicycles strapped to its roof. <end>',
#   '<start> A car with several bikes on a bike rack.  <end>',
#   "<start> A car is loaded down with many bicycles attached to it's roof. <end>",
#   "<start> A car has multiple bikes hooked onto it's roof. <end>"],
#  'COCO_train2014_000000372427.jpg': ['<start> A crisp neutral bathroom embellished with modern treatments. <end>',
#   '<start> The toilet is next to a curtained window. <end>',
#   '<start> Curtains hanging in a bathroom window beside a toilet. <end>',
#   '<start> A bathroom window reveals a snowy day outside. <end>',
#   '<start> A tan bathroom with black curtains and towel <end>'],
#  'COCO_train2014_000000376047.jpg': ['<start> A kitchen scene with stainless steel appliance and a checkered pattern floor. <end>',
#   '<start> A kitchen with new age appliances and equipment. <end>',
#   '<start> Silver and white colored personal kitchen with yellow tiling. <end>',
#   '<start> A modern lighted kitchen with stainless steel appliances. <end>',
#   '<start> A picture of some appliances stove, dishwasher, refridgerator and microwave, in a kitchen. <end>'],
#  'COCO_train2014_000000577876.jpg': ['<start> A lady talking a self portrait in a fancy bathroom. <end>',
#   '<start> A woman takes a selfie in front of a restroom mirror. <end>',
#   '<start> A woman takes a photo of her reflection in a bathroom mirror. <end>',
#   '<start> A woman takes her picture in the mirror in the bathroom. <end>',
#   '<start> A woman taking a self shot at an ornate mirror and sink. <end>'],
#  'COCO_train2014_000000047093.jpg': ['<start> A woman walking and talking on a cell phone. <end>',
#   '<start> A female student is talking on her phone while walking. <end>',
#   '<start> A young woman walking down the street while talking on her cell phone <end>',
#   '<start> Two young women walking while one is on a cell phone <end>',
#   '<start> Two young woman walking by a fire hydrant, one talking on cell. <end>'],
#  'COCO_train2014_000000374873.jpg': ['<start> A man on top of a snowy mountain with skis. <end>',
#   '<start> A group of skiers stand atop a snowy peak. <end>',
#   '<start> Group of skiers atop a mountain looking over edge. <end>',
#   '<start> A man poses for a picture on top of a snowy hill. <end>',
#   '<start> Skiers are standing at the top of a snow-covered mountain. <end>'],
#  'COCO_train2014_000000360053.jpg': ['<start> A stuffed animal is laying on the bed by a window. <end>',
#   "<start> a white bear laying on a bed with someone's hand on the other side <end>",
#   '<start> A white teddy bear is laying on a bed in a dimly lit room. <end>',
#   '<start> A teddy bear lying face down on a bedspread covered mattress in front of a window <end>',
#   '<start> A bed with blue bed spread on it in front of a window. <end>'],
#  'COCO_train2014_000000517565.jpg': ['<start> A wooden toilet seat sits open in an empty bathroom. <end>',
#   '<start> A bathroom with a sink shower and toilette. <end>',
#   '<start> A bathroom with a toilet and a sink. <end>',
#   '<start> Bathroom shot of an open toilet and sink. <end>',
#   '<start> An empty bathroom with the toilet seat up. <end>'],
#  'COCO_train2014_000000543882.jpg': ['<start> A decorated table covered with plates of food and vegetables.  <end>',
#   '<start> A buffet of different types of food sitting on a buffet table. <end>',
#   '<start> A buffet table at a restaurant, covered with food. <end>',
#   '<start> The two banquet tables held a variety of meats, dips, and pastries. <end>',
#   '<start> A display of many prepared food dishes arranged decoratively on serving table.  <end>'],
#  'COCO_train2014_000000038682.jpg': ['<start> a picture of a man riding a bicycle at night <end>',
#   '<start> A man with a backpack rides a bicycle. <end>',
#   '<start> A man using his bicycle to go down a street. <end>',
#   '<start> A person with a backpack on riding by on a bike. <end>',
#   '<start> A man riding a bike down the street at night. <end>'],
#  'COCO_train2014_000000568117.jpg': ['<start> Thee cats sleeping on a bed with a person. <end>',
#   '<start> Three cats sleeping with their owners on a bed. <end>',
#   '<start> Three cats are sleeping on a bed with a person.  <end>',
#   '<start> A person is sleeping on the same bed as three cats <end>',
#   "<start> Two black cats nap as a white cat lays on a sleeping person's chest. <end>"],
#  'COCO_train2014_000000186620.jpg': ['<start> A young man playing a game of Frisbee. <end>',
#   '<start> A man extends his hand out to catch a frisbee. <end>',
#   '<start> A man in a courtyard reaches out to catch a Frisbee. <end>',
#   '<start> College student playing frisbee on a campus lawn. <end>',
#   '<start> A man has a frisbee in mid air just out of his hand. <end>'],
#  'COCO_train2014_000000004377.jpg': ['<start> A group of people playing a game of croquet. <end>',
#   '<start> A game of croquet is being played in a back yard. <end>',
#   '<start> Two guys and a girl playing croquet in the yard. <end>',
#   '<start> A group of four people playing croquet on a lawn. <end>',
#   '<start> A group of friends enjoy a game of croquet on a grassy fenced in field. <end>'],
#  'COCO_train2014_000000189278.jpg': ['<start> A chef opens up an oven in a kitchen. <end>',
#   '<start> This is a restaurant kitchen with two industrial ovens. <end>',
#   '<start> There are two ovens in a kitchen restaurant, and one of them is being used. <end>',
#   '<start> Two ovens in use in a professional kitchen . <end>',
#   '<start> A person standing in a kitchen next to an oven. <end>'],
#  'COCO_train2014_000000170045.jpg': ['<start> a woman standing beside a clean kitchen island <end>',
#   '<start> A woman standing behind the island in the kitchen <end>',
#   '<start> A woman making something in a kitchen.  <end>',
#   '<start> A woman stands in the kitchen, surrounded by wood cabinets and stainless steel appliances. <end>',
#   '<start> A woman is standing at the island counter in a kitchen.  <end>'],
#  'COCO_train2014_000000416172.jpg': ['<start> A kitchen being prepared to get newly painted.  <end>',
#   '<start> The corner of an empty kitchen with cleaning products all over the counter. <end>',
#   '<start> Dirty kitchen with cleaning supplies placed allover the counters. <end>',
#   '<start> An a kitchen is being cleaned and decluttered. <end>',
#   '<start> A dirty kitchen that looks to be under construction. <end>'],
#  'COCO_train2014_000000309517.jpg': ['<start> A person standing in front of a large body of water as the sun sets. <end>',
#   '<start> The silhouette of a person standing in front of a sunset over water.  <end>',
#   '<start> A person is standing in front of the ocean at sunset.  <end>',
#   '<start> A dark profile of a person set before a sunset on the beach. <end>',
#   '<start> Man standing like a shadow in front of the ocean. <end>'],
#  'COCO_train2014_000000274682.jpg': ['<start> An empty bathroom with a large mirror and sink. <end>',
#   '<start> A bathroom with two sinks and a closet.  <end>',
#   '<start> A white bathroom with a walk in closet is shown. <end>',
#   '<start>  A bathroom under construction with a double sink vanity that has a mirrir and light strip over it <end>',
#   '<start> A master bedroom with a closet and attached bathroom. <end>'],
#  'COCO_train2014_000000480545.jpg': ['<start> A set of stairs lead to a toilet and cabinet in a bathroom. <end>',
#   '<start> The bathroom door next to the laundry room is open. <end>',
#   '<start> Through the door view of a small white bathroom.  <end>',
#   '<start> A small bathroom containing a step, toilette and sink. <end>',
#   '<start> The bathroom has a toilet, sink, tile floor and wooden panels on the outside. <end>'],
#  'COCO_train2014_000000210082.jpg': ['<start> Double doors open into a bathroom with a footed tub. <end>',
#   '<start> A free-standing bathroom near an open door and table. <end>',
#   '<start> A bathroom scene with open double doors, double sinks and a bathtub. <end>',
#   '<start> a bathroom with the door open and a tub <end>',
#   '<start> There is an Asian inspired bathroom with double doors. <end>'],
#  'COCO_train2014_000000474031.jpg': ['<start> An empty kitchen has walls painted white.  <end>',
#   '<start> A kitchen area with a microwave and refrigerator. <end>',
#   '<start> A house with a white decorated kitchen.  <end>',
#   '<start> A large kitchen featuring a counter top and refrigerator. <end>',
#   '<start> a large kitchen decorated with white flowers and books  <end>'],
#  'COCO_train2014_000000429065.jpg': ['<start> A colorful tent is stationed on a bike lane. <end>',
#   '<start> A biker rides through a tent in a bike lane. <end>',
#   '<start> A multicolored kiosk for cyclists in a city <end>',
#   '<start> Colorful tent on a street is a stop for bicyclists. <end>',
#   '<start> A shelter area for people on bicycles to warm up from the cold. <end>'],
#  'COCO_train2014_000000002448.jpg': ['<start> Two kitchen stools sitting in front of an island in a kitchen\n <end>',
#   '<start> A kitchen counter with chairs, refrigerator, and cupboards.  <end>',
#   '<start> A picture of a kitchen area with refrigerator and stove. <end>',
#   '<start> A kitchen with a refrigerator, oven, and counter. <end>',
#   '<start> A very clean kitchen with the light on. <end>'],
#  'COCO_train2014_000000161749.jpg': ['<start> Two dogs stand in a kitchen beneath their owner. <end>',
#   "<start> Two stands standing on the floor by their owner's legs <end>",
#   '<start> Two dogs with a woman in the kitchen. <end>',
#   "<start> A photo on a kitchen floor with a person's legs and two dogs. <end>",
#   '<start> Person standing in the kitchen with two dogs at their feet. <end>'],
#  'COCO_train2014_000000435091.jpg': ['<start> A woman smiles at a man who is wearing a colorful sarong. <end>',
#   '<start> Man and woman with group of scissors on table. <end>',
#   '<start> A shirtless man wearing a pink towel in the kitchen with a woman drinking wine. <end>',
#   '<start> Man dressed in a wrap in a personal kitchen. <end>',
#   '<start> A man in a pink sarong showing scissors to a woman with wine. <end>'],
#  'COCO_train2014_000000385626.jpg': ['<start> Woman riding a bicycle down an empty street. <end>',
#   '<start> A woman in green is riding a bike. <end>',
#   '<start> a woman wearing a bright green sweater riding a bicycle <end>',
#   '<start> A woman on a bicycle is going down the small town street. <end>',
#   '<start> A woman bikes down a one way street. <end>'],
#  'COCO_train2014_000000180141.jpg': ["<start> A family sits at a table together enjoying each other's company <end>",
#   '<start> A family is playing a karaoke video game. <end>',
#   '<start> A family watches while two boys play a singing game. <end>',
#   '<start> A family watches two boys singing into microphones. <end>',
#   '<start> Kids and their moms are singing karaoke at the table. <end>'],
#  'COCO_train2014_000000330238.jpg': ['<start> A crowd of skiers prepare to ski down snow covered slopes. <end>',
#   '<start> Many skiiers are gathered at the base of a hill, while several travel down it. <end>',
#   '<start> Hikers climb up a snow-covered mountain in the winter. <end>',
#   '<start> Skiers of all ages skiing down a slope and gathering at the bottom. <end>',
#   '<start> A group of people are skiing on a mountain. <end>'],
#  'COCO_train2014_000000499237.jpg': ['<start> Towels are neatly stacked on a shelf in the bathroom. <end>',
#   '<start> A table with towels on top of it placed under a mirror. <end>',
#   '<start> A bathroom vanity with towels folded under the sink. <end>',
#   '<start> A pedestal sink with vanity sits below a mirror. <end>',
#   '<start> Towels stored under a bathroom sink with a glass countertop. <end>'],
#  'COCO_train2014_000000466800.jpg': ['<start> A view of a fancy spa like bathroom with a blue tiled tub. <end>',
#   '<start> Different types of tiles are on the walls, floor and tub. <end>',
#   '<start> Large modern bathroom with jacuzzi in a house. <end>',
#   '<start> A modern bathtub in a bathroom is displayed. <end>',
#   '<start> A nice bathroom with a standalone shower and a shower curtain. <end>'],
#  'COCO_train2014_000000279939.jpg': ['<start> A bathroom contains a toilet, sink, and bathtub. <end>',
#   '<start> The white bathroom has orange, blue, and gray accents. <end>',
#   '<start> A small bathroom with a white toilette and bath tub. <end>',
#   '<start> A bathroom with toilet and bowl for sink. <end>',
#   '<start> A bathroom with a toilet, sink, and bathtub. <end>'],
#  'COCO_train2014_000000526165.jpg': ['<start> Loving couple pose together behind a fruit-adorned cake. <end>',
#   '<start> An older woman preparing to blow out the candle on her birthday cake standing besides an older man  <end>',
#   '<start> A married couple posing in front of a piece of birthday cake. <end>',
#   '<start> A man and woman smiling in front of a cake. <end>',
#   '<start> A man and woman celebrating a special occasion, about to blow out a candle. <end>'],
#  'COCO_train2014_000000334790.jpg': ['<start> A young man jumping his skate board over a cement seating area. <end>',
#   '<start> Boy riding skateboard and doing trick in air. <end>',
#   '<start> A man in a blue shirt and jeans doing a trick on a skateboard.  <end>',
#   '<start> A skateboarder is airborne as he does a trick.  <end>',
#   '<start> A young man performing a trick on a skateboard, <end>'],
#  'COCO_train2014_000000014750.jpg': ['<start> A bicycle with a basket is parked at the side of a building <end>',
#   '<start> A bicycle leaning against a building near a window. <end>',
#   '<start> A bicycle parked against the side of a stone house. <end>',
#   '<start> A bicycle leaning against an old white building. <end>',
#   '<start> A bicycle is parked up against a white stucco building. <end>'],
#  'COCO_train2014_000000573518.jpg': ['<start> A black colored keyboard for a computer system. <end>',
#   '<start> A black computer keyboard with lcd panel and numeric pad. <end>',
#   '<start> A wireless keyboard compatible with role playing games. <end>',
#   '<start> A computer keyboard, with black keys and white lettering. <end>',
#   '<start> A black computer keyboard with a bunch of keys on it <end>'],
#  'COCO_train2014_000000253464.jpg': ['<start> A mid sized bathroom with toilette, shower and vanity mirror above a sink. <end>',
#   '<start> A very clean bathroom with the lights on. <end>',
#   '<start> The yellow flowers sits atop the counter in a clean bathroom. <end>',
#   '<start> A very clean bathroom is shown with wood cabinets. <end>',
#   '<start> A bathroom has a green and white striped shower curtain. <end>'],
#  'COCO_train2014_000000291827.jpg': ['<start> Two boys with surf boards walking out into the ocean. <end>',
#   '<start> Surfers waiting for the right wave to ride. <end>',
#   '<start> Guys on their way to surfboard at the beach <end>',
#   '<start> People with surf boards going into the ocean. <end>',
#   '<start> A group of surfers wade into the sea. <end>'],
#  'COCO_train2014_000000478007.jpg': ['<start> A bathroom sink and counter with a large mirror above it. <end>',
#   '<start> A wood bathroom vanity with a granite countertop. <end>',
#   '<start> This is a bathroom sink in a hotel <end>',
#   '<start> An indoor bathroom with reflective marble counter tops <end>',
#   '<start> A hotel room bathroom sink and tissue dispenser.  <end>'],
#  'COCO_train2014_000000461221.jpg': ['<start> A kitchen with a over stove and toaster oven including a microwave. <end>',
#   '<start> A kitchen, with sink, stove, and a white cabinet. <end>',
#   '<start> A kitchen cupboard in a kitchen with a stove and a sink. <end>',
#   '<start> A large kitchen cabinet or pantry in a small kitchen. <end>',
#   '<start> Small, clean kitchen with a large white cupboard.  <end>'],
#  'COCO_train2014_000000416909.jpg': ['<start> An un occupied bathroom with a shower toilette and sink. <end>',
#   '<start> A clean bathroom with sink, toilet and shower. <end>',
#   '<start> A small bathroom showing the sink and toilet area. <end>',
#   '<start> A door leading to a bathroom with a sink visible. <end>',
#   '<start> A door opening to a bathroom with orange shades and matching rug. <end>'],
#  'COCO_train2014_000000377955.jpg': ['<start> A silver car parked in a shopping center parking lot. <end>',
#   '<start> A car is parked in a empty parking lot. <end>',
#   '<start> The shopping plaza has many stores and one parked car. <end>',
#   '<start> A silver sedan is parked in a plaza lot on a cloudy day. <end>',
#   '<start> a small strip mall with a few cars in the parking lot <end>'],
#  'COCO_train2014_000000550126.jpg': ['<start> A bathroom with a close shower curtain next to a toilette. <end>',
#   '<start> A white shower curtain with a spiral pattern hanging in the bathroom. <end>',
#   '<start> A bathroom with a toilet bowl and shower curtain. <end>',
#   '<start> A bathroom has a large shower curtain with design. <end>',
#   '<start> A closed shower curtain in a tiled bathroom. <end>'],
#  'COCO_train2014_000000194698.jpg': ["<start> A small dog cradled in his loving owner's arm as he falls asleep. <end>",
#   "<start> A person holding a chihuahua sleeping on it's back in their arm.  <end>",
#   '<start> A person holding a small sleeping dog in their arms. <end>',
#   "<start> A little dog is laying on a man's arm. <end>",
#   '<start> A small dog taking a nap on the arm of a person. <end>'],
#  'COCO_train2014_000000579846.jpg': ['<start> A nearly empty house with a bicycle mounted on the wall. <end>',
#   '<start> A hall opening onto a bathroom, bedroom, and two other rooms. <end>',
#   '<start> A view of a hallway in a house. <end>',
#   '<start> There is a hallway leading to a door where bicycle tires are showing. <end>',
#   '<start> A house hallway with all the bedroom doors open. <end>'],
#  'COCO_train2014_000000009469.jpg': ['<start> A teenage boy is in a field looking at a wire. <end>',
#   '<start> The boy is inspecting the wire for a project. <end>',
#   '<start> A young guy checking on a wire as he holds onto a dog leash. <end>',
#   '<start> A boy is outside with his dog in a field surrounded by a sign and other items. <end>',
#   '<start> A boy building something with wires and poles. <end>'],
#  'COCO_train2014_000000348595.jpg': ['<start> A man in a parade has red and white face and umbrella. <end>',
#   '<start> A young person with red and white face paint holds an umbrella. <end>',
#   '<start> Soccer fan is showing his support by dressing up.  <end>',
#   '<start> A man with a painted red and white face is standing in the street. <end>',
#   '<start> a person with their face painted standing in the street <end>'],
#  'COCO_train2014_000000079143.jpg': ['<start> A small bathroom has separate tub and shower. <end>',
#   '<start> A spacious bathroom with a fancy bathtub and sink. <end>',
#   '<start> A bathroom is lit by a light over a sink. <end>',
#   '<start> A light is on in an empty, clean bathroom. <end>',
#   '<start> A shiny bathroom has an old fashioned bathtub and gold walls. <end>'],
#  'COCO_train2014_000000346909.jpg': ['<start> Two dogs are laying down next to each other. <end>',
#   '<start> Two dogs were captured in a photo with the lighting of the image altered. <end>',
#   '<start> Two dogs sitting one the ground looking at something. <end>',
#   '<start> Two dogs are resting together on the floor. <end>',
#   '<start> Two doge have their paws out in an overexposed picture. <end>'],
#  'COCO_train2014_000000351191.jpg': ['<start> A woman crossing a city street while carrying groceries. <end>',
#   '<start> Shopper crossing a street in the downtown of a city. <end>',
#   '<start> A person crossing at a crosswalk with bags in his hands. <end>',
#   '<start> A city street scene with cars and a person crossing the street. <end>',
#   '<start> A man is crossing a city intersection carrying bags. <end>'],
#  'COCO_train2014_000000165350.jpg': ['<start> A group of bike riders race down a busy street. <end>',
#   '<start> A group of bikers round a turn on a road.  <end>',
#   '<start> Cyclists competing in a race round a corner.  <end>',
#   '<start> A peleton of cyclists leaning into a turn <end>',
#   '<start> Multiple cyclists riding their bikes on the street. <end>'],
#  'COCO_train2014_000000549575.jpg': ['<start> A kitchen filled with many cupboards and lots of counter space. <end>',
#   '<start> An empty and very clean white and tan kitchen. <end>',
#   '<start> unused kitchen stove, sink and counter topsand cabinettes <end>',
#   '<start> A clean kitchen that is empty and white. <end>',
#   '<start> An unfurnished kitchen in a tropical house hold. <end>'],
#  'COCO_train2014_000000387408.jpg': ['<start> An attractive woman taking a selfie in a bathroom. <end>',
#   '<start> A selfie of a young woman in her bathroom. <end>',
#   '<start> A woman is taking a picture of herself in the bathroom. <end>',
#   '<start> A woman taking a selfie in a bathroom <end>',
#   '<start> a woman taking a photo of herself in the mirror  <end>'],
#  'COCO_train2014_000000331863.jpg': ['<start> A group of people sitting on a couch while a brown dog looks at them  <end>',
#   '<start> A group of friends spending the day watching TV together. <end>',
#   '<start> Four friends lounge on a couch with a dog. <end>',
#   '<start> A dog sits staring at a group of people. <end>',
#   '<start> A group of people who are sitting together on a couch. <end>'],
#  'COCO_train2014_000000350553.jpg': ['<start> An older woman walking a bicycle with a bus in the background. <end>',
#   '<start> A woman walks her bike past a city bus. <end>',
#   '<start> A lady waking a bike by a bus. <end>',
#   '<start> A woman walks her bicycle near a bus.  <end>',
#   '<start> A woman walking a bike, while a bus passes by. <end>'],
#  'COCO_train2014_000000064941.jpg': ['<start> Three people riding bikes on the side of a road. <end>',
#   '<start> A group of two adults and a child biking down a road. <end>',
#   '<start> Two adults and a child riding bicycles on the side of a road. <end>',
#   '<start> A couple and their child riding bikes down an asphalt road. <end>',
#   '<start> A young family is biking in the bike lane of a road.  <end>'],
#  'COCO_train2014_000000219409.jpg': ['<start> A fridge that is halfway open during the night. <end>',
#   '<start> An open refrigerator in a kitchen next to a cupboard. <end>',
#   '<start> A fridge door is open in a kitchen at night. <end>',
#   '<start> an open refrigerator with a shinning bright light <end>',
#   '<start> Lower door of refrigerator open in dark kitchen.  <end>'],
#  'COCO_train2014_000000471895.jpg': ['<start> A bathroom featuring an oddly shaped toilette, shower and sink. <end>',
#   '<start> A small bathroom decorated with pretty red flowers. <end>',
#   '<start> a bathroom with a toilet, sink and a mirror <end>',
#   '<start> The bathroom has a shower area, toilet and sink. <end>',
#   '<start> A bathroom that has some flowers on the sink and toilet. <end>'],
#  'COCO_train2014_000000425135.jpg': ['<start> The inside of a bathroom with two sinks. <end>',
#   '<start> A large bathroom with two sinks and three windows. <end>',
#   '<start> A view of a communal bathroom with multiple sinks and windows. <end>',
#   '<start> A bathroom with two porcelain sinks and hexagonal tiles. <end>',
#   '<start> A bathroom with two sinks a bathtub and a shower with lots of lighting from the windows <end>'],
#  'COCO_train2014_000000175565.jpg': ['<start> A cocker spaniel sitting next to a woman holding a baby.  <end>',
#   '<start> A dog lays on a couch next to a woman holding a baby. <end>',
#   '<start> A dog is laying next to a woman holding a baby. <end>',
#   '<start> A person sitting in a chair holding a baby and a dog. <end>',
#   '<start> A woman holding a baby and sitting next to a dog. <end>'],
#  'COCO_train2014_000000178771.jpg': ['<start> A man on his skateboard at a basketball court. <end>',
#   '<start> A young boy riding a skate board at a public skate park. <end>',
#   '<start> A person skateboarding on an outside basketball court. <end>',
#   '<start> A boy is doing tricks on his skateboard. <end>',
#   '<start> A skateboarder has one end of the board in the air on top of a bench. <end>'],
#  'COCO_train2014_000000432201.jpg': ['<start> Clean stainless steel kitchen with large cabinets and counter. <end>',
#   '<start> A small spotless and clean stainless steel kitchen. <end>',
#   '<start> A stainless Steele kitchen with sinks and lots of storage. <end>',
#   '<start> A restaurant kitchen stocked with stainless steel appliances. <end>',
#   '<start> A kitchen with a sink, ovens and dishes in it. <end>'],
#  'COCO_train2014_000000051644.jpg': ['<start> A srfer perches on his board precariously as he hits a big wave. <end>',
#   '<start> A man riding a wave with a surfboard. <end>',
#   '<start> A surfer catches a  wave but is about to fall off his board <end>',
#   '<start> A man is surfing on some small ocean waves. <end>',
#   '<start> a man on a surf board rides on some waves <end>'],
#  'COCO_train2014_000000565401.jpg': ['<start> A bicycle leans against a park bench with a flowering tree nearby. <end>',
#   '<start> A bicycle parked in the grass by a tree.  <end>',
#   '<start> A bicycle leaning up against a park bench. <end>',
#   '<start> A bicycle leans on a bench in a park. <end>',
#   '<start> The bicycle is parked beside of the bench outside. <end>'],
#  'COCO_train2014_000000256950.jpg': ['<start> The serving counter of a restaurant is quiet. <end>',
#   '<start> A kitchen filled with dishes and bowls stacked on top of each other. <end>',
#   '<start> Kitchen ware sitting behind the counter top at a restaurant. <end>',
#   '<start> The restaurant kitchen is highly lit, displaying the colorful bowls. <end>',
#   '<start> There are various utensils on the counter of a large kitchen. <end>'],
#  'COCO_train2014_000000276961.jpg': ['<start> A bathroom mirror with items in front of it. <end>',
#   '<start> A mirror reflecting the opposite wall of a bathroom.  <end>',
#   '<start> A view of a mirror in a bathroom. <end>',
#   '<start> A tiled bathroom vanity with a small mirror. <end>',
#   '<start> A tiled bathroom with toothbrushes and shaving accessories.  <end>'],
#  'COCO_train2014_000000530832.jpg': ['<start> Two women prepare a meal in a large kitchen. <end>',
#   '<start> Two woman standing in a kitchen preparing food. <end>',
#   '<start> two women working in a large kitchen with natural lighting <end>',
#   '<start> A wide angle view of a kitchen with two women working.  <end>',
#   '<start> Two women in the kitchen standing by the sink  <end>'],
#  'COCO_train2014_000000211265.jpg': ['<start> An empty bathroom featuring a toilette and window. <end>',
#   '<start> A bathroom toilet next to a window with a handicap bar next to it and a cabinet over it <end>',
#   '<start> A white bathroom with a tan toilet and a hand rail <end>',
#   '<start> A toilet bowl with a handicap rail next to it. <end>',
#   '<start> The sunlight is shining brightly in the bathroom <end>'],
#  'COCO_train2014_000000226517.jpg': ['<start> A kitchen with a wooden kitchen table and appliances in it. <end>',
#   '<start> A kitchen has a wooden table and capinets. <end>',
#   '<start> A kitchen scene with a dining room table and chairs. <end>',
#   '<start> A kitchen with wooden drawers, table, chairs and stone counter tops. <end>',
#   '<start> a kitchen with a table and chairs and various kitchen appliances  <end>'],
#  'COCO_train2014_000000209040.jpg': ['<start> A bathroom sink with mirror placed above it. <end>',
#   '<start> A nice bathroom has a clean counter with makeup toothbrushes. <end>',
#   '<start> A bathroom scene looking at the sink and mirror. <end>',
#   '<start> A white background with white counter top and white walls. <end>',
#   '<start> a bathroom with a sink and a mirror <end>'],
#  'COCO_train2014_000000199743.jpg': ['<start> A person on a bicycle waiting to cross a street at the intersection. <end>',
#   '<start> A man on a bike waiting at a crosswalk. <end>',
#   '<start> A man waits at the crosswalk with his bicycle. <end>',
#   '<start> A bicyclist and cars wait at a busy intersection. <end>',
#   '<start> A person on a bicycle at a cross walk <end>'],
#  'COCO_train2014_000000427180.jpg': ['<start> A woman in a fushia shirt cooking in an industrial kitchen.  <end>',
#   '<start> A man preparing food in a kitchen underneath a clock. <end>',
#   '<start> A person in a commercial kitchen preparing food. <end>',
#   '<start> Two large refrigerators and long workstation indicate a commercial kitchen. <end>',
# ...
#   '<start> A young child brushing their teeth holding a cup of water. <end>',
#   '<start> A small child holds a cup of water in one hand while brushing his teeth with the other. <end>',
#   '<start> a small child brushing her teeth from a cup <end>',
#   '<start> SMALL CHILD  WITH BLUE TOOTHBRUSH BRUSHING HIS TEETH <end>'],
#  'COCO_train2014_000000558697.jpg': ['<start> Several people stand next to a parked airplane where people are exiting the plane. <end>',
#   '<start> A group of people disembarking from a plane at and airport. <end>',
#   '<start> A plane that is on the ground in the nighttime. <end>',
#   '<start> A Dragonair plane awaiting boarding passengers at night. <end>',
#   '<start> A huge Chinese aircraft is sitting at an airport with people unloading. <end>'],
#  'COCO_train2014_000000328120.jpg': ['<start> A long line of parked bicycles in a large city. <end>',
#   '<start> Many bicycles parked on an asian city street <end>',
#   '<start> A lot about bicycles that our in the streets. <end>',
#   '<start> many different bikes on a city street  <end>',
#   '<start> A row of many bikes parked side by side. <end>'],
#  'COCO_train2014_000000029104.jpg': ['<start> A chef in a kitchen preparing a meal <end>',
#   '<start> A chef preparing food in a professional kitchen. <end>',
#   '<start> A man puts a sauce on a food dish he is preparing. <end>',
#   '<start> a chef pouring a sauce on food cooking on the stove <end>',
#   '<start> A young man is cooking ramen in a kitchen. <end>'],
#  'COCO_train2014_000000577358.jpg': ['<start> People walking by browse the windows of shops. <end>',
#   '<start> Some people stand on the street looking in a store window.  <end>',
#   '<start> A woman standing next to a bicycle and looking through a store window. <end>',
#   '<start> People looking in the shop windows with a bicycle parked against the window. <end>',
#   '<start> A woman is looking inside of a shop window. <end>'],
#  'COCO_train2014_000000465595.jpg': ['<start> Three men are in a kitchen cooking and cutting through a dish. <end>',
#   '<start> A man uses a knife to slice food for serving.  <end>',
#   '<start> Three men in a kitchen preparing a dish. <end>',
#   '<start> Several men in the kitchen with one cutting a piece of meat. <end>',
#   '<start> A man cutting up food sitting on top of a white plate. <end>'],
#  'COCO_train2014_000000278860.jpg': ['<start> A counter top with various kitchen items in a kitchen. <end>',
#   '<start> The utensils have been neat arranged on the kitchen counter. <end>',
#   '<start> Kitchen counter scene showing wood cabinets, knife set and a coffee maker. <end>',
#   '<start> A kitchen filled with appliances and cooking utensils. <end>',
#   '<start> A kitchen counter with appliances and knives on it <end>'],
#  'COCO_train2014_000000063573.jpg': ['<start> A small tiled bathroom with white fixtures  <end>',
#   '<start> The small bathroom has a shower made of glass. <end>',
#   '<start> There is a small bathroom in beige and white colors and two toilets. <end>',
#   '<start> A toilet and a bidet are in a beige tiled bathroom with a shower stall. <end>',
#   '<start> AN IAMGE OF A BATHROOM WITH A TOILET AND A SHOWER  <end>'],
#  'COCO_train2014_000000087096.jpg': ['<start> Vendor in his stall selling various foods and bananas <end>',
#   '<start> A fruit stand with several bunches of hanging bananas. <end>',
#   '<start> A lot of bananas and a person together. <end>',
#   '<start> a person surrounded by bunches of bananas  <end>',
#   '<start> A man standing inside of a store behind piles of ripe bananas. <end>'],
#  'COCO_train2014_000000491128.jpg': ['<start> A photograph of a bathroom inside a home. <end>',
#   '<start> An open door shows a small bathroom space with a toilet and a shower while a sink sits near the open door. <end>',
#   '<start> bathroom with its door open and is very clean  <end>',
#   '<start> A well-lit bathroom with the door open and shower <end>',
#   '<start> A well lit bathroom with a painted glass door. <end>'],
#  'COCO_train2014_000000346699.jpg': ['<start> A small tiled modern bathroom with walk-in shower <end>',
#   '<start> A bathroom with a toilet, sink and a shower. <end>',
#   '<start> A very small and basic, yet clean looking bathroom. <end>',
#   '<start> A bathroom with sink, toilet, shower stall, and beige tiles is shown. <end>',
#   '<start> A bathroom as viewed from a door way. <end>'],
#  'COCO_train2014_000000380350.jpg': ['<start> Three people tossing a Frisbee on the beach. <end>',
#   '<start> a girl throws a frisbee to two boys on a beach <end>',
#   '<start> A girl throws a Frisbee on the beach. <end>',
#   '<start> People that are playing on the bitch with frisbee. <end>',
#   '<start> Three young people catching Frisbee on a sandy beach. <end>'],
#  'COCO_train2014_000000056753.jpg': ['<start> A kitchen with green walls, and a cluttered counter. <end>',
#   '<start> A kitchen is cluttered with bowels and cooking utensils.  <end>',
#   '<start> The kitchen counter of a partially renovated space <end>',
#   '<start> A kitchen scene with focus on the kitchen sink. <end>',
#   '<start> Dishes are placed on top of a kitchen counter. <end>'],
#  'COCO_train2014_000000118794.jpg': ['<start> Two young men having a conversation in a kitchen area. <end>',
#   '<start> Two men in the kitchen of a log cabin at night <end>',
#   '<start> Two people that are sitting in a kitchen talking. <end>',
#   '<start> Two men are in a cabin kitchen with one sitting on the counter. <end>',
#   '<start> Two men are talking in the kitchen of a cabin. <end>'],
#  'COCO_train2014_000000343009.jpg': ['<start> Two women sit together peeling apples in a bowl.  <end>',
#   '<start> This appears to be a mother and daughter sharing a snack.  <end>',
#   '<start> Two women are peeling a bowl of apples while seated. <end>',
#   '<start> Two women peel apples on chairs in a kitchen. <end>',
#   '<start> Two ladies sit on stools while peeling fruit in a bowl.  <end>'],
#  'COCO_train2014_000000471790.jpg': ['<start> A very small kitchen in a mobile home. <end>',
#   '<start> a sink and wood paneled oven in a vehicle <end>',
#   '<start> The door of a small oven is open. <end>',
#   '<start> And Evan that has the fence open to it. <end>',
#   '<start> recreational vehicle kitchen with sink, oven and dishwasher. <end>'],
#  'COCO_train2014_000000087217.jpg': ['<start> A kitchen with large tile floors and a big window <end>',
#   '<start> The kitchen is clean and white with plenty of light <end>',
#   '<start> A KITCHEN WITH A WINDOW THAT PERMITS LIGHT. <end>',
#   '<start> The small white kitchen has been cleaned spotlessy. <end>',
#   '<start> an  image of a kitchen setting with all white appliances <end>'],
#  'COCO_train2014_000000141200.jpg': ['<start> A person that is walking in the rain. <end>',
#   '<start> A lady all bundled up and holding an umbrella walks on.  <end>',
#   '<start> A woman walks in the rain with an umbrella. <end>',
#   '<start> The woman is walking in the rain with an umbrella. <end>',
#   '<start> A woman, under an umbrella, walking in the rain. <end>'],
#  'COCO_train2014_000000207686.jpg': ['<start> a white marbled bathroom with a rectangular window  <end>',
#   '<start> A bathroom complete with a toilet, sink and window <end>',
#   '<start> A bathroom is displayed with white marble walls. <end>',
#   '<start> A white and chrome bathroom with a gray floor. <end>',
#   '<start> This is a well designed bathroom that is plain and elegant at the same time. <end>'],
#  'COCO_train2014_000000261298.jpg': ['<start> A man relaxing on his love seat is doodling on his cell phone.  <end>',
#   '<start> A picture of a person sitting on the couch. <end>',
#   '<start> A MAN IS SITTIGN ON THE COUCH WITH HIS CELL PHONE <end>',
#   '<start> A man is relaxing in an overstuffed chair. <end>',
#   '<start> A person sits in an easy chair using a cell phone, background appears to possibly be a hair or nail salon. <end>'],
#  'COCO_train2014_000000107249.jpg': ['<start> The sink, toilet, and shower are close together in the small bathroom. <end>',
#   '<start> A picture of a small tiled guest bathroom  <end>',
#   '<start> A bathroom with white fixtures and tiled floor <end>',
#   '<start> A view inside of a bathroom with a shower. <end>',
#   '<start> A tiled bathroom has a tub, toilet, and sink. <end>'],
#  'COCO_train2014_000000110395.jpg': ['<start> A brown dog standing in a shower looking miserable. <end>',
#   '<start> A dog looks sad as it sits in the shower. <end>',
#   '<start> A tan dog sitting in  a shower getting a bath <end>',
#   '<start> Large white wet dog wet sitting in the shower.  <end>',
#   '<start> A wet dog looks exhausted inside a shower stall. <end>'],
#  'COCO_train2014_000000481391.jpg': ['<start> A stove top with a tea kettle underneath a glass and wood set of cabinets. <end>',
#   '<start> A kitchen with a red tea pot on the stove <end>',
#   '<start> A picture of a modern day kitchen with an orange tea kettle on the stove. <end>',
#   '<start> A kitchen island with a teapot on the stove <end>',
#   '<start> Kitchen with an island stove and clear cabinet spaces.  <end>'],
#  'COCO_train2014_000000521107.jpg': ['<start> A bathroom with track lighting and a white toilet near a sink. <end>',
#   '<start> A large tiled bathroom with a marble sink and white toilet <end>',
#   '<start> A clean and dimly lit modern hotel bathroom. <end>',
#   '<start> AN IMAGE OF A BATHROOM WITH A TOILET AND A SINK <end>',
#   '<start> A dimly lit clean bathroom featuring a toilet, mirror and counter <end>'],
#  'COCO_train2014_000000506927.jpg': ['<start> A man checking out a parked black scooter. <end>',
#   '<start> a person standing near a small motorcycle on a city street <end>',
#   '<start> a man in a white shirt is looking at a three wheeled motorcycle <end>',
#   '<start> a man looks down at two low riding motor bikes <end>',
#   '<start> a guy staring at a weird looking bike <end>'],
#  'COCO_train2014_000000117178.jpg': ['<start> A group of scooter enthusiasts parked at a red light. <end>',
#   '<start> a group of people on motorized scooters on a city street <end>',
#   '<start> some people wearing helmets are riding mopeds and some buildings <end>',
#   '<start> a group of people ride together on their motorcycles. <end>',
#   '<start> a group of kids riding on bikes on a road <end>'],
#  'COCO_train2014_000000071222.jpg': ['<start> A large shower head in a bathroom shower. <end>',
#   '<start> A tiled shower with a large shower head <end>',
#   '<start> The shower head has a blue light behind it. <end>',
#   '<start> A shower head and a shower shelf with various toiletries. <end>',
#   '<start> Two shower heads in a shower along with a shelf of products. <end>'],
#  'COCO_train2014_000000398105.jpg': ['<start> A clean kitchen with overhead lights and tile flooring <end>',
#   '<start> A large kitchen sink next to an automatic dishwasher underneath track lighting. <end>',
#   '<start> All of the cabinets in the kitchen are made of wood. <end>',
#   '<start> A very clean kitchen with wooden shelves and a stainless steel dishwasher. <end>',
#   '<start> A kitchen being lit by the outside sunlight. <end>'],
#  'COCO_train2014_000000361638.jpg': ['<start> A bathroom with a small white toilet sitting next to a walk in shower. <end>',
#   '<start> A clean bathroom with sink, mirror, toilet and shower. <end>',
#   '<start> A bathroom with a large mirror and walk in shower <end>',
#   '<start> A small cream tiled bathroom with a stand up shower. <end>',
#   '<start> A white bathroom area with no shower curtain. <end>'],
#  'COCO_train2014_000000322725.jpg': ['<start> A man and a woman are looking at a camera. <end>',
#   '<start> A man and a woman making goofy faces for a camera phone. <end>',
#   '<start> A man taking a picture of himself and a woman on his cellphone camera. <end>',
#   '<start> Two people are laughing while looking at a picture on a cell phone. <end>',
#   '<start> Two adults making bizarre faces for a photo shot while drinking beer.  <end>'],
#  'COCO_train2014_000000385307.jpg': ['<start> A kitchen with a center island covered in clutter. <end>',
#   '<start> A kitchen with a number of old fasioned items and furnishings. <end>',
#   '<start> an image of a kitchen setting with wine on the table <end>',
#   '<start> The old kitchen is made mostly of wooden paneling. <end>',
#   '<start> There are some kitchen supplies on a kitchen table <end>'],
#  'COCO_train2014_000000073159.jpg': ["<start> A man in a chef's coat kneels next to a rack of an oven. <end>",
#   '<start> A black-and-white photo of a man cooking in the kitchen. <end>',
#   '<start> cook prepares dish by putting it into the oven <end>',
#   '<start> A man preparing food in a kitchen next to an oven. <end>',
#   '<start> A man in a restaurant kitchen cooking in the oven. <end>'],
#  'COCO_train2014_000000022857.jpg': ['<start> A man preparing food in a professional kitchen. <end>',
#   '<start> A chef preparing meals in an industrial kitchen <end>',
#   '<start> A man cooking in a commercial kitchen over an oven. <end>',
#   '<start> A man is standinb by a grill in a kitchen with a stack of plates near him. <end>',
#   '<start> A male chef working in a large kitchen with stainless steel fixtures. <end>'],
#  'COCO_train2014_000000074335.jpg': ['<start> A group of friends are standing laughing in the kitchen <end>',
#   '<start> Several people stand in a kitchen area with brown cabinets. <end>',
#   '<start> people are gathered in the kitchen one is holding a wine glass <end>',
#   '<start> Friends laughing at a party while drinking beverages <end>',
#   '<start> Several young people standing in the kitchen at a party <end>'],
#  'COCO_train2014_000000125821.jpg': ['<start> A kitchen has dark brown cabinets and counter. <end>',
#   '<start> A small kitchen with a refrigerator, microwave, and dishwasher. <end>',
#   '<start> A kitchen with a microwave, refrigerator, and dishwasher. <end>',
#   '<start> A picture of a very nice and clean kitchen. <end>',
#   '<start> A corner of a small kitchen with cluttered counters. <end>'],
#  'COCO_train2014_000000307759.jpg': ['<start> A bike parked in a kitchen next to a dishwasher. <end>',
#   '<start> An old kitchen with a bicycle parked in there <end>',
#   '<start> The curtain of the open kitchen window has been tied to one side. <end>',
#   '<start> A kitchen that is in the middle of some repairs.  <end>',
#   '<start> A kitchen with various appliances and a bike on the floor. <end>'],
#  'COCO_train2014_000000128647.jpg': ['<start> Several people that are talking to each other. <end>',
#   '<start> THERE ARE PEOPLE STANDING IN THE KITCHEN TALKING  <end>',
#   '<start> three people in a kitchen with a counter top and a refrigerator  <end>',
#   '<start> Two men talking in the kitchen with a woman in the background. <end>',
#   '<start> Two men talk in a kitchen while a woman watches from the doorway. <end>'],
#  'COCO_train2014_000000287039.jpg': ['<start> A picture of a sink in a bathroom. <end>',
#   '<start> A bathroom counter features a black counter and two square sinks. <end>',
#   '<start> A clean bathroom with two sinks and a large mirror. <end>',
#   '<start> A double sink counter with a black top in the bathroom. <end>',
#   '<start> The bathroom vanity features double sinks in a unique rectangular shape. <end>'],
#  'COCO_train2014_000000398053.jpg': ['<start> A picture of a very clean kitchen in a  house. <end>',
#   '<start> The kitchen has a a white stove and refrigerator.  <end>',
#   '<start> A kitchen with white appliances and wood cabinets. <end>',
#   '<start> KITCHEN WITH BROWN CABINETS AND WHITE STOVE AND REFRIGERATOR <end>',
#   '<start> A kitchen scene with an oven and a refrigerator. <end>'],
#  'COCO_train2014_000000041455.jpg': ['<start> A modern bathroom with two sinks and a television on the wall. <end>',
#   '<start> A bathroom with two odd shaped sinks under a large mirror. <end>',
#   '<start> A bathroom with double sinks and tiled bathtub <end>',
#   '<start> an image of bathroom setting with two faucets and a tv <end>',
#   '<start> A tiled bathroom with square sinks and large mirror. <end>'],
#  ...}

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use the `TextVectorization` layer to vectorize the text data,
# that is to say, to turn the
# original strings into integer sequences where each integer represents the index of
# a word in a vocabulary. We will use a custom string standardization scheme
# (strip punctuation characters except `<` and `>`) and the default
# splitting scheme (split on whitespace).

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %% [markdown]
# ## Building a `tf.data.Dataset` pipeline for training
#
# We will generate pairs of images and corresponding captions using a `tf.data.Dataset` object.
# The pipeline consists of two steps:
#
# 1. Read the image from the disk
# 2. Tokenize all the five captions corresponding to the image

# %%
# append coco/train2014/ to all the keys of the dictionary

train_data = {
    os.path.join("coco/train2014/", key): value for key, value in train_data.items()
}

valid_data = {
    os.path.join("coco/train2014/", key): value for key, value in valid_data.items()
}

# %%
train_data["coco/train2014/COCO_train2014_000000254362.jpg"]
# Out:
# ['<start> Three picture frames of ducks swimming in water. <end>',
#  '<start> Multiple shots of birds swimming on top of the water. <end>',
#  '<start> A group of ducks on a calm body of water. <end>',
#  '<start> A set of three photos showing a group of ducks moving across water. <end>',
#  '<start> Three film clips of a pond of ducks.  <end>',
#  '<start> Three panels of ducks swimming on a wide pond. <end>']

# %%
# check in train_data if there are more than 5 values
# remove the 6th value and keep the first 5 values

for key, value in train_data.items():
    if len(value) > 5:
        # print(key, len(value))
        train_data[key] = value[:5]

for key, value in valid_data.items():
    if len(value) > 5:
        # print(key, len(value))
        valid_data[key] = value[:5]

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    print("PROCESS_INPUT: LEN DATASET", len(dataset))
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, tf.ragged.constant((captions))))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))
# Out:
# PROCESS_INPUT: LEN DATASET 4
# PROCESS_INPUT: LEN DATASET 4

# %% [markdown]
# ## Building the model
#
# Our image captioning architecture consists of three models:
#
# 1. A CNN: used to extract the image features
# 2. A TransformerEncoder: The extracted image features are then passed to a Transformer
#                     based encoder that generates a new representation of the inputs
# 3. A TransformerDecoder: This model takes the encoder output and the text data
#                     (sequences) as inputs and tries to learn to generate the caption.

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB7(
        input_shape=(*IMAGE_SIZE, 3),
        include_top=False,
        weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM,
            sequence_length=SEQ_LENGTH,
            vocab_size=VOCAB_SIZE,
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [
                tf.expand_dims(batch_size, -1),
                tf.constant([1, 1], dtype=tf.int32),
            ],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self,
        cnn_model,
        encoder,
        decoder,
        num_captions_per_image=5,
        image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model,
    encoder=encoder,
    decoder=decoder,
    image_aug=image_augmentation,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 1s 0us/step

# %% [markdown]
# ## Model training

# %%
try:
    from google.colab import drive
    import datetime
    drive.mount('/content/gdrive')

    # Create a directory in Google Drive to store models
    # !mkdir /content/gdrive/My\ Drive/Colab_Models
    loss_model_path = "/content/gdrive/My Drive/Colab_Models/loss_model_transformer_efficientnetB7_" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + ".txt"
    checkpoint_path = "/content/gdrive/My Drive/Colab_Models/cp_model_transformer_efficientnetB7_" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + ".h5"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    open(loss_model_path, 'w').close()
except:
    loss_model_path = "loss_model_from_scratch_LSTM_CNN.txt"
    checkpoint_path = "cp_model_from_scratch_LSTM_CNN.weights.h5"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    open(loss_model_path, 'w').close()
# Out:
# Mounted at /content/gdrive

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False,
    reduction='none',
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import _pickle as pickle

class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.history = {'loss':[],'val_loss':[]}

    def on_batch_end(self, batch, logs={}):
        self.history['loss'].append(logs.get('loss'))
        with open(loss_model_path, "r+b") as myfile:
            myfile.write(pickle.dumps(self.history))

    def on_epoch_end(self, epoch, logs={}):
        self.history['val_loss'].append(logs.get('val_loss'))

history = LossHistory()

# Fit the model
caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
    callbacks=[early_stopping, cp_callback, history],
)
# Out:
# Epoch 1/15
# 259/259 [==============================] - ETA: 0s - loss: 21.3716 - acc: 0.2331
# Epoch 1: saving model to /content/gdrive/My Drive/Colab_Models/cp_model_transformer_efficientnetB7_20240708_203425.h5
# 259/259 [==============================] - 2248s 8s/step - loss: 21.3716 - acc: 0.2335 - val_loss: 15.1438 - val_acc: 0.4309
# Epoch 2/15
# 259/259 [==============================] - ETA: 0s - loss: 14.8994 - acc: 0.4242
# Epoch 2: saving model to /content/gdrive/My Drive/Colab_Models/cp_model_transformer_efficientnetB7_20240708_203425.h5
# 259/259 [==============================] - 2105s 8s/step - loss: 14.8994 - acc: 0.4242 - val_loss: 13.5676 - val_acc: 0.4624
# Epoch 3/15
# 259/259 [==============================] - ETA: 0s - loss: 13.8636 - acc: 0.4477
# Epoch 3: saving model to /content/gdrive/My Drive/Colab_Models/cp_model_transformer_efficientnetB7_20240708_203425.h5
# 259/259 [==============================] - 2106s 8s/step - loss: 13.8636 - acc: 0.4477 - val_loss: 12.9348 - val_acc: 0.4746
# Epoch 4/15
# 259/259 [==============================] - ETA: 0s - loss: 13.3131 - acc: 0.4594
# Epoch 4: saving model to /content/gdrive/My Drive/Colab_Models/cp_model_transformer_efficientnetB7_20240708_203425.h5
# 259/259 [==============================] - 2105s 8s/step - loss: 13.3131 - acc: 0.4595 - val_loss: 12.5950 - val_acc: 0.4811
# Epoch 5/15
# 259/259 [==============================] - ETA: 0s - loss: 12.9501 - acc: 0.4667
# Epoch 5: saving model to /content/gdrive/My Drive/Colab_Models/cp_model_transformer_efficientnetB7_20240708_203425.h5
# 259/259 [==============================] - 2104s 8s/step - loss: 12.9501 - acc: 0.4667 - val_loss: 12.3706 - val_acc: 0.4858
# Epoch 6/15
# 244/259 [===========================>..] - ETA: 1:39 - loss: 12.6737 - acc: 0.4727

# %% [markdown]
# ## Check sample predictions

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize("coco/" + "train2014/" + sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()

# %% [markdown]
# ## End Notes
#
# We saw that the model starts to generate reasonable captions after a few epochs. To keep
# this example easily runnable, we have trained it with a few constraints, like a minimal
# number of attention heads. To improve the predictions, you can try changing these training
# settings and find a good model for your use case.
