# %%
# ! wget http://images.cocodataset.org/zips/train2014.zip
# ! wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# ! sudo apt-get install unzip
# ! unzip train2014.zip -d coco
# ! unzip annotations_trainval2014.zip -d coco

# %pwd
# %rm -r *
# %ls

# %%
# !pip install -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt
# Out:
# Requirement already satisfied: pycocotools in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (2.0.8)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 2)) (0.12.2)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 3)) (1.9.3)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 5)) (3.2.4)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (3.3.3)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (2.16.1)
# Requirement already satisfied: keras-preprocessing in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: rouge-score in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: keras-nlp in /opt/conda/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 10)) (0.14.4)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.10/site-packages (from seaborn->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 3)) (9.5.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (3.11.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (0.3.2)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (70.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from keras-nlp->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 10)) (2024.5.15)
# Requirement already satisfied: kagglehub in /opt/conda/lib/python3.10/site-packages (from keras-nlp->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 10)) (0.2.9)
# Requirement already satisfied: tensorflow-text in /opt/conda/lib/python3.10/site-packages (from keras-nlp->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 10)) (2.16.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (0.43.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from kagglehub->keras-nlp->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 10)) (4.66.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow->-r https://raw.githubusercontent.com/alexcalabrese/fdl_project/main/requirements.txt (line 7)) (2.1.5)

# %% [markdown]
# # Image Captioning

# %%
import pandas as pd
import os
import json


class DatasetLoader:

    def __init__(self, folder_name: str = "coco"):
        self.data = self.load_data(folder_name)

    def load_data(self, folder_name: str = "coco"):
        print("Loading data..")
        # Set the data folder
        data_folder = os.path.join(folder_name)

        # Create the directory if it doesn't exist
        if not os.path.exists(data_folder):
            os.makedirs(data_folder)

        # Path to the captions JSON file
        filename = os.path.join(data_folder, "annotations", "captions_train2014.json")

        # Read and parse the JSON file
        with open(filename, "r") as json_file:
            data = json.load(json_file)

        print("Data loaded succesfully!")

        return data

    def get_data_dict(self):
        return self.data

    def get_df_annotations(self):
        return pd.DataFrame(self.data["annotations"])

    def get_df_images(self):
        return pd.DataFrame(self.data["images"])

# %%
class KaggleDatasetLoader:

    def __init__(self, folder_name: str = "/kaggle/input/cocodatasetannotations"):
        self.data = self.load_data(folder_name)

    def load_data(self, folder_name: str = "/kaggle/input/cocodatasetannotations"):
        print("Loading data..")
        # Set the data folder
        data_folder = os.path.join(folder_name)

        # Path to the captions JSON file
        filename = os.path.join(data_folder, "annotations", "captions_train2014.json")

        # Read and parse the JSON file
        with open(filename, "r") as json_file:
            data = json.load(json_file)

        print("Data loaded successfully!")

        return data

    def get_data_dict(self):
        return self.data

    def get_df_annotations(self):
        return pd.DataFrame(self.data["annotations"])

    def get_df_images(self):
        return pd.DataFrame(self.data["images"])

# %% [markdown]
# ## Setup

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import re
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
import keras
from keras import layers
from keras.applications import efficientnet
from keras.layers import TextVectorization

keras.utils.set_random_seed(111)

# %% [markdown]
# ## Download the dataset
#
# We will be using the Flickr8K dataset for this tutorial. This dataset comprises over
# 8,000 images, that are each paired with five different captions.

# %%
# Desired image dimensions
IMAGE_SIZE = (299, 299)

# Vocabulary size
VOCAB_SIZE = 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 25

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 256
EPOCHS = 10
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## Preparing the dataset

# %%
import json
import os
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.xception import preprocess_input


def get_dataset_multisource():
    if 'COLAB_GPU' in os.environ:
        # Load the dataset
        print("[Detected Colab Environment] Loading dataset in /coco folder")
        dataset = DatasetLoader(file_path).load_data(folder_name=os.path.join(os.getcwd(), 'coco'))
    elif 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
        folder_path = "/kaggle/input/cocodatasetannotations/annotations_trainval2014"
        print('[Detected Kaggle Environment] Loading dataset in ' + folder_path)
        dataset = KaggleDatasetLoader(folder_path).load_data(folder_name=folder_path)
    else:
        dataset = DatasetLoader(file_path).load_data(folder_name=os.path.join(os.getcwd(), 'coco'))

    return dataset

dataset = get_dataset_multisource()
# print(os.path.join(os.getcwd(), 'coco'))

# %ls coco/train2014
# Out:
# [Detected Kaggle Environment] Loading dataset in /kaggle/input/cocodatasetannotations/annotations_trainval2014
# Loading data..
# Data loaded successfully!
# Loading data..
# Data loaded successfully!

# %%
# # Load the dataset
# dataset = DatasetLoader(file_path).load_data(folder_name=os.path.join(os.getcwd(), 'coco'))

# %%
def load_captions_data(dataset):
    text_annotations = []

    # Create a mapping from image_id to file_name
    image_id_to_file_name = {image["id"]: image["file_name"] for image in dataset["images"]}

    # Create a mapping from image_id to captions
    image_id_to_captions = {}
    for annotation in dataset["annotations"]:
        image_id = annotation["image_id"]
        caption = "<start> " + annotation["caption"] + " <end>"

        if image_id not in image_id_to_captions:
            image_id_to_captions[image_id] = []

        image_id_to_captions[image_id].append(caption)
        text_annotations.append(caption)

    # Create a combined dictionary with image file names and their corresponding captions
    file_name_to_captions = {
        image_id_to_file_name[image_id]: captions
        for image_id, captions in image_id_to_captions.items()
    }

    return file_name_to_captions, text_annotations


def train_val_split(caption_data, train_size=0.8, sample_size=0.001, shuffle=True):
    all_images = list(caption_data.keys())

    if shuffle:
        np.random.shuffle(all_images)

    # Calculate the number of samples based on the sample_size percentage
    num_samples = int(len(caption_data) * sample_size)

    # Reduce the dataset to the specified sample size
    all_images = all_images[:num_samples]

    train_size = int(len(all_images) * train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    return training_data, validation_data

# Load the dataset
captions_mapping, text_data = load_captions_data(dataset)

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping, sample_size=1.0)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  66226
# Number of validation samples:  16557

# %%
# captions_mapping

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use the `TextVectorization` layer to vectorize the text data,
# that is to say, to turn the
# original strings into integer sequences where each integer represents the index of
# a word in a vocabulary. We will use a custom string standardization scheme
# (strip punctuation characters except `<` and `>`) and the default
# splitting scheme (split on whitespace).

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %% [markdown]
# ## Building a `tf.data.Dataset` pipeline for training
#
# We will generate pairs of images and corresponding captions using a `tf.data.Dataset` object.
# The pipeline consists of two steps:
#
# 1. Read the image from the disk
# 2. Tokenize all the five captions corresponding to the image

# %%
# # append coco/train2014/ to all the keys of the dictionary



# Adjust the file paths based on the environment
if 'KAGGLE_KERNEL_RUN_TYPE' in os.environ:
    print('[Detected Kaggle Environment] Loading dataset in /kaggle/input/cocodatasetannotations folder')
    # Kaggle environment: Adjust the file paths to match Kaggle's dataset structure /kaggle/input/cocodatasetannotations/train2014/COCO_train2014_000000000009.jpg
    train_data = {
        os.path.join("/kaggle/input/cocodatasetannotations/train2014/train2014/", key): value
        for key, value in train_data.items()
    }
    valid_data = {
        os.path.join("/kaggle/input/cocodatasetannotations/train2014/train2014/", key): value
        for key, value in valid_data.items()
    }
else:
    train_data = {
        os.path.join("coco/train2014/", key): value for key, value in train_data.items()
    }

    valid_data = {
        os.path.join("coco/train2014/", key): value for key, value in valid_data.items()
    }
# Out:
# [Detected Kaggle Environment] Loading dataset in /kaggle/input/cocodatasetannotations folder

# %%
train_data
# Out:
# {'/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000539056.jpg': ['<start> A laptop computer that has a small keyboard for it. <end>',
#   '<start> A home office desk with a computer, cordless keyboard, mouse and cell phone. <end>',
#   '<start> A desk with a laptop and a keyboard and mouse. <end>',
#   '<start> A wireless Apple keyboard and mouse sit near an iPhone and an Apple laptop. <end>',
#   '<start> there is a coke glass next to a computer <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000523081.jpg': ['<start> This is a cluttered kitchen with moving boxes stacked. <end>',
#   '<start> the white room is filled with many boxes <end>',
#   '<start> A kitchen filled with boxes and clutter with lots of windows. <end>',
#   '<start> The room is crowded with a lot of boxes  <end>',
#   '<start> Boxes and other items line the floor of a kitchen. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000065971.jpg': ['<start> A container of food and a fork on a table. <end>',
#   '<start> Container with mashed potatoes, broccoli, salmon, and a plastic fork. <end>',
#   '<start> A dish has chicken, mashed potatoes, broccoli, and a fork on it.   <end>',
#   '<start> A styrofoam container hold a meal of barbecue chicken and broccoli. <end>',
#   '<start> A takeout box of salmon, mashed potatoes, and broccoli. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000131174.jpg': ['<start> A modern jet airliner on a snow edged runway  <end>',
#   '<start> The airplane is on the ground on the runway. <end>',
#   '<start> the front view of a white jet  on an airports runway <end>',
#   '<start> a large air plane on an air port run way <end>',
#   '<start> a plane that has just landed at the airport <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000393852.jpg': ['<start> A man is giving a shiny elephant some water.  <end>',
#   '<start> The man is giving the elephant water in its mouth through a water hose. <end>',
#   '<start> Large elephant being bathed and watered by his trainer. <end>',
#   '<start> A man is washing an elephants mouth with a hose. <end>',
#   '<start> An elephant drinking water from a person holding a hose. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000352317.jpg': ['<start> A man on a field swinging a baseball bat. <end>',
#   '<start> A baseball player swinging the bat at an incoming ball <end>',
#   '<start> A man holding a baseball bat over a baseball field. <end>',
#   '<start> A man in his baseball uniform is swinging his bat at a pitch while his coach is watching from the sidelines. <end>',
#   '<start> Baseball player is preparing his swing for the ball that is nearing. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000307835.jpg': ['<start> An old red truck parked next to a tall palm tree. <end>',
#   '<start> A man talking to a passenger in an old red pickup truck. <end>',
#   '<start> A man in white shirt standing next to a red pickup truck. <end>',
#   '<start> a person standing next to a red truck stopped on the side of a road <end>',
#   '<start> A red pick up truck on a street. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000389184.jpg': ['<start> A kite is seen flying high on a cloudy day. <end>',
#   '<start> A big kite that is being flown on the edge of the beach.  <end>',
#   '<start> A kite that is flying in the sky. <end>',
#   '<start> there are kites flying over the water at the beach <end>',
#   '<start> A kite is flying high over the ocean.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000579191.jpg': ['<start> A person holding a surfboard walking into the ocean. <end>',
#   '<start> Male surfer walking into the ocean surf carrying a long surfboard. <end>',
#   '<start> A man holding a surfboard looking at the waves. <end>',
#   '<start> A person holding a surfboard standing in the surf on a beach. <end>',
#   '<start> Man wading into the surf with a surfboard. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000064239.jpg': ['<start> The meal is prepared and ready on the table.  <end>',
#   '<start> A plate of food and a drink on a table. <end>',
#   '<start> A pizza that is sitting on a plate. <end>',
#   '<start> there is a plate of food with many toppings on it <end>',
#   '<start> A white plate topped with a pizza covered in toppings. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000146294.jpg': ['<start> A tennis player is reaching up with racquet to hit the ball. <end>',
#   '<start> The large audience watches the tennis player take a swing.  <end>',
#   '<start> A man who is holding a tennis racket. <end>',
#   '<start> a man reaching up to hit a tennis ball <end>',
#   '<start> A person serving a tennis ball on a tennis court <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000491244.jpg': ['<start> A woman holding a tennis racket on a tennis court. <end>',
#   '<start> A female with a tennis racquet on a tennis court. <end>',
#   '<start> A lady playing tennis on an outdoor tennis court during the day. <end>',
#   '<start> A woman in a short skirt holding a tennis racquet. <end>',
#   '<start> A woman standing in a tennis court holding a racket <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000354380.jpg': ['<start> A close up of a nice looking pizza with toppings. <end>',
#   '<start> Small pizza with zucchini and peppers sprinkled on it <end>',
#   '<start> The pizza is topped with cheese and vegetables. <end>',
#   '<start> We are looking at a sliced up pizza. <end>',
#   '<start> A personal sized pizza with different vegetable toppings. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000314190.jpg': ['<start> A group of men standing around a laptop computer. <end>',
#   '<start> A man is holding a laptop while another man looks at it. <end>',
#   '<start> a man checking out a laptop another man is holding  <end>',
#   '<start> Men standing with a laptop near a large crowd under a tent. <end>',
#   '<start> AFRICAN AMERICAN MEN UNDERNEATH A TENT LOOKING AT EACH OTHER <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000251493.jpg': ['<start> A tennis player stretches in preperation for a game. <end>',
#   '<start> A man holding a tennis racquet on a tennis court. <end>',
#   '<start> A man taking a swing at a tennis ball <end>',
#   '<start> A man jumping on a tennis court while holding a racquet. <end>',
#   '<start> A man on a tennis court with his racket raised up. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000480452.jpg': ['<start> A bus stopped on the side of a road next to a building. <end>',
#   '<start> A blue and yell bus in front of a building. <end>',
#   '<start> A bright blue and yellow bus is parked. <end>',
#   '<start> A Chesterfield bus at rest on a damp parking lot next to a building. <end>',
#   '<start> A public bus is parked outside of a building. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000409628.jpg': ['<start> Two men run backwards while one man jumps to catch a frisbee. <end>',
#   '<start> People in shirts with numbers on a grass field playing frisbee with tents set up on the side of the field. <end>',
#   '<start> A group of men are playing with a frisbee. <end>',
#   '<start> Two men in purple rush to catch a frisbee. <end>',
#   '<start> A group of young men playing a game of frisbee. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000460139.jpg': ['<start> A couple of motorcycle  parked next to each other. <end>',
#   '<start> A couple of dirty bikes outside of a shop <end>',
#   '<start> A person working in mechanical shop with two mopeds outside. <end>',
#   '<start> Two mopeds that look very old outside a shop. <end>',
#   '<start> A couple of motor bikes on a city street. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000223459.jpg': ['<start> Four jets flying parallel in the sky with smoking trailing behind. <end>',
#   '<start> Four airplanes are trailing smoke as they fly downwards. <end>',
#   '<start> A squadron of fighter jets flying through a blue sky. <end>',
#   '<start> a group of jets flying by in the blue sky <end>',
#   '<start> four planes flying in sync in the sky. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000043191.jpg': ['<start> A person holds a sign up by a train. <end>',
#   '<start> A parked passenger train on a sunny day. <end>',
#   '<start> A person is holding a pamphlet in front of a train. <end>',
#   '<start> Holding a train brochure in front of trains. <end>',
#   '<start> A ticket of the event is placed right next to a train.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000291592.jpg': ['<start> A man standing in a kitchen preparing food. <end>',
#   '<start> A man is cooking something in a pan on the stove. <end>',
#   '<start> Man preparing food on a cook top in a kitchen with a small dog at his feet. <end>',
#   '<start> a man with a beard is cooking and a black and gray dog  <end>',
#   '<start> A man in blue shirt in kitchen peppering food next to a dog. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000526980.jpg': ['<start> A very small bathroom stall with a toilet and several rolls of toilet paper. <end>',
#   '<start> A gray bathroom with a white toilet in it. <end>',
#   '<start> From doorway, view of a toilet in small room with metal shelf on wall with two rolls of toilet paper below on dispenser, and a shelf above toilet with four rolls of toilet paper on one side, stacked in twos. <end>',
#   '<start> a photo of a bath room with a toilet and toilet paper <end>',
#   '<start> Shot of a restroom with toilet on far side. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000319359.jpg': ['<start> a living room with a fireplace, large rug and a couch <end>',
#   '<start> A living room complete with a couch, chair and television. <end>',
#   '<start> A casual living room is on display in the sun. <end>',
#   '<start> A living room with big windows and a central fireplace. <end>',
#   '<start> This is a photo of a cozy looking family room with a fireplace. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000343162.jpg': ['<start> A large filed with kites flying over head in it. <end>',
#   '<start> a field full of people flying kites  <end>',
#   '<start> many large balloons in the shape of different animals, flowers and shapes floating in the air and being filled to fly in the air <end>',
#   '<start> A bunch of large kites in interesting shapes of people and animals are flying above as people watch from below. <end>',
#   '<start> A full view of some kites flying high in air.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000218253.jpg': ['<start> A bathroom with a floor toilet, seat and sink. <end>',
#   '<start> A bathroom scene with a chairing missing the center of the seat. <end>',
#   '<start> There is a chair with a hole underneath in the place on a toilet.  <end>',
#   '<start> A bathroom that has a sink and a hole in the floor. <end>',
#   '<start> a black chair a white floor toilet  and a curtain <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000365258.jpg': ['<start> A sandwich cut in half on a white plate with a side of salad and a fork and knife wrapped in a napkin. <end>',
#   '<start> A sandwich on a white plate with utensils rapped in a napkin and lettuce on the side. <end>',
#   '<start> A sandwich on a plate on a table.  <end>',
#   '<start> The sandwich and silverware are setting on the plate. <end>',
#   '<start> A sandwich is layed out on a plate <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000287187.jpg': ['<start> a person jumping a dirt bike in the air <end>',
#   '<start> A person in biking gear doing a trick on a dirt bike. <end>',
#   '<start> a motor-cross rider making a big jump in the air  <end>',
#   '<start> A person is up in the air while riding a motorcycle. <end>',
#   '<start> an image of a guy doing tricks  on his bike <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000368148.jpg': ['<start> Replica clock tower building on the pavement of a pedestrian area. <end>',
#   '<start> A tower with clock at the top in the middle of a city street <end>',
#   '<start> Ben clock made as a model with bystanders walking by. <end>',
#   '<start> A large replica of the Big Ben clock tower. <end>',
#   '<start> A clock tower sitting in a square in a city  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000176316.jpg': ['<start> there are many elephants and baby elephants that are walking together <end>',
#   '<start> Elephants are standing on a barren plain, with two looking at the camera. <end>',
#   '<start> An elephant grazing on grass on a sunny day <end>',
#   '<start> a baby elephant standing by a bigger elephant <end>',
#   '<start> An elephant with her child amongst their herd in the wild. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000566955.jpg': ['<start> a smart phone is plugged into a cable <end>',
#   '<start> A hand that is holding on to a cellphone. <end>',
#   '<start> Someone is holding their tablet connected to a surge protector. <end>',
#   '<start> A person with a cell phone connected to a cord. <end>',
#   '<start> A cell phone plug in and a surge protector and a blue piece of furniture. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000100337.jpg': ['<start> A long haired horse staring at the ocean. <end>',
#   '<start> A view of a horse with a long mane appearing to look at a body of water with green inlets. <end>',
#   '<start> A horse with a long mane standing on the rocks near the water <end>',
#   '<start> A brown horse with a long mane near the sea. <end>',
#   '<start> A horse with a long main standing by some water <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000406326.jpg': ['<start> A dog is laying on a bed in a bedroom. <end>',
#   '<start> A large black bed with a large black dog sleeping on top of it. <end>',
#   '<start> A black dog laying on a bed with black bedding <end>',
#   '<start> A black lab lays on a bed with a black tablecloth.  <end>',
#   '<start> Black dog laying on a bed with a black blanket. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000323374.jpg': ['<start> Two airplanes sitting on top of an airport tarmac. <end>',
#   '<start> A small engine plane with a windshield covering on it. <end>',
#   '<start> The plane is being prepared for long term storage. <end>',
#   '<start> Single engines planes parked at an airport near a mountain. <end>',
#   '<start> A plane that is on the ground in the airport. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000183218.jpg': ['<start> there are two male cooks in the kitchen cooking <end>',
#   '<start> Two gentleman are in the kitchen doing their jobs.  <end>',
#   '<start> A couple of people standing in a small kitchen. <end>',
#   '<start> A couple of men standing in a kitchen as one checks a stove. <end>',
#   '<start> Two men in aprons behind the counter of a commercial kitchen. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000257063.jpg': ['<start> A bedroom with large windows with curtains,a large bed and a television in a corner. <end>',
#   '<start> A tv is mounted in the corner of a bedroom with blue decor. <end>',
#   '<start> A bedroom with the drapes open, and a television on. <end>',
#   '<start> A TV on in the corner of a large bedroom trimmed in blue. <end>',
#   '<start> A tab le inside of a room with a TV mounted in the corner. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000166967.jpg': ['<start> The bird is nesting on top of the church building.  <end>',
#   '<start> Birds sit in a nest on top of a building tower.  <end>',
#   '<start> A bird in a nest on the top of a bell tower. <end>',
#   '<start> A bell tower with a bird nest perched on the top with a bird standing on it  <end>',
#   '<start> A bird sitting on top of a large nets on top of a bell tower. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000405729.jpg': ['<start> A white toilet bowl in  a bathroom with big red tiles <end>',
#   '<start> A white toilet sitting in a bathroom next to a blue pipe. <end>',
#   '<start> a simple, normal toilet with the lid closed <end>',
#   '<start> A toilet in a washroom surrounded by cleaning supplies and a pipe. <end>',
#   '<start> A picture of a white toilet in a bathroom <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000199381.jpg': ['<start> A baseball player standing in a position to pitch a ball. <end>',
#   '<start> a person that is standing up with a glove on <end>',
#   '<start> baseball player throwing a pitch by a brick wall <end>',
#   '<start> A baseball player pitching the ball on the field.  <end>',
#   '<start> His stance shows him bracing to pitch a fast ball. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000350885.jpg': ['<start> A CSX train stopped on a street-level track <end>',
#   '<start> A picture of a train that is on the track. <end>',
#   '<start> A large locomotive on the tracks going through town. <end>',
#   '<start> A train in the middle of a town. <end>',
#   '<start> A large train is coming down the tracks <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000522868.jpg': ['<start> People are feeding an elephant over a guard rail. <end>',
#   '<start> Side view of a man standing by and elephant with trunk raised to two women standing together on deck at top of stairs, outside. <end>',
#   '<start> some people an elephant steps bushes and trees <end>',
#   '<start> an elephant sticking its trunk by some women on a balcony <end>',
#   '<start> Elephant interacting with women near parking lot. area. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000111000.jpg': ['<start> A group of young men playing a game of frisbee in a park. <end>',
#   '<start> a group of people jumping to catch a frisbee in the air <end>',
#   '<start> Four guys are playing with a Frisbee outdoors.  <end>',
#   '<start> Three men jumping for a Frisbee in the park, with a fourth man running to join them. <end>',
#   '<start> Three men jump in an attempt to catch a Frisbee. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000375531.jpg': ['<start> A person and a dog on a small boat. <end>',
#   '<start> A man sitting on top of a bat with a dog on front of it. <end>',
#   '<start> there is a man and a dog riding on a small raft <end>',
#   '<start> A man is on his boat with his dog.  <end>',
#   '<start> A man and his dog are on a small boat. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000537041.jpg': ['<start> a close up of a dog on a beach with his tongue out <end>',
#   '<start> A black-and-white dog, tongue out, looking into the camera. <end>',
#   '<start> A white and black dog holds out his little pink tongue. <end>',
#   '<start> A close shot of a dog with its tongue out.  <end>',
#   '<start> A black and white dog panting with his tongue hanging out. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000480474.jpg': ['<start> A group of people stand next to a sign on the snow. <end>',
#   '<start> Snow boarders and skiers at the top of a slope. <end>',
#   '<start> Skiers work on their skis on a mountain top. <end>',
#   '<start> A group os people are hanging out on a snowy field. <end>',
#   '<start> Many people in their ski gear are scattered around.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000011129.jpg': ['<start> A female tennis player in a action on the court. <end>',
#   '<start> A woman leans in to hit a tennis ball during a match. <end>',
#   '<start> A women who is holding a tennis racket playing tennis. <end>',
#   '<start> a woman running up to a tennis ball to hit it  <end>',
#   '<start> A female tennis player in action in the corner of the court.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000182275.jpg': ['<start> A man and woman are shaving wool from a sheep.  <end>',
#   '<start> A man in a white cowboy hat sheering a sheep. <end>',
#   '<start> People grooming animals in a warehouse full of farm animals. <end>',
#   '<start> A man standing up cutting a sheeps wool. <end>',
#   '<start> A man in an animal pen is shaving a white sheep. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000404502.jpg': ['<start> A white horse standing between two brown horses. <end>',
#   '<start> A white horse and two brown ones in a pen. <end>',
#   '<start> A herd of horses standing in a dirt horse coral. <end>',
#   '<start> Several ponies are standing around near a fence. <end>',
#   '<start> A brown pony next to a white horse and brown horse.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000449004.jpg': ['<start> A white semi trucked wrecked and sitting on the side of a road. <end>',
#   '<start> Semi truck off roadway after accident with emergency personnel nearby. <end>',
#   '<start> Several people and police standing near a truck that is on the side of the road. <end>',
#   '<start> a big truck parked in the ditch next to a highway full of traffic <end>',
#   '<start> This is a picture of a tractor off the side of the road. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000515662.jpg': ['<start> A tray with a pile of hot dogs and a couple of baskets of chili cheese potatoes. <end>',
#   '<start> Some very tasty looking hot dogs and some drinks. <end>',
#   '<start> there are many hot dogs and two plates of fries on the table  <end>',
#   '<start> Two sodas, four hot dogs, and two orders of cheese fries are on a table.  <end>',
#   '<start> The hotdogs are ready on the tray ready to be eaten. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000217487.jpg': ['<start> A banquet hall filled with people eating a meal together. <end>',
#   '<start> A crowd of people sit in rows at long tables with glasses, plates and napkins in front of them. <end>',
#   '<start> A group of men and women sitting down for a formal dinner.  <end>',
#   '<start> people all eating together and pretending to like each other <end>',
#   '<start> People dressed up in formal clothing for a banquet dinner. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000525467.jpg': ['<start> A man riding a skateboard up some stone steps next to a metal fence. <end>',
#   '<start> A man skateboarding on a metal bar near steps <end>',
#   '<start> The skateboarder performs a trick against the edge of a stair. <end>',
#   '<start> A skateboarder is in mid air performing a trick. <end>',
#   '<start> A man skateboarding on the steps at a lakeside park. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000082255.jpg': ['<start> A a man wearing a red neck tie around his neck. <end>',
#   '<start> A gray haired man is wearing a blue shirt and has a tie draped around his neck. <end>',
#   '<start> A man wearing glass wearing a tie around his kneck.  <end>',
#   '<start> an old man with untied tie on is neck <end>',
#   '<start> Man in blue shirt with red tie standing near doorway. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000058627.jpg': ['<start> A young child holding  a bat near a t ball. <end>',
#   '<start> A young girl standing with a bat and a ball on a stand. <end>',
#   '<start> A young child is holding a bat next to a t ball stand. <end>',
#   '<start> A little child on a baseball field playing t-ball. <end>',
#   '<start> Young girl practicing hitting a baseball off a batting tee. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000449138.jpg': ['<start> A boat floating out on water in the middle of a lake. <end>',
#   '<start> A work boat floating in the middle of a vast lake bounded by mountains. <end>',
#   '<start> A boat floating on a body of water. <end>',
#   '<start> A boat is in the middle of the water near mountains. <end>',
#   '<start> A boat with equipment on it riding through a waterway. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000016673.jpg': ['<start> A tall giraffe standing next to a rock mound. <end>',
#   '<start> Two giraffe are eating in a large field. <end>',
#   '<start> an image of two giraffes in the wilderness <end>',
#   '<start> two giraffes on a field with trees and rock formations <end>',
#   '<start> Two giraffes are standing in a maintained yard. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000135065.jpg': ['<start> A tan and black doughnut with white marshmallows and a pink smiley face. <end>',
#   '<start> A felt sewn donut held by a pair of hands. <end>',
#   '<start> The toy doughnut has a face sown on it.  <end>',
#   '<start> Someone holding a fake hand made  donut with sprinkles. <end>',
#   '<start> Hands squeezing a fabric circle made to resemble a donut. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000322427.jpg': ['<start> A pallet is laid on the wooden floor in the apartment. <end>',
#   '<start> A doggie bed on the floor in the doorway. <end>',
#   '<start> The living room is clean and empty from people.  <end>',
#   '<start> An empty living room that has wood floors. <end>',
#   '<start> A floor view of a wooden floor with bedding on it <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000503832.jpg': ['<start> a couple of giraffes are in a pin with zebras <end>',
#   '<start> Their are giraffes and zebras are visited by people. <end>',
#   '<start> A group of people looking at a group of giraffes and zebras in an enclosure. <end>',
#   '<start> People are looking at giraffes and zebras in a zoo.   <end>',
#   '<start> Some very pretty giraffes by a bunch of people. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000439346.jpg': ['<start> A man with a baby in his arms, holds a hair dryer. <end>',
#   '<start> A man holding a bay and a hair dryer. <end>',
#   '<start> A man stands holding his baby and a hair dryer. <end>',
#   '<start> A man holding a baby in one arm and a showerhead in another. <end>',
#   '<start> The man is standing in the hallway holding an infant and a hairdryer. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000279175.jpg': ['<start> A man wearing a black hair while having a beard. <end>',
#   '<start> A well dressed man walks by others who are dining. <end>',
#   '<start> a man in a top hat sits at a table  <end>',
#   '<start> A man in a derby hat is standing in a large room. <end>',
#   '<start> A well dressed man that is wearing a hat is looking away.. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000369285.jpg': ['<start> A man riding a wave on top of a surfboard. <end>',
#   '<start> Person who is surfing on a wave  <end>',
#   '<start> A surfer rides a surfboard in the ocean waves. <end>',
#   '<start> A person is riding a wave on a surfboard. <end>',
#   '<start> A surfer riding a large wave on a surfboard. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000171208.jpg': ['<start> A plane flying over a group of horses near water. <end>',
#   '<start> Brown horses eating tall grass beside a body of water.  <end>',
#   '<start> A group of horses grazing on dry grass next to a stream. <end>',
#   '<start> Horses grazing in a dry pasture by an airport <end>',
#   '<start> The horses are grazing in the tall grass near the canal. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000544875.jpg': ['<start> Two toilet bowls sitting side by side in a hallway. <end>',
#   '<start> Two toilets are shown next to each other on a floor. <end>',
#   '<start> Two toilets, one with a brown lid and one with a white one <end>',
#   '<start> Two white toilets in a alley with a tiled wall. <end>',
#   '<start> Toilet bowls sitting in the middle of a room <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000173791.jpg': ['<start> A baseball player getting ready to hit a ball. <end>',
#   '<start> A player is at bat in a baseball game. <end>',
#   '<start> Baseball player at bat, about to deliver swing <end>',
#   '<start> A batter posed to swing his bat with a catcher and umpire behind him. <end>',
#   '<start> a man is holding a baseball bat on a field <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000120118.jpg': ['<start> A woman is walking the horse on the leash <end>',
#   '<start> A woman is leading a horse from the stable. <end>',
#   '<start> Large brown horse being walked by a woman down the street. <end>',
#   '<start> A woman leading a brown horse down a street. <end>',
#   '<start> a woman walking a brown horse down the road  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000256285.jpg': ['<start> Fluffy white teddy bear sitting on a old brown chair. <end>',
#   '<start> A white stuffed teddy bear sitting on a couch. <end>',
#   '<start> A stuffed white teddy bear sitting on a couch <end>',
#   '<start> A stuffed teddy bear sitting in the corner of a couch. <end>',
#   '<start> A white teddy bear sitting in a chair <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000278301.jpg': ['<start> a man wearing a colorful suit smiling at the camera <end>',
#   '<start> An old man with white hair wearing glasses sitting down in a colorful room. <end>',
#   '<start> A man in a colorful suit jacket smiling. <end>',
#   '<start> A old man in a werid suit sitting down. <end>',
#   '<start> A blond guy in a snazzy suit smiles in a room with brightly wild wallpaper.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000175820.jpg': ['<start> a cat on a table near a emote control  <end>',
#   '<start> A gray and black cat sitting on top of a table looking at a dog. <end>',
#   '<start> a cat is sitting on a couch in a room <end>',
#   '<start> The cat is looking down at the remote control next to it.  <end>',
#   '<start> a black dog and a white black and gray cat <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000286703.jpg': ['<start> A pair of shoe sit underneath a bed. <end>',
#   '<start> The sun is shining from under a bed with two shoes. <end>',
#   '<start> A pair of shoes is sitting under a bed. <end>',
#   '<start> Pair of shoes under a bed with a bin and bag. <end>',
#   '<start> A pair of shoes sitting under a bridge.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000047173.jpg': ['<start> a young person and an older person playing nintendo wii <end>',
#   '<start> A PHOTO IMAGE OF TWO WOMEN PLAYING THE WII TOGETHER <end>',
#   '<start> A mother and daughter are playing Wii together. <end>',
#   '<start> Two women in a bedroom playing the Nintendo Wii. <end>',
#   '<start> A Mother and daughter are gleefully playing Nintendo Wii. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000098720.jpg': ['<start> Three zebras standing in the dirt near a tree. <end>',
#   '<start> a bunch of zebras stand in a contained area  <end>',
#   '<start> Three zebras standing underneath a tree, and beside a wall. <end>',
#   '<start> A concrete wall and a smaller slat fence border an environment with logs and a single tree, surrounded by several zebras, including one that is nuzzling another.  <end>',
#   '<start> a number of zebras near one another near a tree <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000194247.jpg': ['<start> A laptop sitting on a table in a library. <end>',
#   '<start> A laptop on a table with textbooks and papers.  <end>',
#   '<start> Someone is studying at a table inside the library. <end>',
#   '<start> Laptop is open in table with word document up and notebook with papers out in front of it <end>',
#   '<start> A laptop, books, and papers on a table in a library. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000098257.jpg': ['<start> A bathroom has a toilet, a shower, and a closet. <end>',
#   '<start> A shower with a towel hanging over it is featured. <end>',
#   '<start> the bathroom has a glass tub in it  <end>',
#   '<start> This dimly lit bathroom has a shower and a nice closet. <end>',
#   '<start> Towel on glass shower door near toilet on tile floor. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000147466.jpg': ['<start> The young children are doing crafts at the dining room table.  <end>',
#   '<start> Two boy and one girl at a kitchen table playing. <end>',
#   '<start> Some small children gathered at a dining table. <end>',
#   '<start> Three children sit at a table together doing crafts <end>',
#   '<start> A group of small children standing around a table covered with food. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000051198.jpg': ['<start> a street light in front of big ben in london  <end>',
#   '<start> A green lamppost with the Houses of Parliament in the background. <end>',
#   '<start> a outdoor lamp sits in front of a tower with a clock on it  <end>',
#   '<start> a green and gold light post next to a gothic building <end>',
#   '<start> A clock tower near an elegant set of lights. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000287877.jpg': ['<start> A group of people who are looking at a building. <end>',
#   '<start> People are standing around in a parking lot.  <end>',
#   '<start> A group of people standing in a parking lot. <end>',
#   '<start> The tour guide points out the two clocks on the building. <end>',
#   '<start> People bunched together near tracks, waiting for train <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000294990.jpg': ['<start> A green computer chair in front of the computer desk, near a bed.  <end>',
#   '<start> A room is shown with a bed and chairs. <end>',
#   "<start> A view of a modern apartment dwelling and it's furnishings. <end>",
#   '<start> A bedroom with an office including a bed and desk with key board and monitor.  <end>',
#   '<start> a room, with a desk and chair and large windows <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000060769.jpg': ['<start> A young man standing next to a kitchen counter. <end>',
#   '<start> A man standing in a kitchen petting a cat sitting on a counter. <end>',
#   "<start> A man petting a cat that's sitting on a kitchen counter. <end>",
#   '<start> A man standing in the kitchen and petting his cat. <end>',
#   '<start> A man rubs the back of a cat standing on a counter <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000525104.jpg': ['<start> A double decker bus driving on the street outside. <end>',
#   '<start> a double decker bus with a lot of deocrations on it  <end>',
#   '<start> a red bus moving along the street at the zebra crossing <end>',
#   '<start> Double decker bus with airport control tower in background.  <end>',
#   '<start> A large bus drives down a corner street.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000327573.jpg': ['<start> two boys through a frisbee during a game on a field <end>',
#   '<start> A group of young people playing a game of frisbee. <end>',
#   '<start> A few young me in a park playing with a Frizbee. <end>',
#   '<start> The man are playing a game of Frisbee outside in the field.  <end>',
#   '<start> Young men are playing frisbee in a park. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000351091.jpg': ['<start> a couple of buses that are being driven down the road <end>',
#   '<start> Multiple double decker buses traveling down a city street. <end>',
#   '<start> A double decker bus traveling down the street. <end>',
#   '<start> Three double decker buses travelling on a street in the same direction. <end>',
#   '<start> A double decker bus driving on a street. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000087756.jpg': ['<start> A locomotive traveling past a small shack next to a forest. <end>',
#   '<start> A train is riding on a railroad track <end>',
#   '<start> Steam locomotive traveling on a track near a forest. <end>',
#   '<start> A train is approaching on a track next to a building. <end>',
#   '<start> A train with a lot of steam coming out of the engine. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000068211.jpg': ['<start> A baseball player balancing the ball on his left hand. <end>',
#   '<start> A baseball catcher holds the ball on top of his hand. <end>',
#   '<start> Male baseball player rolling a baseball down his hand.  <end>',
#   '<start> A pitcher balancing a baseball on the back of his hand.  <end>',
#   '<start> A baseball player catching the ball in an odd manner. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000105472.jpg': ['<start> men and women outside playing a game of frisbee. <end>',
#   '<start> A group of people paying frisbee on a field. <end>',
#   '<start> A group of people in the middle of a Frisbee game. <end>',
#   '<start> a person jumping to catch a frisbee on a field <end>',
#   '<start> A group of young people play Frisbee on a field. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000523795.jpg': ['<start> Two giraffes on a grassy field during the day. <end>',
#   '<start> two giraffes standing in an open field in the wild <end>',
#   '<start> Two giraffe standing next to each other on a field. <end>',
#   '<start> A couple of giraffe walking away from a tree covered with fencing. <end>',
#   '<start> Two giraffes stand in the grass near a tall tree. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000336770.jpg': ['<start> Commuter train coming into station platform on sunny day. <end>',
#   '<start> a blue train is coming down some tracks <end>',
#   '<start> A train coming around a curve by a sidewalk  <end>',
#   '<start> The passenger train drives around the curve of the tracks. <end>',
#   '<start> The train is going down the railroad tracks. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000100439.jpg': ['<start> Men playing a bowling video game in an open living room. <end>',
#   '<start> People in a living room painted white playing video games. <end>',
#   '<start> A group of men standing around a room next to a TV. <end>',
#   '<start> Some people in a living room playing a video game. <end>',
#   '<start> A group of people playing a game with remote controllers. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000565886.jpg': ['<start> The room is clean and empty of people. <end>',
#   '<start> A living room is shown with leather couches. <end>',
#   '<start> A table that is sitting in front of a couch. <end>',
#   '<start> A yellow room with a fireplace, flat screen television, and brown sofa. <end>',
#   '<start> A large living room  has a fireplace, a leather sofa, and a flat-screen TV. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000114421.jpg': ['<start> A woman in a green shirt models an orange umbrella. <end>',
#   '<start> A woman holding an orange umbrella in a room. <end>',
#   '<start> A woman in a bedroom is holding an open red umbrella. <end>',
#   '<start> A woman smiles while holding a red umbrella over a stack of clothing. <end>',
#   '<start> A smiling woman holding an umbrella in front of a bed. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000068238.jpg': ['<start> A grey and white cat sleeping on a wooden bench. <end>',
#   '<start> a close up of a cat laying on a bench <end>',
#   '<start> A cat is curled up on a wooden bench by himself. <end>',
#   '<start> a cat laying on a wooden bench sleeping contently <end>',
#   '<start> There is an adult cat that is sleeping <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000098232.jpg': ['<start> a number of small boats near a body of water  <end>',
#   '<start> A beach line with lots of boats next to a lake. <end>',
#   '<start> There is a full view of an outdoor area and it is nice.\n <end>',
#   '<start> Birds rest on the canoes that are sitting on the beach.  <end>',
#   '<start> A group of canoes on the edge of the water. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000510434.jpg': ['<start> The woman is surfing on her surfboard.  <end>',
#   '<start> A guy in the water recording another person on a surfboard riding a wave. <end>',
#   '<start> A woman that is standing on a surfboard in the water. <end>',
#   '<start> A PERSON IS RIDING A WAVE AND HAS SOMEONE RECORDING IT <end>',
#   '<start> A woman riding a wave on top of a surfboard. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000362642.jpg': ['<start> Tall clock tower with black, cloudy skies next to a large wall. <end>',
#   '<start> A large clock tower siting under cloudy skies. <end>',
#   '<start> A tall clock tower with windows at night. <end>',
#   "<start> A very tall clock tower with a clock on each of it's sides. <end>",
#   '<start> A view of a rall brick building at night with a clock on it. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000040283.jpg': ['<start> The suitcase has notebooks on the stack of folded clothes. <end>',
#   '<start> this is a bag of luggage on a bed <end>',
#   '<start> An opened suit case filled with clothes and a notepad. <end>',
#   '<start> Large tote bag sitting on a table filled with clothing and books. <end>',
#   '<start> A bag of luggage filled with lots of stuff. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000460996.jpg': ['<start> A woman is fixing the little boys tie <end>',
#   "<start> A woman is adjusting a young boy's tie. <end>",
#   '<start> A little boy wearing a suit and tie and looking handsome. <end>',
#   '<start> The young child is dressed up in a suit for the event.  <end>',
#   '<start> A woman fixes the tie on the suit of a small child. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000280532.jpg': ['<start> A road sign in front of a cloudy blue sky. <end>',
#   '<start> Street sign representing intersection of Shadyside and Eight Mile Roads. <end>',
#   '<start> a street sign for eight mile and shadyside <end>',
#   '<start> Street signs showing the intersection of Eight Mile and Shadyside <end>',
#   '<start> A sign at the corner of Eight Mile and Shadyside. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000250401.jpg': ['<start> A young man laying in a hammock, while holding a black umbrella. <end>',
#   '<start> Man indoors in a hammock holding an umbrella. <end>',
#   '<start> A man with a soccer jersey on and holding an umbrella in a hammock. <end>',
#   '<start> a male in a blue hammock with a black umbrella <end>',
#   '<start> A man in a hammock holding an umbrella over his head. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000517998.jpg': ['<start> A man sits at the computer and uses the mouse. <end>',
#   '<start> A man is surfing the internet on his laptop. <end>',
#   '<start> A guy sits at a table working on a computer.  <end>',
#   '<start> A man is looking at a laptop computer. <end>',
#   '<start> A man with long hair using a laptop computer. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000252411.jpg': ['<start> A small bathroom with vanity, sink and mirrors. <end>',
#   '<start> A white bathroom sink sitting under two mirrors. <end>',
#   '<start> a bathroom with mirrors a counter top and sink  <end>',
#   '<start> A sink not in a fixture in a large bathroom. <end>',
#   '<start> The sink in the bathroom is a large unusual bowl. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000484619.jpg': ['<start> a table with plates of food with people near by <end>',
#   '<start> A woman and some kids at a table. <end>',
#   '<start> Woman and two children having a picnic inside a large tent. <end>',
#   '<start> some people are standing around a table with food and drinks <end>',
#   '<start> A mother and her children enjoying a picnic in a train. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000386162.jpg': ['<start> A man bent over at the waist holding a tennis racket. <end>',
#   '<start> A man holding a racquet standing near another man. <end>',
#   '<start> A couple of men bent over on a tennis court holding racquets. <end>',
#   '<start> A man with a tennis racquet standing in a defensive stance. <end>',
#   '<start> A male tennis player waiting for the ball. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000219059.jpg': ['<start> Dark and light colored cat lying on desktop. <end>',
#   '<start> A cat sleeping in front of a computer. <end>',
#   '<start> a black and white cat is sitting between a keyboard and a monitor <end>',
#   '<start> A cay laying between a computer keyboard and a monitor. <end>',
#   '<start> An cat is sitting between a computer and keyboard. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000154667.jpg': ['<start> A guy standing on a surf board with a big paddle. <end>',
#   '<start> A man balances on a paddle board while riding a wave. <end>',
#   '<start> a man is riding a surfboard out on a wave <end>',
#   '<start> The man surfs on a wave with a paddle. <end>',
#   '<start> Man holding paddle in air on surfboard with patch in corner <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000237273.jpg': ['<start> A man is standing in front of joined horses <end>',
#   '<start> A man in winter clothing standing next to a team of draft horses. <end>',
#   '<start> A man in a warm winter hat and coat stands next to two white horses that have reigns and bridles on. <end>',
#   '<start> A man in a hat and coat next to horses <end>',
#   '<start> The man with blue jacked and yellow hat stands next to the white horses <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000110514.jpg': ['<start> a kid that is eating a round doughnut <end>',
#   '<start> A boy smiles as he spreads chocolate onto his bagel. <end>',
#   '<start> A little boy is spreading something on his bagel. <end>',
#   '<start> A smiling boy spreading Vegemite on a bagel at a cafe <end>',
#   '<start> A boy grabbing a donut with tongs that are silver <end>'],
# ...
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000011953.jpg': ['<start> A bed with blue comforter and laptop on it <end>',
#   '<start> A neatly made bed sits empty, a laptop computer near its pillows. <end>',
#   '<start> close-up detailed image of linens on a clean bed <end>',
#   '<start> A closed laptop sitting on a pristinely made bed. <end>',
#   '<start> A supple and soft blanket adorns this perfectly made bed. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000220654.jpg': ['<start> A large truck made for hauling loads is stopped at a stop sign. <end>',
#   '<start> A dirty dump truck is by a stop sign. <end>',
#   '<start> A dump truck sits by a stop sign. <end>',
#   '<start> A large dump truck on the side of the road next to a stop sign. <end>',
#   '<start> A giant dump truck pausing at a stop sign. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000539197.jpg': ['<start> A bicycle with wagon propped against a building. <end>',
#   '<start> A bike parked on the side of a building in the snow. <end>',
#   '<start> A bicycle pulling a trailer in the snow leaning against a brick building. <end>',
#   '<start> a bike leaning on the side of a house with a cart attachced to the back of it <end>',
#   '<start> A red bicycle parked up against a brick building in the snow. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000105921.jpg': ['<start> Two people in swimwear with a surf board. <end>',
#   '<start> A couple in bathing suits holds a surfboard while there is snow on the ground. <end>',
#   '<start> Man and woman in bathing suits and santa hats holding a blue surf board in the snow <end>',
#   '<start> The couple is posing in the snow with a surfboard, dressed in their bathing suits with Santa hats and weather boots. <end>',
#   '<start> A man and woman standing in the snow in bathing suit, Santa hats, and boots, holding a surfboard <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000281789.jpg': ['<start> two zebras grazing in a field during the day. <end>',
#   '<start> Two zebras grazing in a large grassy field. <end>',
#   '<start> A couple of zebra standing in a grass field. <end>',
#   '<start> Two giraffes eating grass on a grassy field. <end>',
#   '<start> two zebras standing in a grassy field grazing <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000111017.jpg': ['<start> A person is skiing and did a jump in the air.  <end>',
#   '<start> a person on skis jumping in the air  <end>',
#   '<start> A man on skis doing a flip in the air. <end>',
#   '<start> A person flipping upside down on a pair of skis. <end>',
#   '<start> A person on skis performing a somersault with a twist. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000386927.jpg': ['<start> Three teddy bears are sitting next to two wine bottles. <end>',
#   '<start> Three teddy bears on a chair with two wine bottles and a wine glass.  <end>',
#   '<start> Stuffed animals on a couch with wine bottles and a wine glass. <end>',
#   "<start> Bears laid out on the chair to look like they've been drinking with wine glass and bottles <end>",
#   '<start> I am unable to see an image above. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000368040.jpg': ['<start> A man on the beach holding a blue surf board <end>',
#   '<start> a man holding a surfboard on his back  <end>',
#   '<start> A man standing on top of a beach carrying a blue surfboard. <end>',
#   '<start> Man carrying his surfboard and backpack on the beach. <end>',
#   '<start> A man is walking down a beach with a surfboard on his back. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000449808.jpg': ['<start> A group of men standing next to each other on a tennis court. <end>',
#   '<start> A group of people are standing with tennis rackets on the court. <end>',
#   '<start> Tennis players standing by the net posing for a picture. <end>',
#   '<start> A group of people standing by the net in a tennis court. <end>',
#   '<start> A group of tennis players posing with each other on a tennis court. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000469644.jpg': ['<start> a spotted cat pawing at a strange light <end>',
#   '<start> A cat pawing at a lighting fixture.  <end>',
#   '<start> A curious adult cat paws at a light fixture. <end>',
#   '<start> A cat is reaching for a white umbrella. <end>',
#   '<start> Mischievous cat playing with an umbrella with its paw. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000436468.jpg': ['<start> A person laying in bed in front of a small tv. <end>',
#   '<start> Person laying underneath white sheets looking at a television.  <end>',
#   '<start> a person is in bed and watching television <end>',
#   '<start> A person laying under the sheets watching television. <end>',
#   '<start> A person in bed with white sheets watching tv. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000252994.jpg': ['<start> A man riding a skateboard down a walkway. <end>',
#   '<start> A skateboarder is skating outdoors as a bicyclist looks on.  <end>',
#   '<start> A guy is skateboarding in a skate park. <end>',
#   '<start> A man standing on a skateboard with a boy on bike behind him. <end>',
#   '<start> A young boy rides his skateboard on a street course.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000118330.jpg': ['<start> A table with some chairs and a large umbrella. <end>',
#   '<start> A wooden table surrounded with lots of chairs. <end>',
#   '<start> A long table and chairs covered by umbrellas outdoor. <end>',
#   '<start> a long wooden table with chairs around it <end>',
#   '<start> Long umbrella covered dining tables on a patio <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000217143.jpg': ['<start> A beach filled with people and umbrellas next to the ocean. <end>',
#   '<start> A view of a beach on a bright day. <end>',
#   '<start> A lifeguard station on a busy beach with swimmers <end>',
#   '<start> People swimming in the ocean on a clear day. <end>',
#   '<start> A life guard stand and brightly colored umbrellas and blankets on a beach <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000127353.jpg': ['<start> a building with a white clock and some tree branches <end>',
#   '<start> A very tall church with a massive clock tower. <end>',
#   '<start> An old Gothic style church with a clock in the tower. <end>',
#   '<start> A large concrete building with a clock above the windows. <end>',
#   '<start> A very unique, castle-like building has a small clock.  <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000523349.jpg': ['<start> A group of snow skiers are on top of a mountain. <end>',
#   '<start> This is a picture of a popular sking mountain. <end>',
#   '<start> Two snow patrol people at the bottom of a snow hill. <end>',
#   '<start> A bunch of people taking in a day snowboarding. <end>',
#   '<start> snowboarders stand station to hold up other boards <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000007677.jpg': ['<start> A pair of scissors inside of a box. <end>',
#   '<start> A pair of shears in a box that is partially open. <end>',
#   '<start> A pair of scissors in a small box labeled pinking shears. <end>',
#   '<start> some scissors brand new still all boxed up <end>',
#   '<start> A pair of pinking shears sits in its box. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000401583.jpg': ['<start> an elephant standing on the ground with a man on his back <end>',
#   '<start> there is a man wearing green and riding a elephant <end>',
#   '<start> A man sitting on top of an elephant that is standing in the mud.  <end>',
#   '<start> An elephant is standing on a dirt patch with someone on its back.  <end>',
#   '<start> An elephant walking down a dirt road next to a hillside. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000286388.jpg': ['<start> A yellow street sign warns of a hump in the road. <end>',
#   '<start> A street sign indicating a hump in the road. <end>',
#   '<start> A leaning "hump" sign on the side of a two lane road. <end>',
#   '<start> A sign notifying drivers that there is a hump in the road ahead. <end>',
#   '<start> A street sign notifying drivers of a hump in the road. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000103582.jpg': ['<start> A cat sitting on one side of a suitcase while clothes are on the other side.  <end>',
#   '<start> A small cat is sitting on top of a suite case.  <end>',
#   '<start> A cat sitting in an open, packed suitcase  <end>',
#   '<start> A cat is laying on some olive colored luggage. <end>',
#   '<start> A multicolored cat sitting on the top portion of an open piece of luggage that has clothes packed in it. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000309706.jpg': ['<start> A woman wearing sunglasses sitting on a metal outdoor chair. <end>',
#   '<start> A young woman sitting alone on a bench. <end>',
#   '<start> A person that is sitting down reading a book. <end>',
#   '<start> A lady sitting down on the bench observes her purse.  <end>',
#   '<start> a girl is sitting on a bench with a brown purse <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000528112.jpg': ['<start> A sail boat passing under a highway bridge. <end>',
#   '<start> A truck carries hay over a bridge.  <end>',
#   '<start> Sailboat on river passing under bridge with truck traffic.  <end>',
#   '<start> The sailboat takes a leisurely course under the bridge. <end>',
#   '<start> A sail boat traveling under a bridge with a truck on it. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000381472.jpg': ['<start> A plane is parked and being examined by several men. <end>',
#   '<start> A plane sitting on the tarmac with workers nearby. <end>',
#   '<start> A small commercial plane with some workers next to it. <end>',
#   '<start> A large white airplane and some people in vests. <end>',
#   '<start> A small charter plane  being parked by some people working at an airport. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000493959.jpg': ['<start> A set of triplets sit on a couch doing different things. <end>',
#   '<start> Three men are sitting on a orange coach <end>',
#   '<start> Some guys that look like each other on a pretty couch. <end>',
#   '<start> A man with a phone sitting on a couch. <end>',
#   '<start> Time lapse photo of adult male sitting on couch in various activities. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000252775.jpg': ['<start> A man standing next to a white bird cage. <end>',
#   '<start> a man playing with a bird in a house <end>',
#   '<start> A man pets a bird out of its cage. <end>',
#   '<start> A man reaches up to touch a bird on-top of a cage. <end>',
#   '<start> a man touching a bird on top of a cage <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000423806.jpg': ['<start> A woman is holding a wii remote in her right hand while another woman watches. <end>',
#   '<start> Two woman playing with with Wii controllers, standing up. <end>',
#   '<start> A women who is playing a video game. <end>',
#   '<start> Two woman standing in the hallway of an apartment. <end>',
#   '<start> Two women standing and playing a video game. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000361391.jpg': ['<start> someone bending down picking something up off the floor . <end>',
#   '<start> A man wiping up a spill on a kitchen floor. <end>',
#   '<start> A person and a child crawling on a floor. <end>',
#   '<start> A person on the floor in front of a refrigerator <end>',
#   '<start> Beautiful brown colors and wood in the backdrop of a cunning little boy. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000332812.jpg': ['<start> A black and white photo of a baseball player holding a bat. <end>',
#   '<start> An old Boston baseball player sits while holding his bat. <end>',
#   '<start> Old photograph depicting major league baseball player at stadium. <end>',
#   '<start> A baseball player waits on the stadium out back <end>',
#   '<start> A baseball player sitting in the stands with his bat. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000381139.jpg': ['<start> A person on surfboard under a large wave with ledge in background. <end>',
#   '<start> A person on a surfboard rides a wave. <end>',
#   '<start> A surfer rides the pipe on a large wave <end>',
#   '<start> A surfer catches a big wave on a cliff beach. <end>',
#   '<start> A surfboarder riding a large wave near a cliff <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000056323.jpg': ['<start> Two trains parked at a train station near loading platforms. <end>',
#   '<start> a couple of trains are sitting on some tracks <end>',
#   '<start> People walk near the edge of a train station where two red trains sit. <end>',
#   '<start> People walk among a platform as trains are on the tracks. <end>',
#   '<start> Two red trains stopped side by side on the tracks, <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000419334.jpg': ['<start> a cheesy thin crust pizza sitting on a plate  <end>',
#   '<start> A homemade pizza is displayed on a piece of wood. <end>',
#   '<start> Baked pizza displayed on wooden disc on table top. <end>',
#   '<start> There is a cheese pizza with some topping on it. <end>',
#   '<start> a delicous pizza made with egg and ham served on a wooden plate <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000521204.jpg': ['<start> A tennis player prepares to serve the ball <end>',
#   '<start> A male tennis player in the middle of a serve. <end>',
#   '<start> A tennis player bends at the knees while serving the ball. <end>',
#   '<start> A man in a blue T-shirt playing a tennis tournament. <end>',
#   '<start> A tennis player gets ready to serve the ball during a match. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000371359.jpg': ['<start> A small bird sitting on top of a bunch of sticks. <end>',
#   '<start> Small brown bird sitting on a white stick being held.  <end>',
#   '<start> The man is holding the bird on chopsticks. <end>',
#   '<start> A bird that is sitting on a a stick. <end>',
#   '<start> A man holds a bird with a stick <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000098915.jpg': ['<start> People are outside and inside of a bedroom. <end>',
#   '<start> A person is standing in the doorway of a house <end>',
#   '<start> Several people standing around the front door with a bed in the foreground. <end>',
#   '<start> Two people stand near a picture window, with one person inside, and the other person outside on a patio. <end>',
#   '<start> The man is standing in front of the glass door. <end>'],
#  '/kaggle/input/cocodatasetannotations/train2014/train2014/COCO_train2014_000000296931.jpg': ['<start> A corded off area of the inside of a building. <end>',
#   '<start> A fire place sitting below a brick and plaster mantel. <end>',
#   '<start> A room that includes a fireplace, piano, chairs, and white cabinets <end>',
#   '<start> A roped off living room area with chairs and piano. <end>',
#   '<start> a green rug in a large living room <end>'],
#  ...}

# %%
# train_data["coco/train2014/COCO_train2014_000000254362.jpg"]

# %%
# check in train_data if there are more than 5 values
# remove the 6th value and keep the first 5 values

for key, value in train_data.items():
    if len(value) > 5:
        # print(key, len(value))
        train_data[key] = value[:5]

for key, value in valid_data.items():
    if len(value) > 5:
        # print(key, len(value))
        valid_data[key] = value[:5]

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    print("PROCESS_INPUT: LEN DATASET", len(dataset))
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, tf.ragged.constant((captions))))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))
# Out:
# PROCESS_INPUT: LEN DATASET 4
# PROCESS_INPUT: LEN DATASET 4

# %% [markdown]
# ## Building the model
#
# Our image captioning architecture consists of three models:
#
# 1. A CNN: used to extract the image features
# 2. A TransformerEncoder: The extracted image features are then passed to a Transformer
#                     based encoder that generates a new representation of the inputs
# 3. A TransformerDecoder: This model takes the encoder output and the text data
#                     (sequences) as inputs and tries to learn to generate the caption.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Assume IMAGE_SIZE is defined elsewhere, e.g., IMAGE_SIZE = (224, 224)
# Assume EMBED_DIM is defined, e.g., EMBED_DIM = 256


def get_cnn_model(input_shape=(*IMAGE_SIZE, 3)):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv2D(64, 3, activation="leaky_relu", padding="same")(inputs)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(128, 3, activation="leaky_relu", padding="same")(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(256, 3, activation="leaky_relu", padding="same")(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(512, 3, activation="leaky_relu", padding="same")(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(512, 3, activation="leaky_relu", padding="same")(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(512, 3, activation="leaky_relu", padding="same")(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(EMBED_DIM, activation="leaky_relu")(x)
    return keras.Model(inputs, x)


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, training, mask=None):
        inputs = tf.expand_dims(inputs, axis=1)  # Add sequence dimension
        attention_output = self.attention(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM,
            sequence_length=SEQ_LENGTH,
            vocab_size=VOCAB_SIZE,
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [
                tf.expand_dims(batch_size, -1),
                tf.constant([1, 1], dtype=tf.int32),
            ],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self,
        cnn_model,
        encoder,
        decoder,
        num_captions_per_image=5,
        image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=4)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=8)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model,
    encoder=encoder,
    decoder=decoder,
    image_aug=image_augmentation,
)

# %% [markdown]
# ## Model training

# %%
import datetime
try:
    from google.colab import drive
    import datetime
    drive.mount('/content/gdrive')

    # Create a directory in Google Drive to store models
    # !mkdir /content/gdrive/My\ Drive/Colab_Models
    loss_model_path = "/content/gdrive/My Drive/Colab_Models/loss_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + ".txt"
    checkpoint_path = "/content/gdrive/My Drive/Colab_Models/cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + ".weights.h5"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    open(loss_model_path, 'w').close()
except:
    loss_model_path = "loss_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + ".txt"
    checkpoint_path = "cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_" + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + ".weights.h5"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    open(loss_model_path, 'w').close()

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False,
    reduction='none',
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import _pickle as pickle
from keras_nlp.metrics import Bleu, Perplexity, RougeL
from keras.callbacks import Callback
import warnings
import logging
import tensorflow as tf
import json
import os

# # Set TensorFlow logging level to ERROR to suppress warnings and info messages
logging.getLogger('tensorflow').setLevel(logging.ERROR)
warnings.filterwarnings('ignore')




class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.history = {'loss':[],'val_loss':[]}

    def on_batch_end(self, batch, logs={}):
        self.history['loss'].append(logs.get('loss'))
        with open(loss_model_path, "r+b") as myfile:
            myfile.write(pickle.dumps(self.history))

    def on_epoch_end(self, epoch, logs={}):
        self.history['val_loss'].append(logs.get('val_loss'))



class BleuScoreCallback(keras.callbacks.Callback):
    def __init__(self, validation_dataset, dim_batch, vectorization, index_lookup, max_decoded_sentence_length, n_batch=5):
        super().__init__()
        self.validation_dataset = validation_dataset
        self.dim_batch = dim_batch
        self.n_batch = n_batch
        self.vectorization = vectorization
        self.index_lookup = index_lookup
        self.max_decoded_sentence_length = max_decoded_sentence_length
        self.bleu_metric4 = Bleu( max_order=4)
        self.bleu_metric3 = Bleu( max_order=3)
        self.bleu_metric2 = Bleu( max_order=2)
        self.bleu_metric1 = Bleu( max_order=1)

    def on_epoch_end(self, epoch, logs=None):
        references = []
        predictions = []

        for batch_data in self.validation_dataset.take(self.n_batch):
            # reduce batch size if the number of samples is more than the dim_batch ( for limited memory devices)
            if len(batch_data[0]) > self.dim_batch:
                batch_data = (batch_data[0][:self.dim_batch], batch_data[1][:self.dim_batch])
            batch_img, batch_seq = batch_data
            img_embed = self.model.cnn_model(batch_img, training=False)
            encoded_img = self.model.encoder(img_embed, training=False)

            for i in range(batch_img.shape[0]):
                decoded_caption = "<start>"
                for j in range(self.max_decoded_sentence_length):
                    tokenized_caption = self.vectorization([decoded_caption])[:, :-1]
                    mask = tf.math.not_equal(tokenized_caption, 0)
                    predictions_batch = self.model.decoder(
                        tokenized_caption, encoded_img[i:i+1], training=False, mask=mask
                    )

                    if j < predictions_batch.shape[1]:
                        sampled_token_index = np.argmax(predictions_batch[0, j, :])
                        sampled_token = self.index_lookup[sampled_token_index]
                        if sampled_token == "<end>":
                            break
                        decoded_caption += " " + sampled_token
                    else:
                        break

                decoded_caption = decoded_caption.replace("<start> ", "").replace(" <end>", "").strip()
                pred_texts = decoded_caption

                # Convert ground truth token IDs to text ## TO fix that in this way the 5 caption are concatenated, we need to split them get the bleu score separately
                gt_texts = ' '.join([self.index_lookup[int(token)] for token in batch_seq[i, 1:].numpy().flatten() if int(token) != 0])


                references.append([gt_texts])
                predictions.append(pred_texts)

        bleu_score = self.bleu_metric1(references, predictions).numpy()
        print(f"Epoch {epoch+1} - BLEU1 Score: {bleu_score}")
        logs['BLEU-4'] = self.bleu_metric4(references, predictions).numpy()
        logs['BLEU-1'] = self.bleu_metric1(references, predictions).numpy()

class BleuScoreCallback(keras.callbacks.Callback):
    def __init__(self, validation_dataset, dim_batch, vectorization, index_lookup, max_decoded_sentence_length, n_batch=5):
        super().__init__()
        self.validation_dataset = validation_dataset
        self.dim_batch = dim_batch
        self.n_batch = n_batch
        self.vectorization = vectorization
        self.index_lookup = index_lookup
        self.max_decoded_sentence_length = max_decoded_sentence_length
        self.bleu_metric4 = Bleu(max_order=4)
        self.bleu_metric3 = Bleu(max_order=3)
        self.bleu_metric2 = Bleu(max_order=2)
        self.bleu_metric1 = Bleu(max_order=1)

    def on_epoch_end(self, epoch, logs=None):
        references = []
        predictions = []

        for batch_data in self.validation_dataset.take(self.n_batch):
            # Reduce batch size if the number of samples is more than the dim_batch (for limited memory devices)
            if len(batch_data[0]) > self.dim_batch:
                batch_data = (batch_data[0][:self.dim_batch], batch_data[1][:self.dim_batch])
            batch_img, batch_seq = batch_data
            img_embed = self.model.cnn_model(batch_img, training=False)
            encoded_img = self.model.encoder(img_embed, training=False)

            for i in range(batch_img.shape[0]):
                decoded_caption = "<start>"
                for j in range(self.max_decoded_sentence_length):
                    tokenized_caption = self.vectorization([decoded_caption])[:, :-1]
                    mask = tf.math.not_equal(tokenized_caption, 0)
                    predictions_batch = self.model.decoder(
                        tokenized_caption, encoded_img[i:i+1], training=False, mask=mask
                    )

                    if j < predictions_batch.shape[1]:
                        sampled_token_index = np.argmax(predictions_batch[0, j, :])
                        sampled_token = self.index_lookup[sampled_token_index]
                        if sampled_token == "<end>":
                            break
                        decoded_caption += " " + sampled_token
                    else:
                        break

                decoded_caption = decoded_caption.replace("<start> ", "").replace(" <end>", "").strip()
                pred_texts = decoded_caption

                # Convert ground truth token IDs to text and split them into individual captions
                gt_texts = [
                    ' '.join([self.index_lookup[int(token)] for token in caption if int(token) != 0])
                    for caption in batch_seq[i].numpy()
                ]

                references.extend([[gt_text] for gt_text in gt_texts])
                predictions.extend([pred_texts] * len(gt_texts))

        bleu_score1 = self.bleu_metric1(references, predictions).numpy()
        bleu_score4 = self.bleu_metric4(references, predictions).numpy()
        print(f"Epoch {epoch+1} - BLEU1 Score: {bleu_score1}, BLEU4 Score: {bleu_score4}")
        logs['BLEU-1'] = bleu_score1
        logs['BLEU-4'] = bleu_score4

class PerplexityCallback(Callback):
    def __init__(self, validation_dataset, dim_batch, vectorization, index_lookup, max_decoded_sentence_length, n_batch=5, verbose=False):
        super().__init__()
        self.validation_dataset = validation_dataset
        self.dim_batch = dim_batch
        self.n_batch = n_batch
        self.vectorization = vectorization
        self.index_lookup = index_lookup
        self.max_decoded_sentence_length = max_decoded_sentence_length
        self.perplexity_metric = Perplexity(from_logits=True)
        self.verbose = verbose

    def log(self, message):
        if self.verbose:
            print(message)

    def on_epoch_end(self, epoch, logs=None):
        total_perplexity = 0
        num_batches = 0

        for batch_data in self.validation_dataset.take(self.n_batch):
            if len(batch_data[0]) > self.dim_batch:
                batch_data = (batch_data[0][:self.dim_batch], batch_data[1][:self.dim_batch])
            batch_img, batch_seq = batch_data

            self.log(f"Batch sequence shape: {batch_seq.shape}")

            img_embed = self.model.cnn_model(batch_img, training=False)
            encoded_img = self.model.encoder(img_embed, training=False)

            for i in range(batch_img.shape[0]):  # For each image in the batch
                image_perplexities = []
                for c in range(batch_seq.shape[1]):  # For each caption of the image
                    tokenized_caption = self.vectorization(["<start>"])[:, :1]  # Take only the <start> token
                    predictions = []

                    self.log(f"Initial tokenized_caption shape: {tokenized_caption.shape}")

                    for j in range(1, min(self.max_decoded_sentence_length, batch_seq.shape[2] - 1)):
                        try:
                            mask = tf.math.not_equal(tokenized_caption, 0)
                            pred_batch = self.model.decoder(
                                tokenized_caption, encoded_img[i:i+1], training=False, mask=mask
                            )
                            predictions.append(pred_batch[:, -1:, :])  # Only keep the last prediction

                            next_token = tf.reshape(batch_seq[i, c, j], (1, 1))
                            self.log(f"Next token shape: {next_token.shape}, value: {next_token.numpy()}")
                            tokenized_caption = tf.concat([tokenized_caption, next_token], axis=1)
                            self.log(f"Updated tokenized_caption shape: {tokenized_caption.shape}")
                        except tf.errors.InvalidArgumentError as e:
                            self.log(f"Error at position {j}. Skipping this token.")
                            continue

                    if not predictions:
                        self.log("No valid predictions were made. Skipping this caption.")
                        continue

                    predictions = tf.concat(predictions, axis=1)
                    target = batch_seq[i:i+1, c, 1:j]  # Remove <start> token and limit to predicted length

                    self.log(f"Predictions shape: {predictions.shape}")
                    self.log(f"Target shape: {target.shape}")

                    # Ensure predictions and target have the same sequence length
                    min_len = min(predictions.shape[1], target.shape[1])
                    predictions = predictions[:, :min_len, :]
                    target = target[:, :min_len]

                    if min_len == 0:
                        self.log("No valid tokens to calculate perplexity. Skipping this caption.")
                        continue

                    try:
                        self.perplexity_metric.update_state(target, predictions)
                        caption_perplexity = self.perplexity_metric.result().numpy()
                        image_perplexities.append(caption_perplexity)
                    except tf.errors.InvalidArgumentError as e:
                        self.log(f"Error calculating perplexity: {e}")
                    finally:
                        self.perplexity_metric.reset_state()

                # Average perplexity across all captions for this image
                if image_perplexities:
                    avg_image_perplexity = sum(image_perplexities) / len(image_perplexities)
                    total_perplexity += avg_image_perplexity
                    num_batches += 1
                else:
                    self.log("No valid perplexities for this image. Skipping.")

        avg_perplexity = total_perplexity / num_batches if num_batches > 0 else 0
        self.log(f"Epoch {epoch+1} - Average Perplexity: {avg_perplexity:.4f}")
        logs['perplexity'] = avg_perplexity


class RougeScoreCallback(keras.callbacks.Callback):
    def __init__(self, validation_dataset, dim_batch, vectorization, index_lookup, max_decoded_sentence_length, n_batch=5, verbose=False):
        super().__init__()
        self.validation_dataset = validation_dataset
        self.dim_batch = dim_batch
        self.n_batch = n_batch
        self.vectorization = vectorization
        self.index_lookup = index_lookup
        self.max_decoded_sentence_length = max_decoded_sentence_length
        self.rouge_metric = RougeL()
        self.verbose = verbose

    def log(self, message):
        if self.verbose:
            print(message)

    def on_epoch_end(self, epoch, logs=None):
        references = []
        predictions = []

        for batch_data in self.validation_dataset.take(self.n_batch):
            # Reduce batch size if the number of samples is more than the dim_batch (for limited memory devices)
            if len(batch_data[0]) > self.dim_batch:
                batch_data = (batch_data[0][:self.dim_batch], batch_data[1][:self.dim_batch])
            batch_img, batch_seq = batch_data
            img_embed = self.model.cnn_model(batch_img, training=False)
            encoded_img = self.model.encoder(img_embed, training=False)

            for i in range(batch_img.shape[0]):
                decoded_caption = "<start>"
                for j in range(self.max_decoded_sentence_length):
                    tokenized_caption = self.vectorization([decoded_caption])[:, :-1]
                    mask = tf.math.not_equal(tokenized_caption, 0)
                    predictions_batch = self.model.decoder(
                        tokenized_caption, encoded_img[i:i+1], training=False, mask=mask
                    )

                    if j < predictions_batch.shape[1]:
                        sampled_token_index = np.argmax(predictions_batch[0, j, :])
                        sampled_token = self.index_lookup[sampled_token_index]
                        if sampled_token == "<end>":
                            break
                        decoded_caption += " " + sampled_token
                    else:
                        break

                decoded_caption = decoded_caption.replace("<start> ", "").replace(" <end>", "").strip()
                pred_texts = decoded_caption

                # Convert ground truth token IDs to text and split them into individual captions
                gt_texts = [
                    ' '.join([self.index_lookup[int(token)] for token in caption if int(token) != 0])
                    for caption in batch_seq[i].numpy()
                ]

                references.extend(gt_texts)
                predictions.extend([pred_texts] * len(gt_texts))

                if self.verbose:
                    for ref, pred in zip(gt_texts, [pred_texts] * len(gt_texts)):
                        print(f"Reference: {ref}")
                        print(f"Prediction: {pred}")

        rouge_scores = [self.rouge_metric(ref, pred) for ref, pred in zip(references, predictions)]
        rouge_precisions = [score['precision'].numpy() for score in rouge_scores]
        rouge_recalls = [score['recall'].numpy() for score in rouge_scores]
        rouge_f1_scores = [score['f1_score'].numpy() for score in rouge_scores]

        avg_rouge_precision = np.mean(rouge_precisions)
        avg_rouge_recall = np.mean(rouge_recalls)
        avg_rouge_f1_score = np.mean(rouge_f1_scores)

        print(f"Epoch {epoch+1} - ROUGE-L Precision: {avg_rouge_precision}, Recall: {avg_rouge_recall}, F1 Score: {avg_rouge_f1_score}")
        logs['ROUGE-L Precision'] = avg_rouge_precision
        logs['ROUGE-L Recall'] = avg_rouge_recall
        logs['ROUGE-L F1 Score'] = avg_rouge_f1_score


class SaveLogsCallback(keras.callbacks.Callback):
    def __init__(self, log_file_path):
        super().__init__()
        self.log_file_path = log_file_path
        self.logs = []

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = epoch + 1
        # Convert float32 values to regular floats
        logs = {k: (float(v) if isinstance(v, (np.float32, np.float64, tf.dtypes.DType)) else v) for k, v in logs.items()}
        self.logs.append(logs)

    def on_train_end(self, logs=None):
        with open(self.log_file_path, 'w') as f:
            json.dump(self.logs, f, indent=4)


# Define the path where you want to save the logs
log_file_name = 'test_training_logs.json'
if '/' not in loss_model_path:
    log_file_path = log_file_name
else:
    base_path = loss_model_path[:loss_model_path.rfind('/')]

    log_file_path = os.path.join(base_path, log_file_name)

print(log_file_path)
# Create an instance of the callback
save_logs_callback = SaveLogsCallback(log_file_path)


history = LossHistory()
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
bleu_callback = BleuScoreCallback(valid_dataset,10 ,vectorization, index_lookup, SEQ_LENGTH)

# Example usage
rouge_callback = RougeScoreCallback(
    validation_dataset=valid_dataset,
    dim_batch=10,
    vectorization=vectorization,
    index_lookup=index_lookup,
    max_decoded_sentence_length=SEQ_LENGTH,
    verbose=False
)

perplexity_callback = PerplexityCallback(
    validation_dataset=valid_dataset,
    dim_batch=10,
    vectorization=vectorization,
    index_lookup=index_lookup,
    max_decoded_sentence_length=SEQ_LENGTH
)

# Fit the model

caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
    callbacks=[early_stopping, cp_callback, history, bleu_callback, perplexity_callback, rouge_callback, save_logs_callback],
)
# Out:
# test_training_logs.json
# Epoch 1/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.2550 - loss: 27.1080
# Epoch 1: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 1 - BLEU1 Score: 0.13391652703285217, BLEU4 Score: 0.012278786860406399
# Epoch 1 - ROUGE-L Precision: 0.21963635087013245, Recall: 0.18701870739459991, F1 Score: 0.19934839010238647
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1191s 4s/step - acc: 0.2553 - loss: 27.0856 - val_acc: 0.3995 - val_loss: 16.5162 - BLEU-1: 0.1339 - BLEU-4: 0.0123 - perplexity: 8728.5593 - ROUGE-L Precision: 0.2196 - ROUGE-L Recall: 0.1870 - ROUGE-L F1 Score: 0.1993 - epoch: 1.0000
# Epoch 2/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.3973 - loss: 16.5242
# Epoch 2: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 2 - BLEU1 Score: 0.13761217892169952, BLEU4 Score: 0.014584864489734173
# Epoch 2 - ROUGE-L Precision: 0.22181221842765808, Recall: 0.18812714517116547, F1 Score: 0.20143011212348938
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1156s 4s/step - acc: 0.3973 - loss: 16.5228 - val_acc: 0.4208 - val_loss: 15.1757 - BLEU-1: 0.1376 - BLEU-4: 0.0146 - perplexity: 8626.9843 - ROUGE-L Precision: 0.2218 - ROUGE-L Recall: 0.1881 - ROUGE-L F1 Score: 0.2014 - epoch: 2.0000
# Epoch 3/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4155 - loss: 15.3914
# Epoch 3: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 3 - BLEU1 Score: 0.1381385326385498, BLEU4 Score: 0.015188735909759998
# Epoch 3 - ROUGE-L Precision: 0.22637927532196045, Recall: 0.189785897731781, F1 Score: 0.20432008802890778
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1155s 4s/step - acc: 0.4155 - loss: 15.3909 - val_acc: 0.4321 - val_loss: 14.5827 - BLEU-1: 0.1381 - BLEU-4: 0.0152 - perplexity: 8624.1286 - ROUGE-L Precision: 0.2264 - ROUGE-L Recall: 0.1898 - ROUGE-L F1 Score: 0.2043 - epoch: 3.0000
# Epoch 4/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4249 - loss: 14.8376
# Epoch 4: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 4 - BLEU1 Score: 0.14125920832157135, BLEU4 Score: 0.015190343372523785
# Epoch 4 - ROUGE-L Precision: 0.23199167847633362, Recall: 0.19351449608802795, F1 Score: 0.2090180665254593
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1159s 4s/step - acc: 0.4249 - loss: 14.8373 - val_acc: 0.4380 - val_loss: 14.2656 - BLEU-1: 0.1413 - BLEU-4: 0.0152 - perplexity: 8598.2248 - ROUGE-L Precision: 0.2320 - ROUGE-L Recall: 0.1935 - ROUGE-L F1 Score: 0.2090 - epoch: 4.0000
# Epoch 5/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4310 - loss: 14.4810
# Epoch 5: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 5 - BLEU1 Score: 0.14033766090869904, BLEU4 Score: 0.016022132709622383
# Epoch 5 - ROUGE-L Precision: 0.23337794840335846, Recall: 0.1913485825061798, F1 Score: 0.20824426412582397
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1149s 4s/step - acc: 0.4310 - loss: 14.4808 - val_acc: 0.4412 - val_loss: 14.0868 - BLEU-1: 0.1403 - BLEU-4: 0.0160 - perplexity: 8580.0014 - ROUGE-L Precision: 0.2334 - ROUGE-L Recall: 0.1913 - ROUGE-L F1 Score: 0.2082 - epoch: 5.0000
# Epoch 6/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4355 - loss: 14.2223
# Epoch 6: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 6 - BLEU1 Score: 0.13919425010681152, BLEU4 Score: 0.015861552208662033
# Epoch 6 - ROUGE-L Precision: 0.23362773656845093, Recall: 0.1886983960866928, F1 Score: 0.206711545586586
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1152s 4s/step - acc: 0.4355 - loss: 14.2221 - val_acc: 0.4440 - val_loss: 13.9518 - BLEU-1: 0.1392 - BLEU-4: 0.0159 - perplexity: 8540.3472 - ROUGE-L Precision: 0.2336 - ROUGE-L Recall: 0.1887 - ROUGE-L F1 Score: 0.2067 - epoch: 6.0000
# Epoch 7/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4393 - loss: 14.0160
# Epoch 7: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 7 - BLEU1 Score: 0.13862523436546326, BLEU4 Score: 0.01592000387609005
# Epoch 7 - ROUGE-L Precision: 0.2357529252767563, Recall: 0.18887701630592346, F1 Score: 0.2076585441827774
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1152s 4s/step - acc: 0.4393 - loss: 14.0158 - val_acc: 0.4463 - val_loss: 13.8424 - BLEU-1: 0.1386 - BLEU-4: 0.0159 - perplexity: 8579.8066 - ROUGE-L Precision: 0.2358 - ROUGE-L Recall: 0.1889 - ROUGE-L F1 Score: 0.2077 - epoch: 7.0000
# Epoch 8/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4427 - loss: 13.8350
# Epoch 8: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 8 - BLEU1 Score: 0.1401914656162262, BLEU4 Score: 0.016292644664645195
# Epoch 8 - ROUGE-L Precision: 0.2357095181941986, Recall: 0.18901976943016052, F1 Score: 0.20773865282535553
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1152s 4s/step - acc: 0.4427 - loss: 13.8349 - val_acc: 0.4487 - val_loss: 13.7243 - BLEU-1: 0.1402 - BLEU-4: 0.0163 - perplexity: 8544.6837 - ROUGE-L Precision: 0.2357 - ROUGE-L Recall: 0.1890 - ROUGE-L F1 Score: 0.2077 - epoch: 8.0000
# Epoch 9/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4453 - loss: 13.6863
# Epoch 9: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 9 - BLEU1 Score: 0.1412353515625, BLEU4 Score: 0.01626425050199032
# Epoch 9 - ROUGE-L Precision: 0.23864547908306122, Recall: 0.19110345840454102, F1 Score: 0.21019208431243896
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1154s 4s/step - acc: 0.4453 - loss: 13.6862 - val_acc: 0.4511 - val_loss: 13.6316 - BLEU-1: 0.1412 - BLEU-4: 0.0163 - perplexity: 8486.9120 - ROUGE-L Precision: 0.2386 - ROUGE-L Recall: 0.1911 - ROUGE-L F1 Score: 0.2102 - epoch: 9.0000
# Epoch 10/10
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - acc: 0.4479 - loss: 13.5553
# Epoch 10: saving model to cp_model_transformer_based_custom_BLEU_2X_CNN_2X_num_heads_leaky_relu_20240831_094230.weights.h5
# Epoch 10 - BLEU1 Score: 0.1412181258201599, BLEU4 Score: 0.016991328448057175
# Epoch 10 - ROUGE-L Precision: 0.2413347214460373, Recall: 0.19254472851753235, F1 Score: 0.2121158391237259
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1155s 4s/step - acc: 0.4479 - loss: 13.5552 - val_acc: 0.4515 - val_loss: 13.6107 - BLEU-1: 0.1412 - BLEU-4: 0.0170 - perplexity: 8464.9426 - ROUGE-L Precision: 0.2413 - ROUGE-L Recall: 0.1925 - ROUGE-L F1 Score: 0.2121 - epoch: 10.0000

# %%
# from keras_nlp.metrics import Bleu
# bleu = Bleu(max_order=3)
# print("Calculating BLEU Score es:" + str(bleu(["references text"], [" references test"]).numpy()))
# bleu(["references text"], [" references test"]).numpy()

# %%
log_file_path = "test_training_logs.json"

# %%
import json
import matplotlib.pyplot as plt
import math

# Load the JSON data from the log file
with open(log_file_path, 'r') as f:
    logs = json.load(f)

# Extract metrics
epochs = [log['epoch'] for log in logs]
metrics = {key: [log[key] for log in logs if key in log] for key in logs[0].keys() if key != 'epoch'}

# Determine the number of rows and columns for the grid
num_metrics = len(metrics)
num_cols = 3
num_rows = math.ceil(num_metrics / num_cols)

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))

# Flatten axes array for easy iteration
axes = axes.flatten()

# Plot each metric
for idx, (metric, values) in enumerate(metrics.items()):
    axes[idx].plot(epochs, values, label=metric)
    axes[idx].set_xlabel('Epoch')
    axes[idx].set_ylabel(metric)
    axes[idx].set_title(f'{metric} over epochs')
    axes[idx].legend()

# Remove any empty subplots
for idx in range(num_metrics, num_rows * num_cols):
    fig.delaxes(axes[idx])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Check sample predictions

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  a zebra standing in a field with trees in the background
# Predicted Caption:  a zebra standing in a field with trees in the background
# Predicted Caption:  a man is sitting on a couch with a laptop

# %% [markdown]
# ## End Notes
#
# We saw that the model starts to generate reasonable captions after a few epochs. To keep
# this example easily runnable, we have trained it with a few constraints, like a minimal
# number of attention heads. To improve the predictions, you can try changing these training
# settings and find a good model for your use case.
