# %%
from fdl_project.classes.preprocessor import Preprocessor

preprocessor = Preprocessor()

train_dataset, valid_dataset = preprocessor.load_and_prepare_data()
# Out:
# Loading data..
# Data loaded succesfully!
# Loading data..
# Data loaded succesfully!
# Number of training samples:  66226
# Number of validation samples:  16557
# Loading data..
# Data loaded succesfully!
# Loading data..
# Data loaded succesfully!
# PROCESS_INPUT: LEN DATASET 4
# 2024-06-25 16:02:02.239735: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 123797472 exceeds 10% of free system memory.
# ---------------------------------------------------------------------------
# OperatorNotAllowedInGraphError            Traceback (most recent call last)
# Cell In[7], line 5
#       1 from fdl_project.classes.preprocessor import Preprocessor
#       3 preprocessor = Preprocessor()
# ----> 5 train_dataset, valid_dataset = preprocessor.load_and_prepare_data()
#
# File ~/fdl_project/classes/preprocessor.py:77, in Preprocessor.load_and_prepare_data(self)
#      74         train_data[key] = value[:5]
# ...
